# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json as json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
import requests
from datetime import datetime

import os
import sys

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"] 
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp F°": city_max_temp,
                          "Humidity %": city_humidity,
                          "Cloudiness %": city_clouds,
                          "Wind Speed mph": city_wind,
                          "Weather Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | sartell
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | santa cruz de tenerife
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | tiarei
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | hasaki
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 1 | cape canaveral
# Processing Record 23 of Set 1 | mantua
# Processing Record 24 of Set 1 | totness
# Processing Record 25 of Set 1 | leningradskiy
# Processing Record 26 of Set 1 | druzhnaya gorka
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | kolda
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 1 | saint-leu
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | lagoa
# Processing Record 38 of Set 1 | bermejo
# Processing Record 39 of Set 1 | beisfjord
# Processing Record 40 of Set 1 | vestmannaeyjar
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | dingle
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | nuristan
# Processing Record 46 of Set 1 | atar
# Processing Record 47 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | hirara
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | sidi ali
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | honiara
# Processing Record 8 of Set 2 | palmer
# Processing Record 9 of Set 2 | bemidji
# Processing Record 10 of Set 2 | jacmel
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | kiamba
# Processing Record 13 of Set 2 | marawi
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | tingi
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | imbituba
# Processing Record 19 of Set 2 | itarema
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | vostok
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | oistins
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | chifeng
# Processing Record 28 of Set 2 | port-gentil
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | te anau
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | jingdezhen
# Processing Record 33 of Set 2 | byron bay
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | george town
# Processing Record 38 of Set 2 | vanimo
# Processing Record 39 of Set 2 | rubtsovsk
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | pozhva
# Processing Record 43 of Set 2 | egvekinot
# Processing Record 44 of Set 2 | baft
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | oxelosund
# Processing Record 48 of Set 2 | yashkul
# Processing Record 49 of Set 2 | cayenne
# Processing Record 50 of Set 2 | alofi
# Processing Record 1 of Set 3 | atambua
# Processing Record 2 of Set 3 | north bend
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | nichinan
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | bethanien
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | nikolskoye
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | santa fe
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | euclides da cunha
# Processing Record 13 of Set 3 | abu dhabi
# Processing Record 14 of Set 3 | paamiut
# Processing Record 15 of Set 3 | malavalli
# Processing Record 16 of Set 3 | chase
# Processing Record 17 of Set 3 | svetlaya
# Processing Record 18 of Set 3 | kabinda
# Processing Record 19 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 3 | janovice nad uhlavou
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | sfantu gheorghe
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | kidodi
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | brae
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | sistranda
# Processing Record 35 of Set 3 | kenai
# Processing Record 36 of Set 3 | sambava
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | pyapon
# Processing Record 39 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 3 | tirat karmel
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | trincomalee
# Processing Record 43 of Set 3 | san cristobal
# Processing Record 44 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 3 | yershichi
# Processing Record 46 of Set 3 | taoudenni
# Processing Record 47 of Set 3 | ambon
# Processing Record 48 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 3 | mehamn
# Processing Record 50 of Set 3 | hilo
# Processing Record 1 of Set 4 | sharjah
# Processing Record 2 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 4 | tilichiki
# Processing Record 4 of Set 4 | vestmanna
# Processing Record 5 of Set 4 | angoram
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | namatanai
# Processing Record 8 of Set 4 | prince rupert
# Processing Record 9 of Set 4 | coquimbo
# Processing Record 10 of Set 4 | soyo
# Processing Record 11 of Set 4 | jinsha
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | nueve de julio
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | comodoro rivadavia
# Processing Record 17 of Set 4 | truth or consequences
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | tromso
# Processing Record 20 of Set 4 | shemysheyka
# Processing Record 21 of Set 4 | peniche
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | yulara
# Processing Record 24 of Set 4 | tigil
# Processing Record 25 of Set 4 | prainha
# Processing Record 26 of Set 4 | kedrovyy
# Processing Record 27 of Set 4 | minot
# Processing Record 28 of Set 4 | sabang
# Processing Record 29 of Set 4 | dawson
# Processing Record 30 of Set 4 | moyale
# Processing Record 31 of Set 4 | orlik
# Processing Record 32 of Set 4 | daru
# Processing Record 33 of Set 4 | pierre
# Processing Record 34 of Set 4 | qandala
# Processing Record 35 of Set 4 | puqi
# Processing Record 36 of Set 4 | buraydah
# Processing Record 37 of Set 4 | vila velha
# Processing Record 38 of Set 4 | rabat
# Processing Record 39 of Set 4 | praya
# Processing Record 40 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 4 | aksarka
# Processing Record 42 of Set 4 | placido de castro
# Processing Record 43 of Set 4 | san jose
# Processing Record 44 of Set 4 | nantucket
# Processing Record 45 of Set 4 | kyaikkami
# Processing Record 46 of Set 4 | chara
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | sisimiut
# Processing Record 49 of Set 4 | iranshahr
# Processing Record 50 of Set 4 | pozo colorado
# Processing Record 1 of Set 5 | turukhansk
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | dakar
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | touros
# Processing Record 6 of Set 5 | qasigiannguit
# Processing Record 7 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 5 | fuerte olimpo
# Processing Record 9 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 5 | yuncheng
# Processing Record 11 of Set 5 | barcelos
# Processing Record 12 of Set 5 | olafsvik
# Processing Record 13 of Set 5 | nanakuli
# Processing Record 14 of Set 5 | sioux lookout
# Processing Record 15 of Set 5 | labuhan
# Processing Record 16 of Set 5 | hobart
# Processing Record 17 of Set 5 | anchorage
# Processing Record 18 of Set 5 | idrinskoye
# Processing Record 19 of Set 5 | moosomin
# Processing Record 20 of Set 5 | mulege
# Processing Record 21 of Set 5 | vardo
# Processing Record 22 of Set 5 | beidao
# Processing Record 23 of Set 5 | panama city
# Processing Record 24 of Set 5 | taltal
# Processing Record 25 of Set 5 | verkhoyansk
# Processing Record 26 of Set 5 | rio gallegos
# Processing Record 27 of Set 5 | jackson
# Processing Record 28 of Set 5 | victoria
# Processing Record 29 of Set 5 | kracheh
# City not found. Skipping...
# Processing Record 30 of Set 5 | batagay-alyta
# Processing Record 31 of Set 5 | alta floresta
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | kramat
# Processing Record 35 of Set 5 | saint-nazaire
# Processing Record 36 of Set 5 | puerto del rosario
# Processing Record 37 of Set 5 | staryy nadym
# Processing Record 38 of Set 5 | kirakira
# Processing Record 39 of Set 5 | krutinka
# Processing Record 40 of Set 5 | severo-kurilsk
# Processing Record 41 of Set 5 | baton rouge
# Processing Record 42 of Set 5 | nishihara
# Processing Record 43 of Set 5 | gondal
# Processing Record 44 of Set 5 | niamey
# Processing Record 45 of Set 5 | ilo
# Processing Record 46 of Set 5 | chibuto
# Processing Record 47 of Set 5 | puerto madryn
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | cockburn town
# Processing Record 50 of Set 5 | lubango
# Processing Record 1 of Set 6 | hailar
# Processing Record 2 of Set 6 | muli
# Processing Record 3 of Set 6 | awbari
# Processing Record 4 of Set 6 | casa nova
# Processing Record 5 of Set 6 | arman
# Processing Record 6 of Set 6 | colac
# Processing Record 7 of Set 6 | novyy urengoy
# Processing Record 8 of Set 6 | namibe
# Processing Record 9 of Set 6 | kletnya
# Processing Record 10 of Set 6 | ulaangom
# Processing Record 11 of Set 6 | lima
# Processing Record 12 of Set 6 | susangerd
# Processing Record 13 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 6 | husavik
# Processing Record 15 of Set 6 | los llanos de aridane
# Processing Record 16 of Set 6 | pacific grove
# Processing Record 17 of Set 6 | port keats
# Processing Record 18 of Set 6 | yaitepec
# City not found. Skipping...
# Processing Record 19 of Set 6 | westwood
# Processing Record 20 of Set 6 | staraya poltavka
# Processing Record 21 of Set 6 | isangel
# Processing Record 22 of Set 6 | the valley
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | sola
# Processing Record 25 of Set 6 | ozinki
# Processing Record 26 of Set 6 | brewster
# Processing Record 27 of Set 6 | yilan
# Processing Record 28 of Set 6 | providencia
# Processing Record 29 of Set 6 | west wendover
# Processing Record 30 of Set 6 | cairns
# Processing Record 31 of Set 6 | zaraza
# Processing Record 32 of Set 6 | khandbari
# Processing Record 33 of Set 6 | mildura
# Processing Record 34 of Set 6 | neiafu
# Processing Record 35 of Set 6 | moree
# Processing Record 36 of Set 6 | amontada
# Processing Record 37 of Set 6 | tanout
# Processing Record 38 of Set 6 | oga
# Processing Record 39 of Set 6 | haines junction
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | roald
# Processing Record 42 of Set 6 | les cayes
# Processing Record 43 of Set 6 | san carlos de bariloche
# Processing Record 44 of Set 6 | kununurra
# Processing Record 45 of Set 6 | ornskoldsvik
# Processing Record 46 of Set 6 | lata
# Processing Record 47 of Set 6 | rocha
# Processing Record 48 of Set 6 | upington
# Processing Record 49 of Set 6 | akyab
# Processing Record 50 of Set 6 | hildburghausen
# Processing Record 1 of Set 7 | nhulunbuy
# Processing Record 2 of Set 7 | taseyevo
# Processing Record 3 of Set 7 | vaxjo
# Processing Record 4 of Set 7 | kropotkin
# Processing Record 5 of Set 7 | nelson bay
# Processing Record 6 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 7 | vaitape
# Processing Record 8 of Set 7 | faanui
# Processing Record 9 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 7 | constitucion
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | ketchikan
# Processing Record 13 of Set 7 | mitsamiouli
# Processing Record 14 of Set 7 | omsukchan
# Processing Record 15 of Set 7 | san juan
# Processing Record 16 of Set 7 | isoka
# Processing Record 17 of Set 7 | qaqortoq
# Processing Record 18 of Set 7 | mao
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | utena
# Processing Record 21 of Set 7 | tabuk
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | richards bay
# Processing Record 24 of Set 7 | amio
# Processing Record 25 of Set 7 | zyryanka
# Processing Record 26 of Set 7 | komsomolskiy
# Processing Record 27 of Set 7 | hobyo
# Processing Record 28 of Set 7 | kuliyapitiya
# Processing Record 29 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 7 | mrakovo
# Processing Record 31 of Set 7 | palana
# Processing Record 32 of Set 7 | edd
# Processing Record 33 of Set 7 | bezhetsk
# Processing Record 34 of Set 7 | chicama
# Processing Record 35 of Set 7 | lebu
# Processing Record 36 of Set 7 | tolaga bay
# Processing Record 37 of Set 7 | ust-tsilma
# Processing Record 38 of Set 7 | san policarpo
# Processing Record 39 of Set 7 | matagami
# Processing Record 40 of Set 7 | havre
# Processing Record 41 of Set 7 | varkaus
# Processing Record 42 of Set 7 | ulaanbaatar
# Processing Record 43 of Set 7 | laguna
# Processing Record 44 of Set 7 | port elizabeth
# Processing Record 45 of Set 7 | jiuquan
# Processing Record 46 of Set 7 | mastic beach
# Processing Record 47 of Set 7 | monrovia
# Processing Record 48 of Set 7 | nemuro
# Processing Record 49 of Set 7 | villeneuve-sur-lot
# Processing Record 50 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 8 | hun
# Processing Record 2 of Set 8 | gat
# Processing Record 3 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | jacksonville
# Processing Record 5 of Set 8 | strezhevoy
# Processing Record 6 of Set 8 | ostrovnoy
# Processing Record 7 of Set 8 | solnechnyy
# Processing Record 8 of Set 8 | srednekolymsk
# Processing Record 9 of Set 8 | acapulco
# Processing Record 10 of Set 8 | udachnyy
# Processing Record 11 of Set 8 | ravar
# Processing Record 12 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 13 of Set 8 | muros
# Processing Record 14 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 8 | sorland
# Processing Record 16 of Set 8 | szendro
# Processing Record 17 of Set 8 | chernyshevskiy
# Processing Record 18 of Set 8 | samarai
# Processing Record 19 of Set 8 | tahoua
# Processing Record 20 of Set 8 | bakchar
# Processing Record 21 of Set 8 | erenhot
# Processing Record 22 of Set 8 | zabid
# Processing Record 23 of Set 8 | vila franca do campo
# Processing Record 24 of Set 8 | hamilton
# Processing Record 25 of Set 8 | peace river
# Processing Record 26 of Set 8 | morelia
# Processing Record 27 of Set 8 | college
# Processing Record 28 of Set 8 | betanzos
# Processing Record 29 of Set 8 | grindavik
# Processing Record 30 of Set 8 | salalah
# Processing Record 31 of Set 8 | bana
# Processing Record 32 of Set 8 | saint-francois
# Processing Record 33 of Set 8 | geraldton
# Processing Record 34 of Set 8 | ust-nera
# Processing Record 35 of Set 8 | filadelfia
# Processing Record 36 of Set 8 | saskylakh
# Processing Record 37 of Set 8 | sept-iles
# Processing Record 38 of Set 8 | la asuncion
# Processing Record 39 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 8 | broome
# Processing Record 41 of Set 8 | lithgow
# Processing Record 42 of Set 8 | talnakh
# Processing Record 43 of Set 8 | port macquarie
# Processing Record 44 of Set 8 | varkkallai
# Processing Record 45 of Set 8 | catio
# Processing Record 46 of Set 8 | port hardy
# Processing Record 47 of Set 8 | tautira
# Processing Record 48 of Set 8 | zuenoula
# Processing Record 49 of Set 8 | poum
# Processing Record 50 of Set 8 | kavieng
# Processing Record 1 of Set 9 | kazachinskoye
# Processing Record 2 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 3 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 9 | korla
# Processing Record 5 of Set 9 | pevek
# Processing Record 6 of Set 9 | dossor
# Processing Record 7 of Set 9 | jatiroto
# Processing Record 8 of Set 9 | santo antonio do ica
# Processing Record 9 of Set 9 | inuvik
# Processing Record 10 of Set 9 | saint-georges
# Processing Record 11 of Set 9 | sangar
# Processing Record 12 of Set 9 | teya
# Processing Record 13 of Set 9 | kaeo
# Processing Record 14 of Set 9 | rawah
# Processing Record 15 of Set 9 | badvel
# Processing Record 16 of Set 9 | berlevag
# Processing Record 17 of Set 9 | sinjai
# Processing Record 18 of Set 9 | cumana
# Processing Record 19 of Set 9 | oktyabrskoye
# Processing Record 20 of Set 9 | turbo
# Processing Record 21 of Set 9 | charcas
# Processing Record 22 of Set 9 | visnes
# Processing Record 23 of Set 9 | metairie
# Processing Record 24 of Set 9 | marsh harbour
# Processing Record 25 of Set 9 | borger
# Processing Record 26 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 9 | acarau
# Processing Record 28 of Set 9 | duldurga
# Processing Record 29 of Set 9 | maxixe
# Processing Record 30 of Set 9 | rengo
# Processing Record 31 of Set 9 | wardha
# Processing Record 32 of Set 9 | kapit
# Processing Record 33 of Set 9 | almaznyy
# Processing Record 34 of Set 9 | yaan
# Processing Record 35 of Set 9 | masallatah
# Processing Record 36 of Set 9 | isiolo
# Processing Record 37 of Set 9 | ontario
# Processing Record 38 of Set 9 | energeticheskiy
# Processing Record 39 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 9 | kupang
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | belmonte
# Processing Record 43 of Set 9 | camopi
# Processing Record 44 of Set 9 | iralaya
# Processing Record 45 of Set 9 | necochea
# Processing Record 46 of Set 9 | bud
# Processing Record 47 of Set 9 | wichita falls
# Processing Record 48 of Set 9 | san fernando
# Processing Record 49 of Set 9 | xuanhua
# Processing Record 50 of Set 9 | katsuura
# Processing Record 1 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 10 | saint-joseph
# Processing Record 3 of Set 10 | troitskoye
# Processing Record 4 of Set 10 | fasa
# Processing Record 5 of Set 10 | pisco
# Processing Record 6 of Set 10 | quatre cocos
# Processing Record 7 of Set 10 | ludvika
# Processing Record 8 of Set 10 | portland
# Processing Record 9 of Set 10 | leh
# Processing Record 10 of Set 10 | rio grande
# Processing Record 11 of Set 10 | klaksvik
# Processing Record 12 of Set 10 | penzance
# Processing Record 13 of Set 10 | grande prairie
# Processing Record 14 of Set 10 | aklavik
# Processing Record 15 of Set 10 | codrington
# Processing Record 16 of Set 10 | middelburg
# Processing Record 17 of Set 10 | ngunguru
# Processing Record 18 of Set 10 | blairmore
# Processing Record 19 of Set 10 | xingyi
# Processing Record 20 of Set 10 | malazgirt
# Processing Record 21 of Set 10 | mandera
# Processing Record 22 of Set 10 | arlit
# Processing Record 23 of Set 10 | deputatskiy
# Processing Record 24 of Set 10 | mangrol
# Processing Record 25 of Set 10 | ampanihy
# Processing Record 26 of Set 10 | sitka
# Processing Record 27 of Set 10 | grand forks
# Processing Record 28 of Set 10 | nome
# Processing Record 29 of Set 10 | kasane
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | souillac
# Processing Record 32 of Set 10 | menzelinsk
# Processing Record 33 of Set 10 | pasighat
# Processing Record 34 of Set 10 | meulaboh
# Processing Record 35 of Set 10 | port hedland
# Processing Record 36 of Set 10 | narsaq
# Processing Record 37 of Set 10 | sovetskoye
# Processing Record 38 of Set 10 | chalus
# Processing Record 39 of Set 10 | ratnagiri
# Processing Record 40 of Set 10 | bam
# Processing Record 41 of Set 10 | muhororo
# Processing Record 42 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 43 of Set 10 | kaseda
# Processing Record 44 of Set 10 | kumluca
# Processing Record 45 of Set 10 | paita
# Processing Record 46 of Set 10 | morgan city
# Processing Record 47 of Set 10 | maltahohe
# Processing Record 48 of Set 10 | staryy krym
# Processing Record 49 of Set 10 | ambilobe
# Processing Record 50 of Set 10 | pudozh
# Processing Record 1 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 11 | kanigoro
# Processing Record 3 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 4 of Set 11 | ribeira grande
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | talagang
# Processing Record 7 of Set 11 | kenora
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | mutis
# Processing Record 10 of Set 11 | ballaghaderreen
# Processing Record 11 of Set 11 | yeppoon
# Processing Record 12 of Set 11 | aykhal
# Processing Record 13 of Set 11 | anzio
# Processing Record 14 of Set 11 | show low
# Processing Record 15 of Set 11 | padang
# Processing Record 16 of Set 11 | hualmay
# Processing Record 17 of Set 11 | klyuchi
# Processing Record 18 of Set 11 | manggar
# Processing Record 19 of Set 11 | parabel
# Processing Record 20 of Set 11 | bathsheba
# Processing Record 21 of Set 11 | mount isa
# Processing Record 22 of Set 11 | arak
# Processing Record 23 of Set 11 | constantine
# Processing Record 24 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 25 of Set 11 | jieshi
# Processing Record 26 of Set 11 | trinidad
# Processing Record 27 of Set 11 | linares
# Processing Record 28 of Set 11 | half moon bay
# Processing Record 29 of Set 11 | odweyne
# Processing Record 30 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 11 | garowe
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | itacarambi
# Processing Record 34 of Set 11 | usinsk
# Processing Record 35 of Set 11 | fomboni
# Processing Record 36 of Set 11 | mazagao
# Processing Record 37 of Set 11 | christchurch
# Processing Record 38 of Set 11 | raga
# Processing Record 39 of Set 11 | omboue
# Processing Record 40 of Set 11 | saint-augustin
# Processing Record 41 of Set 11 | espanola
# Processing Record 42 of Set 11 | ende
# Processing Record 43 of Set 11 | mogocha
# Processing Record 44 of Set 11 | baghdad
# Processing Record 45 of Set 11 | smithville
# Processing Record 46 of Set 11 | handan
# Processing Record 47 of Set 11 | kalabo
# Processing Record 48 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 49 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 11 | port lincoln
# Processing Record 1 of Set 12 | havelock
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | cookshire
# City not found. Skipping...
# Processing Record 4 of Set 12 | longido
# Processing Record 5 of Set 12 | noumea
# Processing Record 6 of Set 12 | caravelas
# Processing Record 7 of Set 12 | bolshevik
# Processing Record 8 of Set 12 | taitung
# Processing Record 9 of Set 12 | jawhar
# Processing Record 10 of Set 12 | smithers
# Processing Record 11 of Set 12 | kidal
# Processing Record 12 of Set 12 | disna
# Processing Record 13 of Set 12 | posse
# Processing Record 14 of Set 12 | zaprudnya
# Processing Record 15 of Set 12 | lampazos de naranjo
# Processing Record 16 of Set 12 | mareeba
# Processing Record 17 of Set 12 | stornoway
# Processing Record 18 of Set 12 | qingdao
# Processing Record 19 of Set 12 | inverell
# Processing Record 20 of Set 12 | melnikovo
# Processing Record 21 of Set 12 | laje
# Processing Record 22 of Set 12 | kirkwall
# Processing Record 23 of Set 12 | jardim
# Processing Record 24 of Set 12 | zhigansk
# Processing Record 25 of Set 12 | mecca
# Processing Record 26 of Set 12 | sun valley
# Processing Record 27 of Set 12 | salinopolis
# Processing Record 28 of Set 12 | marienburg
# Processing Record 29 of Set 12 | hami
# Processing Record 30 of Set 12 | baykit
# Processing Record 31 of Set 12 | khromtau
# Processing Record 32 of Set 12 | marathon
# Processing Record 33 of Set 12 | linqiong
# Processing Record 34 of Set 12 | bubaque
# Processing Record 35 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 12 | beringovskiy
# Processing Record 37 of Set 12 | fenoarivo atsinanana
# Processing Record 38 of Set 12 | nekhayevskiy
# Processing Record 39 of Set 12 | milkovo
# Processing Record 40 of Set 12 | iwanai
# Processing Record 41 of Set 12 | rodrigues alves
# Processing Record 42 of Set 12 | tiznit
# Processing Record 43 of Set 12 | liverpool
# Processing Record 44 of Set 12 | abha
# Processing Record 45 of Set 12 | sao filipe
# Processing Record 46 of Set 12 | williams lake
# Processing Record 47 of Set 12 | kousseri
# Processing Record 48 of Set 12 | lypova dolyna
# Processing Record 49 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 50 of Set 12 | pamanukan
# Processing Record 1 of Set 13 | kalmunai
# Processing Record 2 of Set 13 | labuan
# Processing Record 3 of Set 13 | vilhena
# Processing Record 4 of Set 13 | xam nua
# Processing Record 5 of Set 13 | warwick
# Processing Record 6 of Set 13 | morondava
# Processing Record 7 of Set 13 | guerrero negro
# Processing Record 8 of Set 13 | husyatyn
# Processing Record 9 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 13 | bouloupari
# Processing Record 11 of Set 13 | jacareacanga
# Processing Record 12 of Set 13 | tessalit
# Processing Record 13 of Set 13 | port blair
# Processing Record 14 of Set 13 | flin flon
# Processing Record 15 of Set 13 | khandyga
# Processing Record 16 of Set 13 | avera
# Processing Record 17 of Set 13 | tuatapere
# Processing Record 18 of Set 13 | yamada
# Processing Record 19 of Set 13 | yinchuan
# Processing Record 20 of Set 13 | sayyan
# Processing Record 21 of Set 13 | banda aceh
# Processing Record 22 of Set 13 | champagnole
# Processing Record 23 of Set 13 | moron
# Processing Record 24 of Set 13 | loding
# Processing Record 25 of Set 13 | calvinia
# Processing Record 26 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 27 of Set 13 | lorengau
# Processing Record 28 of Set 13 | pervomayskiy
# Processing Record 29 of Set 13 | nabire
# Processing Record 30 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 13 | la mana
# Processing Record 32 of Set 13 | iskateley
# Processing Record 33 of Set 13 | basco
# Processing Record 34 of Set 13 | mulki
# Processing Record 35 of Set 13 | fondi
# Processing Record 36 of Set 13 | yen bai
# Processing Record 37 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 38 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 13 | alice springs
# Processing Record 40 of Set 13 | cervo
# Processing Record 41 of Set 13 | tura
# Processing Record 42 of Set 13 | port augusta
# Processing Record 43 of Set 13 | bestobe
# Processing Record 44 of Set 13 | karratha
# Processing Record 45 of Set 13 | auki
# Processing Record 46 of Set 13 | dunedin
# Processing Record 47 of Set 13 | saint-michel-des-saints
# Processing Record 48 of Set 13 | champerico
# Processing Record 49 of Set 13 | anadyr
# Processing Record 50 of Set 13 | umm lajj
# Processing Record 1 of Set 14 | camana
# Processing Record 2 of Set 14 | dwarka
# Processing Record 3 of Set 14 | asosa
# Processing Record 4 of Set 14 | vrangel
# Processing Record 5 of Set 14 | west bay
# Processing Record 6 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 7 of Set 14 | plered
# City not found. Skipping...
# Processing Record 8 of Set 14 | sergeyevka
# Processing Record 9 of Set 14 | arona
# Processing Record 10 of Set 14 | kahului
# Processing Record 11 of Set 14 | neuquen
# Processing Record 12 of Set 14 | santa barbara
# Processing Record 13 of Set 14 | cururupu
# Processing Record 14 of Set 14 | cabedelo
# Processing Record 15 of Set 14 | ciudad bolivar
# Processing Record 16 of Set 14 | varsag
# Processing Record 17 of Set 14 | knysna
# Processing Record 18 of Set 14 | tucuman
# Processing Record 19 of Set 14 | hakodate
# Processing Record 20 of Set 14 | tunceli
# Processing Record 21 of Set 14 | redlands
# Processing Record 22 of Set 14 | olmos
# Processing Record 23 of Set 14 | paka
# Processing Record 24 of Set 14 | keuruu
# Processing Record 25 of Set 14 | sibolga
# Processing Record 26 of Set 14 | sulangan
# Processing Record 27 of Set 14 | sayville
# Processing Record 28 of Set 14 | tacambaro
# City not found. Skipping...
# Processing Record 29 of Set 14 | tazmalt
# Processing Record 30 of Set 14 | balkhash
# Processing Record 31 of Set 14 | senanga
# Processing Record 32 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 14 | waipawa
# Processing Record 34 of Set 14 | virginia beach
# Processing Record 35 of Set 14 | misrikh
# Processing Record 36 of Set 14 | agirish
# Processing Record 37 of Set 14 | eureka
# Processing Record 38 of Set 14 | taft
# Processing Record 39 of Set 14 | loganville
# Processing Record 40 of Set 14 | urengoy
# Processing Record 41 of Set 14 | ponca city
# Processing Record 42 of Set 14 | narasannapeta
# Processing Record 43 of Set 14 | xuddur
# Processing Record 44 of Set 14 | hounde
# Processing Record 45 of Set 14 | port antonio
# Processing Record 46 of Set 14 | itacare
# Processing Record 47 of Set 14 | angoche
# Processing Record 48 of Set 14 | yithion
# City not found. Skipping...
# Processing Record 49 of Set 14 | manavalakurichi
# Processing Record 50 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 1 of Set 15 | gold coast
# Processing Record 2 of Set 15 | finnsnes
# Processing Record 3 of Set 15 | bayan
# Processing Record 4 of Set 15 | luanda
# Processing Record 5 of Set 15 | kawhia
# Processing Record 6 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 15 | orcopampa
# Processing Record 8 of Set 15 | mathbaria
# Processing Record 9 of Set 15 | maloy
# Processing Record 10 of Set 15 | sabha
# Processing Record 11 of Set 15 | mogadishu
# Processing Record 12 of Set 15 | biltine
# Processing Record 13 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 15 | haimen
# Processing Record 15 of Set 15 | roma
# Processing Record 16 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | ambulu
# Processing Record 18 of Set 15 | bilibino
# Processing Record 19 of Set 15 | asau
# Processing Record 20 of Set 15 | zainsk
# Processing Record 21 of Set 15 | holland
# Processing Record 22 of Set 15 | teguldet
# Processing Record 23 of Set 15 | ho
# City not found. Skipping...
# Processing Record 24 of Set 15 | mimongo
# Processing Record 25 of Set 15 | margate
# Processing Record 26 of Set 15 | kabalo
# Processing Record 27 of Set 15 | gorontalo
# Processing Record 28 of Set 15 | duverge
# Processing Record 29 of Set 15 | sinegorye
# Processing Record 30 of Set 15 | terrace bay
# Processing Record 31 of Set 15 | thunder bay
# Processing Record 32 of Set 15 | graulhet
# Processing Record 33 of Set 15 | dudinka
# Processing Record 34 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 15 | koslan
# Processing Record 36 of Set 15 | sherlovaya gora
# Processing Record 37 of Set 15 | polyarnyy
# Processing Record 38 of Set 15 | hurricane
# Processing Record 39 of Set 15 | sydney
# Processing Record 40 of Set 15 | salta
# Processing Record 41 of Set 15 | zwedru
# Processing Record 42 of Set 15 | baker city
# Processing Record 43 of Set 15 | qitaihe
# Processing Record 44 of Set 15 | ukiah
# Processing Record 45 of Set 15 | tobermory
# Processing Record 46 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 15 | tual
# Processing Record 48 of Set 15 | flinders
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(json.dumps(city_data))
# Out:
# [{"City": "Faya", "Country": "SA", "Lat": 18.3851, "Lng": 42.4509, "Max Temp F\u00b0": 64.51, "Humidity %": 71, "Cloudiness %": 10, "Wind Speed mph": 5.37, "Weather Description": "clear sky"}, {"City": "Tiksi", "Country": "RU", "Lat": 71.6872, "Lng": 128.8694, "Max Temp F\u00b0": 45.07, "Humidity %": 72, "Cloudiness %": 76, "Wind Speed mph": 10.36, "Weather Description": "broken clouds"}, {"City": "Torbay", "Country": "CA", "Lat": 47.6666, "Lng": -52.7314, "Max Temp F\u00b0": 62.58, "Humidity %": 85, "Cloudiness %": 20, "Wind Speed mph": 20.71, "Weather Description": "few clouds"}, {"City": "Saldanha", "Country": "ZA", "Lat": -33.0117, "Lng": 17.9442, "Max Temp F\u00b0": 48.25, "Humidity %": 90, "Cloudiness %": 9, "Wind Speed mph": 7.18, "Weather Description": "clear sky"}, {"City": "Atuona", "Country": "PF", "Lat": -9.8, "Lng": -139.0333, "Max Temp F\u00b0": 77.58, "Humidity %": 73, "Cloudiness %": 69, "Wind Speed mph": 15.5, "Weather Description": "light rain"}, {"City": "Port Alfred", "Country": "ZA", "Lat": -33.5906, "Lng": 26.891, "Max Temp F\u00b0": 61.93, "Humidity %": 45, "Cloudiness %": 0, "Wind Speed mph": 12.08, "Weather Description": "clear sky"}, {"City": "Longyearbyen", "Country": "SJ", "Lat": 78.2186, "Lng": 15.6401, "Max Temp F\u00b0": 46.24, "Humidity %": 66, "Cloudiness %": 40, "Wind Speed mph": 12.66, "Weather Description": "scattered clouds"}, {"City": "East London", "Country": "ZA", "Lat": -33.0153, "Lng": 27.9116, "Max Temp F\u00b0": 67.32, "Humidity %": 25, "Cloudiness %": 0, "Wind Speed mph": 10.09, "Weather Description": "clear sky"}, {"City": "Kodiak", "Country": "US", "Lat": 57.79, "Lng": -152.4072, "Max Temp F\u00b0": 62.11, "Humidity %": 72, "Cloudiness %": 90, "Wind Speed mph": 8.05, "Weather Description": "overcast clouds"}, {"City": "Sartell", "Country": "US", "Lat": 45.6216, "Lng": -94.2069, "Max Temp F\u00b0": 75.67, "Humidity %": 60, "Cloudiness %": 1, "Wind Speed mph": 4, "Weather Description": "haze"}, {"City": "Rikitea", "Country": "PF", "Lat": -23.1203, "Lng": -134.9692, "Max Temp F\u00b0": 70.16, "Humidity %": 62, "Cloudiness %": 64, "Wind Speed mph": 14.14, "Weather Description": "broken clouds"}, {"City": "Airai", "Country": "TL", "Lat": -8.9266, "Lng": 125.4092, "Max Temp F\u00b0": 75.31, "Humidity %": 41, "Cloudiness %": 100, "Wind Speed mph": 4.92, "Weather Description": "overcast clouds"}, {"City": "Santa Cruz De Tenerife", "Country": "ES", "Lat": 28.4682, "Lng": -16.2546, "Max Temp F\u00b0": 72.21, "Humidity %": 84, "Cloudiness %": 75, "Wind Speed mph": 1.01, "Weather Description": "broken clouds"}, {"City": "Iqaluit", "Country": "CA", "Lat": 63.7506, "Lng": -68.5145, "Max Temp F\u00b0": 44.33, "Humidity %": 87, "Cloudiness %": 75, "Wind Speed mph": 15.01, "Weather Description": "broken clouds"}, {"City": "Tiarei", "Country": "PF", "Lat": -17.5333, "Lng": -149.3333, "Max Temp F\u00b0": 82, "Humidity %": 78, "Cloudiness %": 15, "Wind Speed mph": 11.99, "Weather Description": "few clouds"}, {"City": "Ushuaia", "Country": "AR", "Lat": -54.8, "Lng": -68.3, "Max Temp F\u00b0": 40.66, "Humidity %": 65, "Cloudiness %": 75, "Wind Speed mph": 3.44, "Weather Description": "broken clouds"}, {"City": "Hasaki", "Country": "JP", "Lat": 35.7333, "Lng": 140.8333, "Max Temp F\u00b0": 95.29, "Humidity %": 72, "Cloudiness %": 65, "Wind Speed mph": 8.08, "Weather Description": "broken clouds"}, {"City": "Mataura", "Country": "NZ", "Lat": -46.1927, "Lng": 168.8643, "Max Temp F\u00b0": 46.47, "Humidity %": 65, "Cloudiness %": 100, "Wind Speed mph": 4.25, "Weather Description": "overcast clouds"}, {"City": "Mahebourg", "Country": "MU", "Lat": -20.4081, "Lng": 57.7, "Max Temp F\u00b0": 68.29, "Humidity %": 83, "Cloudiness %": 75, "Wind Speed mph": 8.05, "Weather Description": "broken clouds"}, {"City": "Cape Canaveral", "Country": "US", "Lat": 28.4058, "Lng": -80.6048, "Max Temp F\u00b0": 77.25, "Humidity %": 92, "Cloudiness %": 40, "Wind Speed mph": 9.22, "Weather Description": "scattered clouds"}, {"Ci ...

# %%
city_data
# Out:
# [{'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp F°': 64.51,
#   'Humidity %': 71,
#   'Cloudiness %': 10,
#   'Wind Speed mph': 5.37,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp F°': 45.07,
#   'Humidity %': 72,
#   'Cloudiness %': 76,
#   'Wind Speed mph': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp F°': 62.58,
#   'Humidity %': 85,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 20.71,
#   'Weather Description': 'few clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp F°': 48.25,
#   'Humidity %': 90,
#   'Cloudiness %': 9,
#   'Wind Speed mph': 7.18,
#   'Weather Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp F°': 77.58,
#   'Humidity %': 73,
#   'Cloudiness %': 69,
#   'Wind Speed mph': 15.5,
#   'Weather Description': 'light rain'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp F°': 61.93,
#   'Humidity %': 45,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 12.08,
#   'Weather Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp F°': 46.24,
#   'Humidity %': 66,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp F°': 67.32,
#   'Humidity %': 25,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 10.09,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp F°': 62.11,
#   'Humidity %': 72,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sartell',
#   'Country': 'US',
#   'Lat': 45.6216,
#   'Lng': -94.2069,
#   'Max Temp F°': 75.67,
#   'Humidity %': 60,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 4,
#   'Weather Description': 'haze'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp F°': 70.16,
#   'Humidity %': 62,
#   'Cloudiness %': 64,
#   'Wind Speed mph': 14.14,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp F°': 75.31,
#   'Humidity %': 41,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.92,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Santa Cruz De Tenerife',
#   'Country': 'ES',
#   'Lat': 28.4682,
#   'Lng': -16.2546,
#   'Max Temp F°': 72.21,
#   'Humidity %': 84,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp F°': 44.33,
#   'Humidity %': 87,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 15.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tiarei',
#   'Country': 'PF',
#   'Lat': -17.5333,
#   'Lng': -149.3333,
#   'Max Temp F°': 82,
#   'Humidity %': 78,
#   'Cloudiness %': 15,
#   'Wind Speed mph': 11.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp F°': 40.66,
#   'Humidity %': 65,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp F°': 95.29,
#   'Humidity %': 72,
#   'Cloudiness %': 65,
#   'Wind Speed mph': 8.08,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp F°': 46.47,
#   'Humidity %': 65,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.25,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp F°': 68.29,
#   'Humidity %': 83,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Cape Canaveral',
#   'Country': 'US',
#   'Lat': 28.4058,
#   'Lng': -80.6048,
#   'Max Temp F°': 77.25,
#   'Humidity %': 92,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mantua',
#   'Country': 'IT',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp F°': 70.84,
#   'Humidity %': 83,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 0.43,
#   'Weather Description': 'light rain'},
#  {'City': 'Totness',
#   'Country': 'SR',
#   'Lat': 5.8833,
#   'Lng': -56.3167,
#   'Max Temp F°': 76.53,
#   'Humidity %': 85,
#   'Cloudiness %': 14,
#   'Wind Speed mph': 2.59,
#   'Weather Description': 'few clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp F°': 40.08,
#   'Humidity %': 100,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 3.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Druzhnaya Gorka',
#   'Country': 'RU',
#   'Lat': 59.2761,
#   'Lng': 30.1425,
#   'Max Temp F°': 51.19,
#   'Humidity %': 96,
#   'Cloudiness %': 30,
#   'Wind Speed mph': 5.17,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp F°': 61.92,
#   'Humidity %': 89,
#   'Cloudiness %': 10,
#   'Wind Speed mph': 2.51,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp F°': 81.82,
#   'Humidity %': 75,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 7.9,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kolda',
#   'Country': 'SN',
#   'Lat': 12.8833,
#   'Lng': -14.95,
#   'Max Temp F°': 74.23,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 3.91,
#   'Weather Description': 'light rain'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp F°': 43.18,
#   'Humidity %': 94,
#   'Cloudiness %': 36,
#   'Wind Speed mph': 4.72,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Leu',
#   'Country': 'RE',
#   'Lat': -21.15,
#   'Lng': 55.2833,
#   'Max Temp F°': 65.26,
#   'Humidity %': 81,
#   'Cloudiness %': 46,
#   'Wind Speed mph': 18.52,
#   'Weather Description': 'light rain'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp F°': 57.65,
#   'Humidity %': 66,
#   'Cloudiness %': 61,
#   'Wind Speed mph': 1.74,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp F°': 49.93,
#   'Humidity %': 59,
#   'Cloudiness %': 87,
#   'Wind Speed mph': 8.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp F°': 55.13,
#   'Humidity %': 58,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp F°': 71.11,
#   'Humidity %': 91,
#   'Cloudiness %': 5,
#   'Wind Speed mph': 8.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bermejo',
#   'Country': 'AR',
#   'Lat': -32.8833,
#   'Lng': -68.8,
#   'Max Temp F°': 49.91,
#   'Humidity %': 53,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Beisfjord',
#   'Country': 'NO',
#   'Lat': 68.3751,
#   'Lng': 17.5988,
#   'Max Temp F°': 52.05,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.09,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp F°': 53.78,
#   'Humidity %': 93,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 7.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp F°': 73.56,
#   'Humidity %': 83,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 17.27,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp F°': 41.94,
#   'Humidity %': 86,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp F°': 88.63,
#   'Humidity %': 62,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 16.55,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nuristan',
#   'Country': 'AF',
#   'Lat': 35.3,
#   'Lng': 70.8333,
#   'Max Temp F°': 55.49,
#   'Humidity %': 45,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp F°': 89.42,
#   'Humidity %': 41,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.79,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp F°': 81.95,
#   'Humidity %': 74,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.32,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp F°': 45.54,
#   'Humidity %': 87,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 9.57,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp F°': 86.27,
#   'Humidity %': 79,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp F°': 72.01,
#   'Humidity %': 77,
#   'Cloudiness %': 12,
#   'Wind Speed mph': 5.26,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp F°': 48.88,
#   'Humidity %': 84,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 7.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp F°': 55.4,
#   'Humidity %': 67,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'few clouds'},
#  {'City': 'Sidi Ali',
#   'Country': 'DZ',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp F°': 69.19,
#   'Humidity %': 91,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.39,
#   'Weather Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp F°': 85.95,
#   'Humidity %': 82,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'few clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp F°': 51.82,
#   'Humidity %': 65,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 16.11,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp F°': 81.34,
#   'Humidity %': 81,
#   'Cloudiness %': 60,
#   'Wind Speed mph': 5.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp F°': 65.57,
#   'Humidity %': 82,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 0,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bemidji',
#   'Country': 'US',
#   'Lat': 47.4736,
#   'Lng': -94.8803,
#   'Max Temp F°': 75.29,
#   'Humidity %': 65,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Jacmel',
#   'Country': 'HT',
#   'Lat': 18.2342,
#   'Lng': -72.5347,
#   'Max Temp F°': 82.24,
#   'Humidity %': 82,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 3.11,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp F°': 44.76,
#   'Humidity %': 86,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.51,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kiamba',
#   'Country': 'PH',
#   'Lat': 5.9894,
#   'Lng': 124.6242,
#   'Max Temp F°': 88.16,
#   'Humidity %': 57,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 4.76,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp F°': 82.65,
#   'Humidity %': 52,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 6.02,
#   'Weather Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp F°': 56.71,
#   'Humidity %': 56,
#   'Cloudiness %': 79,
#   'Wind Speed mph': 4,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tingi',
#   'Country': 'TZ',
#   'Lat': -11.3,
#   'Lng': 35.0333,
#   'Max Temp F°': 52.74,
#   'Humidity %': 67,
#   'Cloudiness %': 22,
#   'Wind Speed mph': 3.96,
#   'Weather Description': 'few clouds'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp F°': 44.1,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.13,
#   'Weather Description': 'light rain'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp F°': 53.64,
#   'Humidity %': 94,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 2.3,
#   'Weather Description': 'smoke'},
#  {'City': 'Imbituba',
#   'Country': 'BR',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp F°': 59.83,
#   'Humidity %': 89,
#   'Cloudiness %': 92,
#   'Wind Speed mph': 7.87,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp F°': 76.37,
#   'Humidity %': 86,
#   'Cloudiness %': 70,
#   'Wind Speed mph': 7.34,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp F°': 68.25,
#   'Humidity %': 83,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp F°': 46.8,
#   'Humidity %': 62,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp F°': 74.21,
#   'Humidity %': 87,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.16,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp F°': 80.69,
#   'Humidity %': 78,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp F°': 67.6,
#   'Humidity %': 74,
#   'Cloudiness %': 43,
#   'Wind Speed mph': 11.95,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp F°': 51.91,
#   'Humidity %': 88,
#   'Cloudiness %': 34,
#   'Wind Speed mph': 5.3,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Chifeng',
#   'Country': 'CN',
#   'Lat': 42.2683,
#   'Lng': 118.9636,
#   'Max Temp F°': 81.41,
#   'Humidity %': 55,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 11.86,
#   'Weather Description': 'clear sky'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp F°': 75.6,
#   'Humidity %': 85,
#   'Cloudiness %': 78,
#   'Wind Speed mph': 14,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp F°': 42.91,
#   'Humidity %': 70,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 11.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp F°': 45.48,
#   'Humidity %': 68,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 0.2,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp F°': 56.88,
#   'Humidity %': 86,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Jingdezhen',
#   'Country': 'CN',
#   'Lat': 29.2947,
#   'Lng': 117.2079,
#   'Max Temp F°': 93.45,
#   'Humidity %': 55,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'light rain'},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp F°': 67.95,
#   'Humidity %': 29,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 9.42,
#   'Weather Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp F°': 83.44,
#   'Humidity %': 69,
#   'Cloudiness %': 78,
#   'Wind Speed mph': 12.62,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp F°': 84.18,
#   'Humidity %': 75,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 7,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp F°': 63.12,
#   'Humidity %': 42,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 5.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'George Town',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp F°': 85.93,
#   'Humidity %': 83,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp F°': 86.18,
#   'Humidity %': 65,
#   'Cloudiness %': 17,
#   'Wind Speed mph': 6.85,
#   'Weather Description': 'few clouds'},
#  {'City': 'Rubtsovsk',
#   'Country': 'RU',
#   'Lat': 51.5,
#   'Lng': 81.25,
#   'Max Temp F°': 76.26,
#   'Humidity %': 38,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 5.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp F°': 65.79,
#   'Humidity %': 86,
#   'Cloudiness %': 97,
#   'Wind Speed mph': 18.16,
#   'Weather Description': 'light rain'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp F°': 42.4,
#   'Humidity %': 95,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 1.79,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pozhva',
#   'Country': 'RU',
#   'Lat': 59.0912,
#   'Lng': 56.0847,
#   'Max Temp F°': 66.85,
#   'Humidity %': 85,
#   'Cloudiness %': 77,
#   'Wind Speed mph': 4.63,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp F°': 45.23,
#   'Humidity %': 99,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.25,
#   'Weather Description': 'light rain'},
#  {'City': 'Baft',
#   'Country': 'IR',
#   'Lat': 29.234,
#   'Lng': 56.6057,
#   'Max Temp F°': 72.68,
#   'Humidity %': 35,
#   'Cloudiness %': 42,
#   'Wind Speed mph': 3.2,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp F°': 69.06,
#   'Humidity %': 83,
#   'Cloudiness %': 35,
#   'Wind Speed mph': 6.8,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp F°': 54.91,
#   'Humidity %': 93,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 5.44,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Oxelosund',
#   'Country': 'SE',
#   'Lat': 58.6706,
#   'Lng': 17.1015,
#   'Max Temp F°': 48.58,
#   'Humidity %': 93,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Yashkul',
#   'Country': 'RU',
#   'Lat': 46.1711,
#   'Lng': 45.3435,
#   'Max Temp F°': 82.65,
#   'Humidity %': 31,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 3.65,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp F°': 81.09,
#   'Humidity %': 83,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp F°': 75.09,
#   'Humidity %': 64,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Atambua',
#   'Country': 'ID',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp F°': 84.6,
#   'Humidity %': 47,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.25,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp F°': 60.87,
#   'Humidity %': 94,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 14.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp F°': 102.79,
#   'Humidity %': 14,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 5.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nichinan',
#   'Country': 'JP',
#   'Lat': 31.6,
#   'Lng': 131.3667,
#   'Max Temp F°': 87.48,
#   'Humidity %': 77,
#   'Cloudiness %': 94,
#   'Wind Speed mph': 9.69,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp F°': 51.91,
#   'Humidity %': 82,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 8.95,
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Bethanien',
#   'Country': 'NA',
#   'Lat': -26.502,
#   'Lng': 17.1583,
#   'Max Temp F°': 56.25,
#   'Humidity %': 43,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 4.09,
#   'Weather Description': 'clear sky'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp F°': 64.45,
#   'Humidity %': 84,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.62,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp F°': 52.02,
#   'Humidity %': 94,
#   'Cloudiness %': 13,
#   'Wind Speed mph': 5.41,
#   'Weather Description': 'few clouds'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp F°': 55.31,
#   'Humidity %': 88,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 14.97,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Santa Fe',
#   'Country': 'AR',
#   'Lat': -31.6333,
#   'Lng': -60.7,
#   'Max Temp F°': 55.99,
#   'Humidity %': 63,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp F°': 40.62,
#   'Humidity %': 89,
#   'Cloudiness %': 19,
#   'Wind Speed mph': 10.38,
#   'Weather Description': 'few clouds'},
#  {'City': 'Euclides Da Cunha',
#   'Country': 'BR',
#   'Lat': -10.5075,
#   'Lng': -39.0158,
#   'Max Temp F°': 61.09,
#   'Humidity %': 92,
#   'Cloudiness %': 76,
#   'Wind Speed mph': 4.65,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Abu Dhabi',
#   'Country': 'AE',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp F°': 89.71,
#   'Humidity %': 66,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Paamiut',
#   'Country': 'GL',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp F°': 45.52,
#   'Humidity %': 95,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'light rain'},
#  {'City': 'Malavalli',
#   'Country': 'IN',
#   'Lat': 12.3833,
#   'Lng': 77.0833,
#   'Max Temp F°': 73.26,
#   'Humidity %': 68,
#   'Cloudiness %': 83,
#   'Wind Speed mph': 15.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Chase',
#   'Country': 'CA',
#   'Lat': 50.8165,
#   'Lng': -119.6857,
#   'Max Temp F°': 84.4,
#   'Humidity %': 30,
#   'Cloudiness %': 7,
#   'Wind Speed mph': 3.98,
#   'Weather Description': 'clear sky'},
#  {'City': 'Svetlaya',
#   'Country': 'RU',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp F°': 66.13,
#   'Humidity %': 91,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.82,
#   'Weather Description': 'light rain'},
#  {'City': 'Kabinda',
#   'Country': 'CD',
#   'Lat': -6.1333,
#   'Lng': 24.4833,
#   'Max Temp F°': 65.89,
#   'Humidity %': 43,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.74,
#   'Weather Description': 'clear sky'},
#  {'City': 'Janovice Nad Uhlavou',
#   'Country': 'CZ',
#   'Lat': 49.3451,
#   'Lng': 13.2181,
#   'Max Temp F°': 58.69,
#   'Humidity %': 93,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.35,
#   'Weather Description': 'light rain'},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp F°': 73.65,
#   'Humidity %': 83,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 7.14,
#   'Weather Description': 'few clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp F°': 52.92,
#   'Humidity %': 87,
#   'Cloudiness %': 36,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp F°': 57.04,
#   'Humidity %': 71,
#   'Cloudiness %': 91,
#   'Wind Speed mph': 4.88,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sfantu Gheorghe',
#   'Country': 'RO',
#   'Lat': 45.8667,
#   'Lng': 25.7833,
#   'Max Temp F°': 65.26,
#   'Humidity %': 83,
#   'Cloudiness %': 5,
#   'Wind Speed mph': 2.51,
#   'Weather Description': 'clear sky'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp F°': 57.47,
#   'Humidity %': 31,
#   'Cloudiness %': 29,
#   'Wind Speed mph': 13.29,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp F°': 44.62,
#   'Humidity %': 81,
#   'Cloudiness %': 44,
#   'Wind Speed mph': 0,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Kidodi',
#   'Country': 'TZ',
#   'Lat': -7.6036,
#   'Lng': 37.0044,
#   'Max Temp F°': 64.49,
#   'Humidity %': 93,
#   'Cloudiness %': 26,
#   'Wind Speed mph': 1.21,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp F°': 67.5,
#   'Humidity %': 83,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp F°': 77.05,
#   'Humidity %': 69,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp F°': 57.11,
#   'Humidity %': 94,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.51,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp F°': 57,
#   'Humidity %': 63,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 6.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sistranda',
#   'Country': 'NO',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp F°': 49.89,
#   'Humidity %': 70,
#   'Cloudiness %': 81,
#   'Wind Speed mph': 4.63,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kenai',
#   'Country': 'US',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp F°': 66.02,
#   'Humidity %': 76,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sambava',
#   'Country': 'MG',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp F°': 67.5,
#   'Humidity %': 84,
#   'Cloudiness %': 7,
#   'Wind Speed mph': 11.72,
#   'Weather Description': 'clear sky'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp F°': 76.08,
#   'Humidity %': 44,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pyapon',
#   'Country': 'MM',
#   'Lat': 16.2833,
#   'Lng': 95.6833,
#   'Max Temp F°': 79.52,
#   'Humidity %': 87,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 9.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tirat Karmel',
#   'Country': 'IL',
#   'Lat': 32.7617,
#   'Lng': 34.9719,
#   'Max Temp F°': 76.95,
#   'Humidity %': 70,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp F°': 57.92,
#   'Humidity %': 72,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Trincomalee',
#   'Country': 'LK',
#   'Lat': 8.5711,
#   'Lng': 81.2335,
#   'Max Temp F°': 83.44,
#   'Humidity %': 71,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 20.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp F°': 75.38,
#   'Humidity %': 98,
#   'Cloudiness %': 95,
#   'Wind Speed mph': 4.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yershichi',
#   'Country': 'RU',
#   'Lat': 53.6725,
#   'Lng': 32.7542,
#   'Max Temp F°': 52.84,
#   'Humidity %': 86,
#   'Cloudiness %': 7,
#   'Wind Speed mph': 3.15,
#   'Weather Description': 'clear sky'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp F°': 101.93,
#   'Humidity %': 16,
#   'Cloudiness %': 62,
#   'Wind Speed mph': 6.73,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ambon',
#   'Country': 'ID',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp F°': 75.34,
#   'Humidity %': 100,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'heavy intensity rain'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp F°': 45.77,
#   'Humidity %': 87,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 21.88,
#   'Weather Description': 'light rain'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp F°': 78.24,
#   'Humidity %': 83,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 0,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Sharjah',
#   'Country': 'AE',
#   'Lat': 25.3573,
#   'Lng': 55.4033,
#   'Max Temp F°': 93.18,
#   'Humidity %': 53,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp F°': 48.22,
#   'Humidity %': 56,
#   'Cloudiness %': 94,
#   'Wind Speed mph': 7.11,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp F°': 49.12,
#   'Humidity %': 100,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'heavy intensity drizzle'},
#  {'City': 'Angoram',
#   'Country': 'PG',
#   'Lat': -4.0625,
#   'Lng': 144.0661,
#   'Max Temp F°': 92.82,
#   'Humidity %': 50,
#   'Cloudiness %': 18,
#   'Wind Speed mph': 2.57,
#   'Weather Description': 'few clouds'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp F°': 78.96,
#   'Humidity %': 44,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'smoke'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp F°': 85.08,
#   'Humidity %': 69,
#   'Cloudiness %': 12,
#   'Wind Speed mph': 3.49,
#   'Weather Description': 'few clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp F°': 62.69,
#   'Humidity %': 88,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp F°': 49.73,
#   'Humidity %': 93,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 2.3,
#   'Weather Description': 'few clouds'},
#  {'City': 'Soyo',
#   'Country': 'AO',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp F°': 71.35,
#   'Humidity %': 94,
#   'Cloudiness %': 29,
#   'Wind Speed mph': 7.76,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Jinsha',
#   'Country': 'CN',
#   'Lat': 32.0898,
#   'Lng': 121.0735,
#   'Max Temp F°': 90,
#   'Humidity %': 63,
#   'Cloudiness %': 52,
#   'Wind Speed mph': 13.31,
#   'Weather Description': 'light rain'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp F°': 88.52,
#   'Humidity %': 77,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 11.01,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Nueve De Julio',
#   'Country': 'AR',
#   'Lat': -35.4444,
#   'Lng': -60.8831,
#   'Max Temp F°': 48.7,
#   'Humidity %': 64,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 7.45,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp F°': 82.74,
#   'Humidity %': 89,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Country': 'AR',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp F°': 46.26,
#   'Humidity %': 39,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Truth Or Consequences',
#   'Country': 'US',
#   'Lat': 33.1284,
#   'Lng': -107.2528,
#   'Max Temp F°': 89.83,
#   'Humidity %': 30,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 13.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ancud',
#   'Country': 'CL',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp F°': 40.42,
#   'Humidity %': 72,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 5.73,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Tromso',
#   'Country': 'NO',
#   'Lat': 69.6496,
#   'Lng': 18.957,
#   'Max Temp F°': 47.05,
#   'Humidity %': 87,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Shemysheyka',
#   'Country': 'RU',
#   'Lat': 52.892,
#   'Lng': 45.3928,
#   'Max Temp F°': 64.33,
#   'Humidity %': 96,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.48,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Peniche',
#   'Country': 'PT',
#   'Lat': 39.3558,
#   'Lng': -9.3811,
#   'Max Temp F°': 67.62,
#   'Humidity %': 93,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.46,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp F°': 57.76,
#   'Humidity %': 89,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 1.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp F°': 57.04,
#   'Humidity %': 41,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 13.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp F°': 53.69,
#   'Humidity %': 54,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 11.63,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Prainha',
#   'Country': 'BR',
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp F°': 74.62,
#   'Humidity %': 69,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 2.13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kedrovyy',
#   'Country': 'RU',
#   'Lat': 56.1667,
#   'Lng': 91.8167,
#   'Max Temp F°': 61.21,
#   'Humidity %': 80,
#   'Cloudiness %': 97,
#   'Wind Speed mph': 1.88,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Minot',
#   'Country': 'US',
#   'Lat': 48.2325,
#   'Lng': -101.2963,
#   'Max Temp F°': 84.42,
#   'Humidity %': 28,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'smoke'},
#  {'City': 'Sabang',
#   'Country': 'ID',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp F°': 82.99,
#   'Humidity %': 73,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 22.26,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dawson',
#   'Country': 'US',
#   'Lat': 31.7735,
#   'Lng': -84.4466,
#   'Max Temp F°': 80.02,
#   'Humidity %': 86,
#   'Cloudiness %': 5,
#   'Wind Speed mph': 6.17,
#   'Weather Description': 'clear sky'},
#  {'City': 'Moyale',
#   'Country': 'KE',
#   'Lat': 3.5167,
#   'Lng': 39.0584,
#   'Max Temp F°': 64.22,
#   'Humidity %': 67,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 12.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Orlik',
#   'Country': 'RU',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp F°': 65.08,
#   'Humidity %': 49,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 1.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp F°': 80.64,
#   'Humidity %': 76,
#   'Cloudiness %': 87,
#   'Wind Speed mph': 9.98,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pierre',
#   'Country': 'US',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp F°': 80.85,
#   'Humidity %': 50,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 7,
#   'Weather Description': 'clear sky'},
#  {'City': 'Qandala',
#   'Country': 'SO',
#   'Lat': 11.472,
#   'Lng': 49.8728,
#   'Max Temp F°': 87.28,
#   'Humidity %': 48,
#   'Cloudiness %': 64,
#   'Wind Speed mph': 11.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Puqi',
#   'Country': 'CN',
#   'Lat': 29.7167,
#   'Lng': 113.8833,
#   'Max Temp F°': 90.7,
#   'Humidity %': 62,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 9.4,
#   'Weather Description': 'clear sky'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp F°': 82.85,
#   'Humidity %': 14,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 7.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp F°': 64.35,
#   'Humidity %': 94,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Rabat',
#   'Country': 'MA',
#   'Lat': 33.9911,
#   'Lng': -6.8401,
#   'Max Temp F°': 71.01,
#   'Humidity %': 93,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 0,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp F°': 77.54,
#   'Humidity %': 94,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Aksarka',
#   'Country': 'RU',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp F°': 63.16,
#   'Humidity %': 64,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 4.94,
#   'Weather Description': 'clear sky'},
#  {'City': 'Placido De Castro',
#   'Country': 'BR',
#   'Lat': -10.3353,
#   'Lng': -67.1856,
#   'Max Temp F°': 71.1,
#   'Humidity %': 44,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 2.82,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Jose',
#   'Country': 'US',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp F°': 91.26,
#   'Humidity %': 43,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 4,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp F°': 71.71,
#   'Humidity %': 91,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'light rain'},
#  {'City': 'Kyaikkami',
#   'Country': 'MM',
#   'Lat': 16.08,
#   'Lng': 97.5675,
#   'Max Temp F°': 80.56,
#   'Humidity %': 86,
#   'Cloudiness %': 96,
#   'Wind Speed mph': 10.4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp F°': 63.55,
#   'Humidity %': 64,
#   'Cloudiness %': 60,
#   'Wind Speed mph': 1.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp F°': 53.73,
#   'Humidity %': 83,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.53,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp F°': 47.66,
#   'Humidity %': 89,
#   'Cloudiness %': 54,
#   'Wind Speed mph': 4.38,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Iranshahr',
#   'Country': 'IR',
#   'Lat': 27.2025,
#   'Lng': 60.6848,
#   'Max Temp F°': 89.94,
#   'Humidity %': 31,
#   'Cloudiness %': 4,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pozo Colorado',
#   'Country': 'PY',
#   'Lat': -23.4923,
#   'Lng': -58.7972,
#   'Max Temp F°': 56.64,
#   'Humidity %': 42,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Turukhansk',
#   'Country': 'RU',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp F°': 69.01,
#   'Humidity %': 63,
#   'Cloudiness %': 12,
#   'Wind Speed mph': 8.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp F°': 64.47,
#   'Humidity %': 33,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 14.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Dakar',
#   'Country': 'SN',
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Max Temp F°': 78.93,
#   'Humidity %': 94,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp F°': 72.5,
#   'Humidity %': 83,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 15.39,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Qasigiannguit',
#   'Country': 'GL',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp F°': 44.85,
#   'Humidity %': 89,
#   'Cloudiness %': 76,
#   'Wind Speed mph': 1.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Fuerte Olimpo',
#   'Country': 'PY',
#   'Lat': -21.0415,
#   'Lng': -57.8738,
#   'Max Temp F°': 65.57,
#   'Humidity %': 32,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 5.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yuncheng',
#   'Country': 'CN',
#   'Lat': 35.0231,
#   'Lng': 110.9928,
#   'Max Temp F°': 86.45,
#   'Humidity %': 55,
#   'Cloudiness %': 77,
#   'Wind Speed mph': 2.55,
#   'Weather Description': 'light rain'},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp F°': 67.28,
#   'Humidity %': 95,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 1.25,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp F°': 53.37,
#   'Humidity %': 91,
#   'Cloudiness %': 95,
#   'Wind Speed mph': 8.32,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nanakuli',
#   'Country': 'US',
#   'Lat': 21.3906,
#   'Lng': -158.1547,
#   'Max Temp F°': 87.75,
#   'Humidity %': 45,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'few clouds'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp F°': 79.18,
#   'Humidity %': 78,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'smoke'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp F°': 85.08,
#   'Humidity %': 64,
#   'Cloudiness %': 8,
#   'Wind Speed mph': 3.56,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp F°': 57.06,
#   'Humidity %': 56,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Anchorage',
#   'Country': 'US',
#   'Lat': 61.2181,
#   'Lng': -149.9003,
#   'Max Temp F°': 71.2,
#   'Humidity %': 75,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Idrinskoye',
#   'Country': 'RU',
#   'Lat': 54.3708,
#   'Lng': 92.1358,
#   'Max Temp F°': 70.14,
#   'Humidity %': 74,
#   'Cloudiness %': 26,
#   'Wind Speed mph': 3.76,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Moosomin',
#   'Country': 'CA',
#   'Lat': 50.1333,
#   'Lng': -101.6677,
#   'Max Temp F°': 73.47,
#   'Humidity %': 47,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.93,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mulege',
#   'Country': 'MX',
#   'Lat': 26.8833,
#   'Lng': -111.9833,
#   'Max Temp F°': 90.28,
#   'Humidity %': 54,
#   'Cloudiness %': 13,
#   'Wind Speed mph': 3.13,
#   'Weather Description': 'few clouds'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp F°': 48.4,
#   'Humidity %': 96,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 35.14,
#   'Weather Description': 'light rain'},
#  {'City': 'Beidao',
#   'Country': 'CN',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp F°': 76.5,
#   'Humidity %': 57,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 3.38,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Panama City',
#   'Country': 'PA',
#   'Lat': 8.9936,
#   'Lng': -79.5197,
#   'Max Temp F°': 80.06,
#   'Humidity %': 92,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp F°': 57.67,
#   'Humidity %': 79,
#   'Cloudiness %': 34,
#   'Wind Speed mph': 2.55,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Verkhoyansk',
#   'Country': 'RU',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp F°': 72.23,
#   'Humidity %': 23,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 11.18,
#   'Weather Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp F°': 44.65,
#   'Humidity %': 49,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 18.41,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Jackson',
#   'Country': 'US',
#   'Lat': 42.4165,
#   'Lng': -122.8345,
#   'Max Temp F°': 93.07,
#   'Humidity %': 31,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'smoke'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp F°': 89.96,
#   'Humidity %': 77,
#   'Cloudiness %': 80,
#   'Wind Speed mph': 5.01,
#   'Weather Description': 'light rain'},
#  {'City': 'Batagay-Alyta',
#   'Country': 'RU',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp F°': 71.35,
#   'Humidity %': 28,
#   'Cloudiness %': 4,
#   'Wind Speed mph': 13.85,
#   'Weather Description': 'clear sky'},
#  {'City': 'Alta Floresta',
#   'Country': 'BR',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp F°': 70.48,
#   'Humidity %': 40,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 3.87,
#   'Weather Description': 'clear sky'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp F°': 37.63,
#   'Humidity %': 93,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 10.36,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp F°': 71.56,
#   'Humidity %': 82,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kramat',
#   'Country': 'ID',
#   'Lat': -8.1311,
#   'Lng': 113.4499,
#   'Max Temp F°': 85.48,
#   'Humidity %': 63,
#   'Cloudiness %': 38,
#   'Wind Speed mph': 3.74,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Saint-Nazaire',
#   'Country': 'FR',
#   'Lat': 47.2833,
#   'Lng': -2.2,
#   'Max Temp F°': 61.07,
#   'Humidity %': 99,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 14.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Puerto Del Rosario',
#   'Country': 'ES',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp F°': 71.35,
#   'Humidity %': 68,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 14.97,
#   'Weather Description': 'clear sky'},
#  {'City': 'Staryy Nadym',
#   'Country': 'RU',
#   'Lat': 65.6118,
#   'Lng': 72.6842,
#   'Max Temp F°': 63.12,
#   'Humidity %': 67,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 12.88,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp F°': 80.53,
#   'Humidity %': 73,
#   'Cloudiness %': 51,
#   'Wind Speed mph': 8.9,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Krutinka',
#   'Country': 'RU',
#   'Lat': 56.0055,
#   'Lng': 71.5113,
#   'Max Temp F°': 59.92,
#   'Humidity %': 86,
#   'Cloudiness %': 32,
#   'Wind Speed mph': 8.01,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp F°': 54.07,
#   'Humidity %': 69,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 18.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Baton Rouge',
#   'Country': 'US',
#   'Lat': 30.4508,
#   'Lng': -91.1545,
#   'Max Temp F°': 78.93,
#   'Humidity %': 87,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nishihara',
#   'Country': 'JP',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp F°': 87.08,
#   'Humidity %': 85,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 13.8,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Gondal',
#   'Country': 'IN',
#   'Lat': 21.9667,
#   'Lng': 70.8,
#   'Max Temp F°': 86.02,
#   'Humidity %': 82,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 16.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Niamey',
#   'Country': 'NE',
#   'Lat': 13.5137,
#   'Lng': 2.1098,
#   'Max Temp F°': 77.29,
#   'Humidity %': 83,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ilo',
#   'Country': 'PE',
#   'Lat': -17.6394,
#   'Lng': -71.3375,
#   'Max Temp F°': 62.64,
#   'Humidity %': 79,
#   'Cloudiness %': 80,
#   'Wind Speed mph': 5.26,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Chibuto',
#   'Country': 'MZ',
#   'Lat': -24.6867,
#   'Lng': 33.5306,
#   'Max Temp F°': 54.79,
#   'Humidity %': 84,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.09,
#   'Weather Description': 'clear sky'},
#  {'City': 'Puerto Madryn',
#   'Country': 'AR',
#   'Lat': -42.7692,
# ...
#   'Country': 'BR',
#   'Lat': -1.8283,
#   'Lng': -44.8683,
#   'Max Temp F°': 72.09,
#   'Humidity %': 85,
#   'Cloudiness %': 34,
#   'Wind Speed mph': 1.19,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Cabedelo',
#   'Country': 'BR',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp F°': 74.07,
#   'Humidity %': 87,
#   'Cloudiness %': 21,
#   'Wind Speed mph': 12.21,
#   'Weather Description': 'few clouds'},
#  {'City': 'Ciudad Bolivar',
#   'Country': 'VE',
#   'Lat': 8.1222,
#   'Lng': -63.5497,
#   'Max Temp F°': 74.93,
#   'Humidity %': 88,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.92,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Varsag',
#   'Country': 'RO',
#   'Lat': 46.5167,
#   'Lng': 25.35,
#   'Max Temp F°': 51.06,
#   'Humidity %': 79,
#   'Cloudiness %': 37,
#   'Wind Speed mph': 4,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Knysna',
#   'Country': 'ZA',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp F°': 52.18,
#   'Humidity %': 83,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 4.79,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tucuman',
#   'Country': 'AR',
#   'Lat': -26.8241,
#   'Lng': -65.2226,
#   'Max Temp F°': 51.8,
#   'Humidity %': 71,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'smoke'},
#  {'City': 'Hakodate',
#   'Country': 'JP',
#   'Lat': 41.7758,
#   'Lng': 140.7367,
#   'Max Temp F°': 79.11,
#   'Humidity %': 89,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 2.3,
#   'Weather Description': 'light rain'},
#  {'City': 'Tunceli',
#   'Country': 'TR',
#   'Lat': 39.1083,
#   'Lng': 39.5471,
#   'Max Temp F°': 76.06,
#   'Humidity %': 50,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 6.24,
#   'Weather Description': 'clear sky'},
#  {'City': 'Redlands',
#   'Country': 'US',
#   'Lat': 34.0556,
#   'Lng': -117.1825,
#   'Max Temp F°': 101.66,
#   'Humidity %': 28,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Olmos',
#   'Country': 'PE',
#   'Lat': -5.9847,
#   'Lng': -79.7453,
#   'Max Temp F°': 60.91,
#   'Humidity %': 80,
#   'Cloudiness %': 36,
#   'Wind Speed mph': 2.57,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Paka',
#   'Country': 'MY',
#   'Lat': 4.6374,
#   'Lng': 103.4368,
#   'Max Temp F°': 82.33,
#   'Humidity %': 83,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 1.14,
#   'Weather Description': 'few clouds'},
#  {'City': 'Keuruu',
#   'Country': 'FI',
#   'Lat': 62.2667,
#   'Lng': 24.7,
#   'Max Temp F°': 48.38,
#   'Humidity %': 84,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 5.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp F°': 84.16,
#   'Humidity %': 67,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 2.64,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sulangan',
#   'Country': 'PH',
#   'Lat': 11.1373,
#   'Lng': 123.7228,
#   'Max Temp F°': 85.12,
#   'Humidity %': 70,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 14.76,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sayville',
#   'Country': 'US',
#   'Lat': 40.7359,
#   'Lng': -73.0821,
#   'Max Temp F°': 71.78,
#   'Humidity %': 86,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 0,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Tazmalt',
#   'Country': 'DZ',
#   'Lat': 36.3868,
#   'Lng': 4.3989,
#   'Max Temp F°': 73.33,
#   'Humidity %': 92,
#   'Cloudiness %': 48,
#   'Wind Speed mph': 2.53,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Balkhash',
#   'Country': 'KZ',
#   'Lat': 46.844,
#   'Lng': 74.9804,
#   'Max Temp F°': 77.61,
#   'Humidity %': 29,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 22.37,
#   'Weather Description': 'clear sky'},
#  {'City': 'Senanga',
#   'Country': 'ZM',
#   'Lat': -16.1167,
#   'Lng': 23.2667,
#   'Max Temp F°': 50.49,
#   'Humidity %': 45,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Waipawa',
#   'Country': 'NZ',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp F°': 49.3,
#   'Humidity %': 63,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 9.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Virginia Beach',
#   'Country': 'US',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Max Temp F°': 73.45,
#   'Humidity %': 86,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'light rain'},
#  {'City': 'Misrikh',
#   'Country': 'IN',
#   'Lat': 27.45,
#   'Lng': 80.5167,
#   'Max Temp F°': 83.79,
#   'Humidity %': 71,
#   'Cloudiness %': 17,
#   'Wind Speed mph': 9.08,
#   'Weather Description': 'few clouds'},
#  {'City': 'Agirish',
#   'Country': 'RU',
#   'Lat': 61.9247,
#   'Lng': 63.0231,
#   'Max Temp F°': 68.22,
#   'Humidity %': 59,
#   'Cloudiness %': 80,
#   'Wind Speed mph': 5.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Eureka',
#   'Country': 'US',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp F°': 58.19,
#   'Humidity %': 88,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Taft',
#   'Country': 'IR',
#   'Lat': 31.7471,
#   'Lng': 54.2088,
#   'Max Temp F°': 76.95,
#   'Humidity %': 18,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Loganville',
#   'Country': 'US',
#   'Lat': 33.839,
#   'Lng': -83.9007,
#   'Max Temp F°': 72.68,
#   'Humidity %': 94,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Urengoy',
#   'Country': 'RU',
#   'Lat': 65.9667,
#   'Lng': 78.3667,
#   'Max Temp F°': 64.98,
#   'Humidity %': 76,
#   'Cloudiness %': 89,
#   'Wind Speed mph': 7.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ponca City',
#   'Country': 'US',
#   'Lat': 36.707,
#   'Lng': -97.0856,
#   'Max Temp F°': 75.69,
#   'Humidity %': 60,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 8.52,
#   'Weather Description': 'clear sky'},
#  {'City': 'Narasannapeta',
#   'Country': 'IN',
#   'Lat': 18.4167,
#   'Lng': 84.05,
#   'Max Temp F°': 87.89,
#   'Humidity %': 59,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 6.64,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Xuddur',
#   'Country': 'SO',
#   'Lat': 4.1213,
#   'Lng': 43.8894,
#   'Max Temp F°': 69.48,
#   'Humidity %': 83,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 16.31,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hounde',
#   'Country': 'BF',
#   'Lat': 11.5,
#   'Lng': -3.5167,
#   'Max Temp F°': 71.46,
#   'Humidity %': 82,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 4.34,
#   'Weather Description': 'light rain'},
#  {'City': 'Port Antonio',
#   'Country': 'JM',
#   'Lat': 18.18,
#   'Lng': -76.4612,
#   'Max Temp F°': 82.31,
#   'Humidity %': 84,
#   'Cloudiness %': 39,
#   'Wind Speed mph': 7.9,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Itacare',
#   'Country': 'BR',
#   'Lat': -14.2775,
#   'Lng': -38.9967,
#   'Max Temp F°': 68.32,
#   'Humidity %': 87,
#   'Cloudiness %': 52,
#   'Wind Speed mph': 8.48,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Angoche',
#   'Country': 'MZ',
#   'Lat': -16.2325,
#   'Lng': 39.9086,
#   'Max Temp F°': 66.34,
#   'Humidity %': 88,
#   'Cloudiness %': 7,
#   'Wind Speed mph': 7.2,
#   'Weather Description': 'clear sky'},
#  {'City': 'Manavalakurichi',
#   'Country': 'IN',
#   'Lat': 8.1333,
#   'Lng': 77.3,
#   'Max Temp F°': 82.49,
#   'Humidity %': 74,
#   'Cloudiness %': 97,
#   'Wind Speed mph': 15.52,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gold Coast',
#   'Country': 'AU',
#   'Lat': -28,
#   'Lng': 153.4333,
#   'Max Temp F°': 71.2,
#   'Humidity %': 38,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Finnsnes',
#   'Country': 'NO',
#   'Lat': 69.2296,
#   'Lng': 17.9811,
#   'Max Temp F°': 47.01,
#   'Humidity %': 89,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 3.58,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bayan',
#   'Country': 'CN',
#   'Lat': 46.0833,
#   'Lng': 127.4,
#   'Max Temp F°': 69.42,
#   'Humidity %': 85,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Luanda',
#   'Country': 'AO',
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp F°': 68.77,
#   'Humidity %': 91,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 6.67,
#   'Weather Description': 'few clouds'},
#  {'City': 'Kawhia',
#   'Country': 'NZ',
#   'Lat': -38.0651,
#   'Lng': 174.8183,
#   'Max Temp F°': 59.38,
#   'Humidity %': 62,
#   'Cloudiness %': 65,
#   'Wind Speed mph': 7.02,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Orcopampa',
#   'Country': 'PE',
#   'Lat': -15.2661,
#   'Lng': -72.3417,
#   'Max Temp F°': 42.4,
#   'Humidity %': 72,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.68,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mathbaria',
#   'Country': 'BD',
#   'Lat': 22.2876,
#   'Lng': 89.9593,
#   'Max Temp F°': 83.64,
#   'Humidity %': 79,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.03,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Maloy',
#   'Country': 'NO',
#   'Lat': 61.9353,
#   'Lng': 5.1136,
#   'Max Temp F°': 52.05,
#   'Humidity %': 84,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 7.11,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sabha',
#   'Country': 'LY',
#   'Lat': 27.0377,
#   'Lng': 14.4283,
#   'Max Temp F°': 85.24,
#   'Humidity %': 22,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 11.39,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mogadishu',
#   'Country': 'SO',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp F°': 75.92,
#   'Humidity %': 87,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 14.47,
#   'Weather Description': 'light rain'},
#  {'City': 'Biltine',
#   'Country': 'TD',
#   'Lat': 14.5333,
#   'Lng': 20.9167,
#   'Max Temp F°': 75.61,
#   'Humidity %': 75,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 11.52,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Haimen',
#   'Country': 'CN',
#   'Lat': 23.1935,
#   'Lng': 116.6142,
#   'Max Temp F°': 87.69,
#   'Humidity %': 79,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 10.87,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Roma',
#   'Country': 'US',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp F°': 65.43,
#   'Humidity %': 83,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ambulu',
#   'Country': 'ID',
#   'Lat': -8.345,
#   'Lng': 113.6058,
#   'Max Temp F°': 83.84,
#   'Humidity %': 68,
#   'Cloudiness %': 38,
#   'Wind Speed mph': 6.71,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp F°': 37.27,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.04,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp F°': 60.4,
#   'Humidity %': 96,
#   'Cloudiness %': 13,
#   'Wind Speed mph': 2.89,
#   'Weather Description': 'few clouds'},
#  {'City': 'Zainsk',
#   'Country': 'RU',
#   'Lat': 55.3195,
#   'Lng': 52.0694,
#   'Max Temp F°': 70.79,
#   'Humidity %': 64,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 5.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Holland',
#   'Country': 'US',
#   'Lat': 42.7875,
#   'Lng': -86.1089,
#   'Max Temp F°': 68.79,
#   'Humidity %': 65,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Teguldet',
#   'Country': 'RU',
#   'Lat': 57.3064,
#   'Lng': 88.1667,
#   'Max Temp F°': 70.21,
#   'Humidity %': 68,
#   'Cloudiness %': 60,
#   'Wind Speed mph': 3.78,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mimongo',
#   'Country': 'GA',
#   'Lat': -1.6195,
#   'Lng': 11.6068,
#   'Max Temp F°': 68.14,
#   'Humidity %': 96,
#   'Cloudiness %': 55,
#   'Wind Speed mph': 2.89,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp F°': 55.31,
#   'Humidity %': 74,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 3.78,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kabalo',
#   'Country': 'CD',
#   'Lat': -6.05,
#   'Lng': 26.9167,
#   'Max Temp F°': 72.63,
#   'Humidity %': 42,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Gorontalo',
#   'Country': 'ID',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp F°': 89.01,
#   'Humidity %': 59,
#   'Cloudiness %': 66,
#   'Wind Speed mph': 7.25,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Duverge',
#   'Country': 'DO',
#   'Lat': 18.3784,
#   'Lng': -71.5247,
#   'Max Temp F°': 76.51,
#   'Humidity %': 92,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 0.4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sinegorye',
#   'Country': 'RU',
#   'Lat': 62.0788,
#   'Lng': 150.477,
#   'Max Temp F°': 52.27,
#   'Humidity %': 43,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 16.46,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Terrace Bay',
#   'Country': 'CA',
#   'Lat': 48.7834,
#   'Lng': -87.1,
#   'Max Temp F°': 62.22,
#   'Humidity %': 89,
#   'Cloudiness %': 33,
#   'Wind Speed mph': 1.63,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Thunder Bay',
#   'Country': 'CA',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp F°': 68.29,
#   'Humidity %': 80,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'smoke'},
#  {'City': 'Graulhet',
#   'Country': 'FR',
#   'Lat': 43.7669,
#   'Lng': 1.9894,
#   'Max Temp F°': 65.82,
#   'Humidity %': 96,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 0.94,
#   'Weather Description': 'light rain'},
#  {'City': 'Dudinka',
#   'Country': 'RU',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp F°': 70.65,
#   'Humidity %': 58,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 9.57,
#   'Weather Description': 'clear sky'},
#  {'City': 'Koslan',
#   'Country': 'RU',
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp F°': 59.2,
#   'Humidity %': 92,
#   'Cloudiness %': 95,
#   'Wind Speed mph': 4.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sherlovaya Gora',
#   'Country': 'RU',
#   'Lat': 50.5667,
#   'Lng': 116.25,
#   'Max Temp F°': 69.22,
#   'Humidity %': 59,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.53,
#   'Weather Description': 'light rain'},
#  {'City': 'Polyarnyy',
#   'Country': 'RU',
#   'Lat': 69.1989,
#   'Lng': 33.4478,
#   'Max Temp F°': 48.67,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 15.9,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hurricane',
#   'Country': 'US',
#   'Lat': 37.1753,
#   'Lng': -113.2899,
#   'Max Temp F°': 100.87,
#   'Humidity %': 24,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 10.04,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sydney',
#   'Country': 'AU',
#   'Lat': -33.8679,
#   'Lng': 151.2073,
#   'Max Temp F°': 61.56,
#   'Humidity %': 39,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Salta',
#   'Country': 'AR',
#   'Lat': -24.7859,
#   'Lng': -65.4117,
#   'Max Temp F°': 55.99,
#   'Humidity %': 53,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'clear sky'},
#  {'City': 'Zwedru',
#   'Country': 'LR',
#   'Lat': 6.0667,
#   'Lng': -8.1281,
#   'Max Temp F°': 68.72,
#   'Humidity %': 97,
#   'Cloudiness %': 44,
#   'Wind Speed mph': 2.95,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Baker City',
#   'Country': 'US',
#   'Lat': 44.7749,
#   'Lng': -117.8344,
#   'Max Temp F°': 85.71,
#   'Humidity %': 28,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 24.16,
#   'Weather Description': 'light rain'},
#  {'City': 'Qitaihe',
#   'Country': 'CN',
#   'Lat': 45.8,
#   'Lng': 130.85,
#   'Max Temp F°': 87.12,
#   'Humidity %': 42,
#   'Cloudiness %': 64,
#   'Wind Speed mph': 8.16,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ukiah',
#   'Country': 'US',
#   'Lat': 39.1502,
#   'Lng': -123.2078,
#   'Max Temp F°': 96.69,
#   'Humidity %': 11,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tobermory',
#   'Country': 'CA',
#   'Lat': 45.2501,
#   'Lng': -81.6665,
#   'Max Temp F°': 62.31,
#   'Humidity %': 82,
#   'Cloudiness %': 14,
#   'Wind Speed mph': 9.64,
#   'Weather Description': 'few clouds'},
#  {'City': 'Tual',
#   'Country': 'ID',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp F°': 80.76,
#   'Humidity %': 73,
#   'Cloudiness %': 97,
#   'Wind Speed mph': 18.59,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp F°': 60.06,
#   'Humidity %': 50,
#   'Cloudiness %': 18,
#   'Wind Speed mph': 15.01,
#   'Weather Description': 'few clouds'}]

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp F°  Humidity %  \
# 0         Faya      SA  18.3851   42.4509        64.51          71
# 1        Tiksi      RU  71.6872  128.8694        45.07          72
# 2       Torbay      CA  47.6666  -52.7314        62.58          85
# 3     Saldanha      ZA -33.0117   17.9442        48.25          90
# 4       Atuona      PF  -9.8000 -139.0333        77.58          73
# ..         ...     ...      ...       ...          ...         ...
# 682    Qitaihe      CN  45.8000  130.8500        87.12          42
# 683      Ukiah      US  39.1502 -123.2078        96.69          11
# 684  Tobermory      CA  45.2501  -81.6665        62.31          82
# 685       Tual      ID  -5.6667  132.7500        80.76          73
# 686   Flinders      AU -34.5833  150.8552        60.06          50
#
#      Cloudiness %  Wind Speed mph Weather Description
# 0              10            5.37           clear sky
# 1              76           10.36       broken clouds
# 2              20           20.71          few clouds
# 3               9            7.18           clear sky
# 4              69           15.50          light rain
# ..            ...             ...                 ...
# 682            64            8.16       broken clouds
# 683             1            9.22           clear sky
# 684            14            9.64          few clouds
# 685            97           18.59     overcast clouds
# 686            18           15.01          few clouds
#
# [687 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
