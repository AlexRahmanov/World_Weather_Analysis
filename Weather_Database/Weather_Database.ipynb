# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json as json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
import requests
from datetime import datetime

import os
import sys

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"] 
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp F°": city_max_temp,
                          "Humidity %": city_humidity,
                          "Cloudiness %": city_clouds,
                          "Wind Speed mph": city_wind,
                          "Weather Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | manyana
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | lumphat
# Processing Record 7 of Set 1 | kapit
# Processing Record 8 of Set 1 | morozovsk
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | richards bay
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | sorland
# Processing Record 14 of Set 1 | cairns
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | itaqui
# Processing Record 18 of Set 1 | kahului
# Processing Record 19 of Set 1 | yerbogachen
# Processing Record 20 of Set 1 | husavik
# Processing Record 21 of Set 1 | sola
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | shebunino
# Processing Record 24 of Set 1 | shenjiamen
# Processing Record 25 of Set 1 | ust-ishim
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | opuwo
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | namtsy
# Processing Record 32 of Set 1 | tambo
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | deputatskiy
# Processing Record 35 of Set 1 | sonqar
# City not found. Skipping...
# Processing Record 36 of Set 1 | mersing
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | lumberton
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | kandrian
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | san juan
# Processing Record 48 of Set 1 | vladaia
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | barcelos
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | roquetas de mar
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | mayo
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | nenjiang
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | prokuplje
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | jinka
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | hambantota
# Processing Record 17 of Set 2 | abu kamal
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | necochea
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | sao filipe
# Processing Record 22 of Set 2 | nouakchott
# Processing Record 23 of Set 2 | hobyo
# Processing Record 24 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 2 | pisco
# Processing Record 26 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 2 | gigmoto
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | sampit
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | berdigestyakh
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | savannah bight
# Processing Record 37 of Set 2 | houma
# Processing Record 38 of Set 2 | jinchang
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | antsohihy
# Processing Record 41 of Set 2 | shahrud
# Processing Record 42 of Set 2 | starosubkhangulovo
# Processing Record 43 of Set 2 | yanam
# Processing Record 44 of Set 2 | doume
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | orsha
# Processing Record 48 of Set 2 | sulangan
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | mumbwa
# Processing Record 1 of Set 3 | mae hong son
# Processing Record 2 of Set 3 | batagay
# Processing Record 3 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | basoko
# Processing Record 7 of Set 3 | alice springs
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | te anau
# Processing Record 11 of Set 3 | haapiti
# Processing Record 12 of Set 3 | yumen
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 15 of Set 3 | baherden
# Processing Record 16 of Set 3 | labrea
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | hervey bay
# Processing Record 20 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | quatre cocos
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | ahipara
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | vestmannaeyjar
# Processing Record 27 of Set 3 | healdsburg
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | poitiers
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | garowe
# Processing Record 32 of Set 3 | prince rupert
# Processing Record 33 of Set 3 | inhambane
# Processing Record 34 of Set 3 | nyurba
# Processing Record 35 of Set 3 | kharan
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | pittsfield
# Processing Record 38 of Set 3 | arcata
# Processing Record 39 of Set 3 | placido de castro
# Processing Record 40 of Set 3 | baoding
# Processing Record 41 of Set 3 | dauriya
# Processing Record 42 of Set 3 | salalah
# Processing Record 43 of Set 3 | hirara
# Processing Record 44 of Set 3 | longhua
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | nacala
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | vostok
# Processing Record 49 of Set 3 | sinegorye
# Processing Record 50 of Set 3 | chabahar
# Processing Record 1 of Set 4 | padang
# Processing Record 2 of Set 4 | lincoln
# Processing Record 3 of Set 4 | la baule-escoublac
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | pangnirtung
# Processing Record 6 of Set 4 | preobrazheniye
# Processing Record 7 of Set 4 | kutum
# Processing Record 8 of Set 4 | luanda
# Processing Record 9 of Set 4 | kapuskasing
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | fare
# Processing Record 13 of Set 4 | port blair
# Processing Record 14 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | vila franca do campo
# Processing Record 18 of Set 4 | faya
# Processing Record 19 of Set 4 | stroud
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | lompoc
# Processing Record 22 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 4 | coihaique
# Processing Record 24 of Set 4 | atocha
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | la cruz
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | santa maria
# Processing Record 31 of Set 4 | bima
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | tangshan
# Processing Record 34 of Set 4 | ilo
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | lookan
# Processing Record 38 of Set 4 | vila velha
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | fairbanks
# Processing Record 41 of Set 4 | andra
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | pevek
# Processing Record 44 of Set 4 | bajmok
# Processing Record 45 of Set 4 | altamira
# Processing Record 46 of Set 4 | dustlik
# Processing Record 47 of Set 4 | caravelas
# Processing Record 48 of Set 4 | atchison
# Processing Record 49 of Set 4 | bengkulu
# Processing Record 50 of Set 4 | mitsamiouli
# Processing Record 1 of Set 5 | tilichiki
# Processing Record 2 of Set 5 | lalganj
# Processing Record 3 of Set 5 | durres
# Processing Record 4 of Set 5 | zempoala
# Processing Record 5 of Set 5 | isaszeg
# Processing Record 6 of Set 5 | inongo
# Processing Record 7 of Set 5 | lodja
# Processing Record 8 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 10 of Set 5 | tutoia
# Processing Record 11 of Set 5 | saint anthony
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | teya
# Processing Record 14 of Set 5 | lhokseumawe
# Processing Record 15 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 5 | mbandaka
# Processing Record 17 of Set 5 | libreville
# Processing Record 18 of Set 5 | bundaberg
# Processing Record 19 of Set 5 | tura
# Processing Record 20 of Set 5 | brufut
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | narsaq
# Processing Record 23 of Set 5 | palembang
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | pennagaram
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | zhigansk
# Processing Record 28 of Set 5 | kaeo
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | chardara
# Processing Record 31 of Set 5 | chernyshevsk
# Processing Record 32 of Set 5 | severo-kurilsk
# Processing Record 33 of Set 5 | muros
# Processing Record 34 of Set 5 | santa rosalia
# Processing Record 35 of Set 5 | aripuana
# Processing Record 36 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 37 of Set 5 | mazatlan
# Processing Record 38 of Set 5 | saint-philippe
# Processing Record 39 of Set 5 | shebalino
# Processing Record 40 of Set 5 | kapiri mposhi
# Processing Record 41 of Set 5 | gizo
# Processing Record 42 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | qunduz
# Processing Record 45 of Set 5 | fianarantsoa
# Processing Record 46 of Set 5 | gatehouse of fleet
# Processing Record 47 of Set 5 | tynda
# Processing Record 48 of Set 5 | murray bridge
# Processing Record 49 of Set 5 | nome
# Processing Record 50 of Set 5 | lorengau
# Processing Record 1 of Set 6 | hay river
# Processing Record 2 of Set 6 | tambacounda
# Processing Record 3 of Set 6 | koygorodok
# Processing Record 4 of Set 6 | zaplyusye
# City not found. Skipping...
# Processing Record 5 of Set 6 | poronaysk
# Processing Record 6 of Set 6 | bata
# Processing Record 7 of Set 6 | hamakita
# Processing Record 8 of Set 6 | goderich
# Processing Record 9 of Set 6 | aanekoski
# Processing Record 10 of Set 6 | katsuura
# Processing Record 11 of Set 6 | hofn
# Processing Record 12 of Set 6 | ventspils
# Processing Record 13 of Set 6 | yacuiba
# Processing Record 14 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 15 of Set 6 | bubaque
# Processing Record 16 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 6 | kamaishi
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | de-kastri
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | whitehorse
# Processing Record 22 of Set 6 | charters towers
# Processing Record 23 of Set 6 | novyy svit
# Processing Record 24 of Set 6 | moerai
# Processing Record 25 of Set 6 | bar harbor
# Processing Record 26 of Set 6 | ulaangom
# Processing Record 27 of Set 6 | zalantun
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | avera
# Processing Record 30 of Set 6 | roccastrada
# Processing Record 31 of Set 6 | jonesboro
# Processing Record 32 of Set 6 | grand gaube
# Processing Record 33 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 6 | amazar
# Processing Record 35 of Set 6 | amuntai
# Processing Record 36 of Set 6 | tigil
# Processing Record 37 of Set 6 | codrington
# Processing Record 38 of Set 6 | biryusinsk
# Processing Record 39 of Set 6 | anuradhapura
# Processing Record 40 of Set 6 | cap malheureux
# Processing Record 41 of Set 6 | buala
# Processing Record 42 of Set 6 | andenes
# Processing Record 43 of Set 6 | petatlan
# Processing Record 44 of Set 6 | broken hill
# Processing Record 45 of Set 6 | gobabis
# Processing Record 46 of Set 6 | biak
# Processing Record 47 of Set 6 | mahebourg
# Processing Record 48 of Set 6 | adrian
# Processing Record 49 of Set 6 | verkhoyansk
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | kuusamo
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | alikalia
# Processing Record 5 of Set 7 | laredo
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | polunochnoye
# Processing Record 8 of Set 7 | skjervoy
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | gat
# Processing Record 11 of Set 7 | ayan
# Processing Record 12 of Set 7 | rozivka
# Processing Record 13 of Set 7 | havelock
# Processing Record 14 of Set 7 | matola
# Processing Record 15 of Set 7 | sungairaya
# Processing Record 16 of Set 7 | fortuna
# Processing Record 17 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | turan
# Processing Record 20 of Set 7 | peniche
# Processing Record 21 of Set 7 | nedjo
# Processing Record 22 of Set 7 | idah
# Processing Record 23 of Set 7 | kurchum
# Processing Record 24 of Set 7 | new norfolk
# Processing Record 25 of Set 7 | pyay
# Processing Record 26 of Set 7 | russell
# Processing Record 27 of Set 7 | cabra
# Processing Record 28 of Set 7 | henties bay
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | cockburn town
# Processing Record 31 of Set 7 | cartagena
# Processing Record 32 of Set 7 | springbok
# Processing Record 33 of Set 7 | gorontalo
# Processing Record 34 of Set 7 | hasaki
# Processing Record 35 of Set 7 | candating
# Processing Record 36 of Set 7 | rocha
# Processing Record 37 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 38 of Set 7 | los alamos
# Processing Record 39 of Set 7 | sokoni
# Processing Record 40 of Set 7 | coquimbo
# Processing Record 41 of Set 7 | leningradskiy
# Processing Record 42 of Set 7 | kimbe
# Processing Record 43 of Set 7 | byron bay
# Processing Record 44 of Set 7 | nouadhibou
# Processing Record 45 of Set 7 | progreso
# Processing Record 46 of Set 7 | suruc
# Processing Record 47 of Set 7 | baculin
# Processing Record 48 of Set 7 | osoyoos
# Processing Record 49 of Set 7 | aswan
# Processing Record 50 of Set 7 | paamiut
# Processing Record 1 of Set 8 | nicoya
# Processing Record 2 of Set 8 | mandello del lario
# Processing Record 3 of Set 8 | kafue
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | trinidad
# Processing Record 6 of Set 8 | nalut
# Processing Record 7 of Set 8 | sao domingos
# Processing Record 8 of Set 8 | dubbo
# Processing Record 9 of Set 8 | kashmor
# Processing Record 10 of Set 8 | sabla
# Processing Record 11 of Set 8 | talas
# Processing Record 12 of Set 8 | aklavik
# Processing Record 13 of Set 8 | itaituba
# Processing Record 14 of Set 8 | elmadag
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | pabna
# Processing Record 17 of Set 8 | nushki
# Processing Record 18 of Set 8 | iznoski
# Processing Record 19 of Set 8 | berlevag
# Processing Record 20 of Set 8 | fonte boa
# Processing Record 21 of Set 8 | shelburne
# Processing Record 22 of Set 8 | cheyenne
# Processing Record 23 of Set 8 | kaitangata
# Processing Record 24 of Set 8 | chicama
# Processing Record 25 of Set 8 | marawi
# Processing Record 26 of Set 8 | newport
# Processing Record 27 of Set 8 | sur
# Processing Record 28 of Set 8 | villarrica
# Processing Record 29 of Set 8 | bandipur
# Processing Record 30 of Set 8 | meulaboh
# Processing Record 31 of Set 8 | mayumba
# Processing Record 32 of Set 8 | kamennogorsk
# Processing Record 33 of Set 8 | sonoita
# Processing Record 34 of Set 8 | maniwaki
# Processing Record 35 of Set 8 | dondo
# Processing Record 36 of Set 8 | jarinu
# Processing Record 37 of Set 8 | san nicolas
# Processing Record 38 of Set 8 | duz
# City not found. Skipping...
# Processing Record 39 of Set 8 | horta
# Processing Record 40 of Set 8 | brazzaville
# Processing Record 41 of Set 8 | namatanai
# Processing Record 42 of Set 8 | ambulu
# Processing Record 43 of Set 8 | lata
# Processing Record 44 of Set 8 | dillon
# Processing Record 45 of Set 8 | roebourne
# Processing Record 46 of Set 8 | flinders
# Processing Record 47 of Set 8 | aden
# Processing Record 48 of Set 8 | poum
# Processing Record 49 of Set 8 | karakulino
# Processing Record 50 of Set 8 | vanavara
# Processing Record 1 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 9 | pontian kecil
# Processing Record 3 of Set 9 | colares
# Processing Record 4 of Set 9 | touros
# Processing Record 5 of Set 9 | bose
# Processing Record 6 of Set 9 | syracuse
# Processing Record 7 of Set 9 | saint-augustin
# Processing Record 8 of Set 9 | conegliano
# Processing Record 9 of Set 9 | leninskoye
# Processing Record 10 of Set 9 | naryan-mar
# Processing Record 11 of Set 9 | geraldton
# Processing Record 12 of Set 9 | macas
# Processing Record 13 of Set 9 | dingle
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | kaspiyskiy
# Processing Record 16 of Set 9 | monroe
# Processing Record 17 of Set 9 | komsomolskiy
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | groton
# Processing Record 20 of Set 9 | trat
# Processing Record 21 of Set 9 | mae sot
# Processing Record 22 of Set 9 | lagoa
# Processing Record 23 of Set 9 | sfantu gheorghe
# Processing Record 24 of Set 9 | valdemarpils
# Processing Record 25 of Set 9 | meiganga
# Processing Record 26 of Set 9 | benjamin constant
# Processing Record 27 of Set 9 | nabire
# Processing Record 28 of Set 9 | porto novo
# Processing Record 29 of Set 9 | kasama
# Processing Record 30 of Set 9 | atambua
# Processing Record 31 of Set 9 | west wendover
# Processing Record 32 of Set 9 | zhuhai
# Processing Record 33 of Set 9 | kanor
# Processing Record 34 of Set 9 | batagay-alyta
# Processing Record 35 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 9 | ucluelet
# Processing Record 37 of Set 9 | toora-khem
# Processing Record 38 of Set 9 | ponerihouen
# Processing Record 39 of Set 9 | anadyr
# Processing Record 40 of Set 9 | clyde river
# Processing Record 41 of Set 9 | rawatsar
# Processing Record 42 of Set 9 | ribeira brava
# Processing Record 43 of Set 9 | mingguang
# Processing Record 44 of Set 9 | troitsko-pechorsk
# Processing Record 45 of Set 9 | hassleholm
# Processing Record 46 of Set 9 | ejby
# Processing Record 47 of Set 9 | ca mau
# Processing Record 48 of Set 9 | hovd
# Processing Record 49 of Set 9 | antalaha
# Processing Record 50 of Set 9 | areosa
# Processing Record 1 of Set 10 | hokitika
# Processing Record 2 of Set 10 | burnie
# Processing Record 3 of Set 10 | canto do buriti
# Processing Record 4 of Set 10 | panipat
# Processing Record 5 of Set 10 | isangel
# Processing Record 6 of Set 10 | chisec
# Processing Record 7 of Set 10 | eyl
# Processing Record 8 of Set 10 | roald
# Processing Record 9 of Set 10 | partizanskoye
# Processing Record 10 of Set 10 | weston
# Processing Record 11 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 12 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 10 | galle
# Processing Record 14 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 10 | shingu
# Processing Record 16 of Set 10 | ayios matthaios
# City not found. Skipping...
# Processing Record 17 of Set 10 | hudson bay
# Processing Record 18 of Set 10 | novikovo
# Processing Record 19 of Set 10 | skibbereen
# Processing Record 20 of Set 10 | kijang
# Processing Record 21 of Set 10 | kloulklubed
# Processing Record 22 of Set 10 | port hedland
# Processing Record 23 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 24 of Set 10 | celestun
# Processing Record 25 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 10 | parabel
# Processing Record 27 of Set 10 | morant bay
# Processing Record 28 of Set 10 | yulara
# Processing Record 29 of Set 10 | rio gallegos
# Processing Record 30 of Set 10 | dickinson
# Processing Record 31 of Set 10 | antofagasta
# Processing Record 32 of Set 10 | omboue
# Processing Record 33 of Set 10 | alim
# Processing Record 34 of Set 10 | shieli
# Processing Record 35 of Set 10 | pundaguitan
# Processing Record 36 of Set 10 | torrevieja
# Processing Record 37 of Set 10 | pacific grove
# Processing Record 38 of Set 10 | fukue
# Processing Record 39 of Set 10 | presidencia roque saenz pena
# Processing Record 40 of Set 10 | bagotville
# Processing Record 41 of Set 10 | yeppoon
# Processing Record 42 of Set 10 | resistencia
# Processing Record 43 of Set 10 | manta
# Processing Record 44 of Set 10 | burewala
# Processing Record 45 of Set 10 | mortka
# Processing Record 46 of Set 10 | riosucio
# Processing Record 47 of Set 10 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 10 | moberly
# Processing Record 49 of Set 10 | amga
# Processing Record 50 of Set 10 | shiyan
# Processing Record 1 of Set 11 | pachino
# Processing Record 2 of Set 11 | kropotkin
# Processing Record 3 of Set 11 | witu
# Processing Record 4 of Set 11 | san miguel
# Processing Record 5 of Set 11 | awjilah
# Processing Record 6 of Set 11 | yarmouth
# Processing Record 7 of Set 11 | zyryanka
# Processing Record 8 of Set 11 | flagstaff
# Processing Record 9 of Set 11 | soyo
# Processing Record 10 of Set 11 | nemuro
# Processing Record 11 of Set 11 | pahrump
# Processing Record 12 of Set 11 | hailar
# Processing Record 13 of Set 11 | beringovskiy
# Processing Record 14 of Set 11 | conde
# Processing Record 15 of Set 11 | wahiawa
# Processing Record 16 of Set 11 | issoire
# Processing Record 17 of Set 11 | molteno
# Processing Record 18 of Set 11 | merauke
# Processing Record 19 of Set 11 | bali
# Processing Record 20 of Set 11 | baykit
# Processing Record 21 of Set 11 | imeni poliny osipenko
# Processing Record 22 of Set 11 | albenga
# Processing Record 23 of Set 11 | tuatapere
# Processing Record 24 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 25 of Set 11 | sioux lookout
# Processing Record 26 of Set 11 | oranjemund
# Processing Record 27 of Set 11 | lavumisa
# Processing Record 28 of Set 11 | bokoro
# Processing Record 29 of Set 11 | cabo san lucas
# Processing Record 30 of Set 11 | klaksvik
# Processing Record 31 of Set 11 | kelvington
# Processing Record 32 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 11 | nortelandia
# Processing Record 34 of Set 11 | sunnyside
# Processing Record 35 of Set 11 | lingao
# Processing Record 36 of Set 11 | conceicao do araguaia
# Processing Record 37 of Set 11 | belawan
# Processing Record 38 of Set 11 | palana
# Processing Record 39 of Set 11 | la romana
# Processing Record 40 of Set 11 | ayia
# City not found. Skipping...
# Processing Record 41 of Set 11 | belmonte
# Processing Record 42 of Set 11 | kulhudhuffushi
# Processing Record 43 of Set 11 | darab
# Processing Record 44 of Set 11 | phalaborwa
# Processing Record 45 of Set 11 | cap-aux-meules
# Processing Record 46 of Set 11 | salair
# Processing Record 47 of Set 11 | yaan
# Processing Record 48 of Set 11 | podlesnoye
# Processing Record 49 of Set 11 | tevaitoa
# Processing Record 50 of Set 11 | waingapu
# Processing Record 1 of Set 12 | anito
# Processing Record 2 of Set 12 | mabini
# Processing Record 3 of Set 12 | ippy
# Processing Record 4 of Set 12 | orcopampa
# Processing Record 5 of Set 12 | reconquista
# Processing Record 6 of Set 12 | beyneu
# Processing Record 7 of Set 12 | palmer
# Processing Record 8 of Set 12 | bantogon
# Processing Record 9 of Set 12 | tambura
# Processing Record 10 of Set 12 | chudovo
# Processing Record 11 of Set 12 | rosamorada
# Processing Record 12 of Set 12 | punalur
# Processing Record 13 of Set 12 | maniitsoq
# Processing Record 14 of Set 12 | surt
# Processing Record 15 of Set 12 | katherine
# Processing Record 16 of Set 12 | kankan
# Processing Record 17 of Set 12 | san jeronimo
# Processing Record 18 of Set 12 | groningen
# Processing Record 19 of Set 12 | coahuayana
# Processing Record 20 of Set 12 | hamilton
# Processing Record 21 of Set 12 | asau
# Processing Record 22 of Set 12 | tessalit
# Processing Record 23 of Set 12 | road town
# Processing Record 24 of Set 12 | la ronge
# Processing Record 25 of Set 12 | blythe
# Processing Record 26 of Set 12 | madisonville
# Processing Record 27 of Set 12 | matagami
# Processing Record 28 of Set 12 | najran
# Processing Record 29 of Set 12 | bahar
# Processing Record 30 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 31 of Set 12 | torrington
# Processing Record 32 of Set 12 | todos santos
# Processing Record 33 of Set 12 | tomatlan
# Processing Record 34 of Set 12 | le port
# Processing Record 35 of Set 12 | moose factory
# Processing Record 36 of Set 12 | bathsheba
# Processing Record 37 of Set 12 | rawson
# Processing Record 38 of Set 12 | bereznik
# Processing Record 39 of Set 12 | nexo
# Processing Record 40 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 12 | saint-georges
# Processing Record 42 of Set 12 | gladstone
# Processing Record 43 of Set 12 | roma
# Processing Record 44 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 12 | mount gambier
# Processing Record 46 of Set 12 | tinjah
# City not found. Skipping...
# Processing Record 47 of Set 12 | natal
# Processing Record 48 of Set 12 | samarai
# Processing Record 49 of Set 12 | rincon
# Processing Record 50 of Set 12 | oriximina
# Processing Record 1 of Set 13 | srednekolymsk
# Processing Record 2 of Set 13 | turayf
# Processing Record 3 of Set 13 | chara
# Processing Record 4 of Set 13 | lapeer
# Processing Record 5 of Set 13 | buin
# Processing Record 6 of Set 13 | xiuyan
# Processing Record 7 of Set 13 | gaya
# Processing Record 8 of Set 13 | mackenzie
# Processing Record 9 of Set 13 | kuytun
# Processing Record 10 of Set 13 | bhatkal
# Processing Record 11 of Set 13 | arlit
# Processing Record 12 of Set 13 | marigliano
# Processing Record 13 of Set 13 | snyder
# Processing Record 14 of Set 13 | udachnyy
# Processing Record 15 of Set 13 | tral
# Processing Record 16 of Set 13 | pottsville
# Processing Record 17 of Set 13 | muzhi
# Processing Record 18 of Set 13 | margate
# Processing Record 19 of Set 13 | leninskiy
# Processing Record 20 of Set 13 | keetmanshoop
# Processing Record 21 of Set 13 | yining
# Processing Record 22 of Set 13 | eugene
# Processing Record 23 of Set 13 | kyzyl-suu
# Processing Record 24 of Set 13 | abdanan
# Processing Record 25 of Set 13 | gulu
# Processing Record 26 of Set 13 | yar-sale
# Processing Record 27 of Set 13 | huanren
# Processing Record 28 of Set 13 | santa isabel
# Processing Record 29 of Set 13 | malim
# Processing Record 30 of Set 13 | thinadhoo
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | luderitz
# Processing Record 33 of Set 13 | pingzhuang
# Processing Record 34 of Set 13 | pryazha
# Processing Record 35 of Set 13 | rudbar
# Processing Record 36 of Set 13 | wajima
# Processing Record 37 of Set 13 | sibu
# Processing Record 38 of Set 13 | port moresby
# Processing Record 39 of Set 13 | devarkonda
# Processing Record 40 of Set 13 | erenhot
# Processing Record 41 of Set 13 | general pico
# Processing Record 42 of Set 13 | turukhansk
# Processing Record 43 of Set 13 | vulcan
# Processing Record 44 of Set 13 | sharjah
# Processing Record 45 of Set 13 | oyama
# Processing Record 46 of Set 13 | kattivakkam
# Processing Record 47 of Set 13 | eskil
# Processing Record 48 of Set 13 | tuy hoa
# Processing Record 49 of Set 13 | lucapa
# Processing Record 50 of Set 13 | florianopolis
# Processing Record 1 of Set 14 | inuvik
# Processing Record 2 of Set 14 | salinas
# Processing Record 3 of Set 14 | arawa
# Processing Record 4 of Set 14 | lima
# Processing Record 5 of Set 14 | bowen
# Processing Record 6 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 14 | abu samrah
# Processing Record 8 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 14 | pastavy
# Processing Record 10 of Set 14 | kalmunai
# Processing Record 11 of Set 14 | kirakira
# Processing Record 12 of Set 14 | uyemskiy
# Processing Record 13 of Set 14 | mitu
# Processing Record 14 of Set 14 | ermelo
# Processing Record 15 of Set 14 | zunyi
# Processing Record 16 of Set 14 | siirt
# Processing Record 17 of Set 14 | lakatoro
# Processing Record 18 of Set 14 | benemerito de las americas
# Processing Record 19 of Set 14 | atakpame
# Processing Record 20 of Set 14 | shellbrook
# Processing Record 21 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 14 | graham
# Processing Record 23 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 14 | verdun
# Processing Record 25 of Set 14 | pingliang
# Processing Record 26 of Set 14 | gwadar
# Processing Record 27 of Set 14 | velikiy ustyug
# Processing Record 28 of Set 14 | kilindoni
# Processing Record 29 of Set 14 | planaltina
# Processing Record 30 of Set 14 | nakonde
# Processing Record 31 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 14 | khash
# Processing Record 33 of Set 14 | half moon bay
# Processing Record 34 of Set 14 | ekhabi
# Processing Record 35 of Set 14 | moranbah
# Processing Record 36 of Set 14 | kintampo
# Processing Record 37 of Set 14 | apache junction
# Processing Record 38 of Set 14 | oussouye
# Processing Record 39 of Set 14 | jackson
# Processing Record 40 of Set 14 | warburg
# Processing Record 41 of Set 14 | jacareacanga
# Processing Record 42 of Set 14 | oga
# Processing Record 43 of Set 14 | huarmey
# Processing Record 44 of Set 14 | jiwani
# Processing Record 45 of Set 14 | buraydah
# Processing Record 46 of Set 14 | gambela
# Processing Record 47 of Set 14 | mahon
# Processing Record 48 of Set 14 | riyadh
# Processing Record 49 of Set 14 | guerrero negro
# Processing Record 50 of Set 14 | santa fe
# Processing Record 1 of Set 15 | catuday
# Processing Record 2 of Set 15 | magadan
# Processing Record 3 of Set 15 | leczna
# Processing Record 4 of Set 15 | itarema
# Processing Record 5 of Set 15 | teguise
# Processing Record 6 of Set 15 | belize
# Processing Record 7 of Set 15 | kajaani
# Processing Record 8 of Set 15 | mount isa
# Processing Record 9 of Set 15 | marsabit
# Processing Record 10 of Set 15 | sevierville
# Processing Record 11 of Set 15 | yabelo
# Processing Record 12 of Set 15 | kahuta
# Processing Record 13 of Set 15 | sovetskiy
# Processing Record 14 of Set 15 | bukama
# Processing Record 15 of Set 15 | los llanos de aridane
# Processing Record 16 of Set 15 | banda aceh
# Processing Record 17 of Set 15 | awbari
# Processing Record 18 of Set 15 | olinda
# Processing Record 19 of Set 15 | tecoanapa
# Processing Record 20 of Set 15 | taltal
# Processing Record 21 of Set 15 | adre
# Processing Record 22 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 24 of Set 15 | ouesso
# Processing Record 25 of Set 15 | mpika
# Processing Record 26 of Set 15 | purpe
# Processing Record 27 of Set 15 | portsmouth
# Processing Record 28 of Set 15 | lasa
# Processing Record 29 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 15 | lebanon
# Processing Record 31 of Set 15 | mount darwin
# Processing Record 32 of Set 15 | alpena
# Processing Record 33 of Set 15 | launceston
# Processing Record 34 of Set 15 | ouadda
# Processing Record 35 of Set 15 | bilgi
# Processing Record 36 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 37 of Set 15 | nioro
# Processing Record 38 of Set 15 | montego bay
# Processing Record 39 of Set 15 | maykor
# Processing Record 40 of Set 15 | lewes
# Processing Record 41 of Set 15 | tautira
# Processing Record 42 of Set 15 | arkhangelsk
# Processing Record 43 of Set 15 | teneguiban
# City not found. Skipping...
# Processing Record 44 of Set 15 | muhlhausen
# Processing Record 45 of Set 15 | port hardy
# Processing Record 46 of Set 15 | wheatley
# Processing Record 47 of Set 15 | kerman
# Processing Record 48 of Set 15 | buchanan
# Processing Record 49 of Set 15 | samdrup jongkhar
# Processing Record 50 of Set 15 | ozernovskiy
# Processing Record 1 of Set 16 | labuhan
# Processing Record 2 of Set 16 | moron
# Processing Record 3 of Set 16 | huangmei
# Processing Record 4 of Set 16 | dakar
# Processing Record 5 of Set 16 | san cristobal
# Processing Record 6 of Set 16 | cozumel
# Processing Record 7 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 16 | sangar
# Processing Record 9 of Set 16 | mlyniv
# Processing Record 10 of Set 16 | kilgore
# Processing Record 11 of Set 16 | rivadavia
# Processing Record 12 of Set 16 | giyani
# Processing Record 13 of Set 16 | algarrobo
# Processing Record 14 of Set 16 | mangai
# Processing Record 15 of Set 16 | bida
# Processing Record 16 of Set 16 | koryazhma
# Processing Record 17 of Set 16 | karratha
# Processing Record 18 of Set 16 | bambanglipuro
# Processing Record 19 of Set 16 | terrace
# Processing Record 20 of Set 16 | santa lucia
# Processing Record 21 of Set 16 | karimganj
# Processing Record 22 of Set 16 | ye
# City not found. Skipping...
# Processing Record 23 of Set 16 | coolum beach
# Processing Record 24 of Set 16 | winnemucca
# Processing Record 25 of Set 16 | san isidro
# Processing Record 26 of Set 16 | loandjili
# Processing Record 27 of Set 16 | koslan
# Processing Record 28 of Set 16 | boa vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#json.dumps(thing_to_be_printed, indent=4, sort_keys=True) iport p print
import pprint
pprint.pprint(city_data)
# Out:
# [{'City': 'Talnakh',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 58,
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp F°': 71.51,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.01},
#  {'City': 'Manyana',
#   'Cloudiness %': 20,
#   'Country': 'BW',
#   'Humidity %': 39,
#   'Lat': -23.4,
#   'Lng': 21.7167,
#   'Max Temp F°': 54.09,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 6.96},
#  {'City': 'Bethel',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 87,
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp F°': 72.41,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.44},
#  {'City': 'Albany',
#   'Cloudiness %': 0,
#   'Country': 'US',
#   'Humidity %': 81,
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp F°': 72.21,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.8},
#  {'City': 'Bredasdorp',
#   'Cloudiness %': 96,
#   'Country': 'ZA',
#   'Humidity %': 94,
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp F°': 54.28,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.44},
#  {'City': 'Lumphat',
#   'Cloudiness %': 100,
#   'Country': 'KH',
#   'Humidity %': 98,
#   'Lat': 13.4878,
#   'Lng': 106.9816,
#   'Max Temp F°': 75.27,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.15},
#  {'City': 'Kapit',
#   'Cloudiness %': 45,
#   'Country': 'MY',
#   'Humidity %': 70,
#   'Lat': 2.0167,
#   'Lng': 112.9333,
#   'Max Temp F°': 82.56,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.28},
#  {'City': 'Morozovsk',
#   'Cloudiness %': 76,
#   'Country': 'RU',
#   'Humidity %': 49,
#   'Lat': 48.3539,
#   'Lng': 41.8261,
#   'Max Temp F°': 76.93,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 9.98},
#  {'City': 'Tuktoyaktuk',
#   'Cloudiness %': 90,
#   'Country': 'CA',
#   'Humidity %': 100,
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp F°': 46.4,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 18.41},
#  {'City': 'Vaini',
#   'Cloudiness %': 20,
#   'Country': 'TO',
#   'Humidity %': 78,
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp F°': 77.16,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Richards Bay',
#   'Cloudiness %': 0,
#   'Country': 'ZA',
#   'Humidity %': 91,
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp F°': 60.1,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.29},
#  {'City': 'Hermanus',
#   'Cloudiness %': 68,
#   'Country': 'ZA',
#   'Humidity %': 85,
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp F°': 54.81,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 8.61},
#  {'City': 'Sorland',
#   'Cloudiness %': 100,
#   'Country': 'NO',
#   'Humidity %': 86,
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp F°': 54.46,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.72},
#  {'City': 'Cairns',
#   'Cloudiness %': 100,
#   'Country': 'AU',
#   'Humidity %': 49,
#   'Lat': -16.9167,
#   'Lng': 145.7667,
#   'Max Temp F°': 78.12,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 17.27},
#  {'City': 'Rikitea',
#   'Cloudiness %': 66,
#   'Country': 'PF',
#   'Humidity %': 74,
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp F°': 74.3,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 15.23},
#  {'City': 'Itaqui',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 68,
#   'Lat': -29.1253,
#   'Lng': -56.5531,
#   'Max Temp F°': 63.48,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.87},
#  {'City': 'Kahului',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 78,
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp F°': 83.46,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 21.85},
#  {'City': 'Yerbogachen',
#   'Cloudiness %': 95,
#   'Country': 'RU',
#   'Humidity %': 57,
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp F°': 68.65,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.05},
#  {'City': 'Husavik',
#   'Cloudiness %': 61,
#   'Country': 'IS',
#   'Humidity %': 90,
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp F°': 53.51,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 2.98},
#  {'City': 'Sola',
#   'Cloudiness %': 0,
#   'Country': 'VU',
#   'Humidity %': 72,
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp F°': 78.33,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 1.45},
#  {'City': 'Lebu',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 85,
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp F°': 51.31,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 10.31},
#  {'City': 'Shebunino',
#   'Cloudiness %': 93,
#   'Country': 'RU',
#   'Humidity %': 78,
#   'Lat': 46.4339,
#   'Lng': 141.8603,
#   'Max Temp F°': 75.36,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.31},
#  {'City': 'Shenjiamen',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 81,
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp F°': 82.02,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.09},
#  {'City': 'Ust-Ishim',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 85,
#   'Lat': 57.6935,
#   'Lng': 71.1665,
#   'Max Temp F°': 62.02,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3},
#  {'City': 'East London',
#   'Cloudiness %': 3,
#   'Country': 'ZA',
#   'Humidity %': 89,
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp F°': 63.03,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.63},
#  {'City': 'Grindavik',
#   'Cloudiness %': 40,
#   'Country': 'IS',
#   'Humidity %': 100,
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp F°': 53.91,
#   'Weather Description': 'fog',
#   'Wind Speed mph': 5.75},
#  {'City': 'Georgetown',
#   'Cloudiness %': 20,
#   'Country': 'MY',
#   'Humidity %': 78,
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp F°': 84.13,
#   'Weather Description': 'thunderstorm',
#   'Wind Speed mph': 3.44},
#  {'City': 'Opuwo',
#   'Cloudiness %': 1,
#   'Country': 'NA',
#   'Humidity %': 33,
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp F°': 58.89,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.91},
#  {'City': 'Chokurdakh',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 72,
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp F°': 43.88,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.13},
#  {'City': 'Namtsy',
#   'Cloudiness %': 1,
#   'Country': 'RU',
#   'Humidity %': 26,
#   'Lat': 62.7161,
#   'Lng': 129.6658,
#   'Max Temp F°': 68.11,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 11.39},
#  {'City': 'Tambo',
#   'Cloudiness %': 22,
#   'Country': 'PE',
#   'Humidity %': 66,
#   'Lat': -14.8,
#   'Lng': -73.9167,
#   'Max Temp F°': 38.01,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 2.06},
#  {'City': 'Avarua',
#   'Cloudiness %': 75,
#   'Country': 'CK',
#   'Humidity %': 61,
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp F°': 77.05,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.61},
#  {'City': 'Deputatskiy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 92,
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp F°': 37.15,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.28},
#  {'City': 'Mersing',
#   'Cloudiness %': 40,
#   'Country': 'MY',
#   'Humidity %': 89,
#   'Lat': 2.4312,
#   'Lng': 103.8405,
#   'Max Temp F°': 80.51,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.14},
#  {'City': 'Hobart',
#   'Cloudiness %': 75,
#   'Country': 'AU',
#   'Humidity %': 51,
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp F°': 60.06,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 5.01},
#  {'City': 'Mataura',
#   'Cloudiness %': 77,
#   'Country': 'NZ',
#   'Humidity %': 71,
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp F°': 50.49,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 2.53},
#  {'City': 'Sitka',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 72,
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp F°': 62.49,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 9.22},
#  {'City': 'Lumberton',
#   'Cloudiness %': 23,
#   'Country': 'US',
#   'Humidity %': 72,
#   'Lat': 34.6182,
#   'Lng': -79.0086,
#   'Max Temp F°': 78.46,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.42},
#  {'City': 'Busselton',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 76,
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp F°': 51.04,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.89},
#  {'City': 'Iqaluit',
#   'Cloudiness %': 90,
#   'Country': 'CA',
#   'Humidity %': 75,
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp F°': 42.53,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 9.22},
#  {'City': 'Kandrian',
#   'Cloudiness %': 86,
#   'Country': 'PG',
#   'Humidity %': 79,
#   'Lat': -6.2167,
#   'Lng': 149.55,
#   'Max Temp F°': 80.38,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 16.33},
#  {'City': 'Castro',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 90,
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp F°': 50.31,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.62},
#  {'City': 'Ancud',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 87,
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp F°': 50.43,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 11.97},
#  {'City': 'Ushuaia',
#   'Cloudiness %': 40,
#   'Country': 'AR',
#   'Humidity %': 65,
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp F°': 38.86,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 5.75},
#  {'City': 'San Juan',
#   'Cloudiness %': 100,
#   'Country': 'AR',
#   'Humidity %': 30,
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp F°': 64.54,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.29},
#  {'City': 'Vladaia',
#   'Cloudiness %': 100,
#   'Country': 'RO',
#   'Humidity %': 67,
#   'Lat': 44.35,
#   'Lng': 23.0333,
#   'Max Temp F°': 73.06,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.11},
#  {'City': 'Bluff',
#   'Cloudiness %': 43,
#   'Country': 'NZ',
#   'Humidity %': 70,
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp F°': 50.81,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 13.58},
#  {'City': 'Barcelos',
#   'Cloudiness %': 15,
#   'Country': 'PT',
#   'Humidity %': 93,
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp F°': 65.84,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.67},
#  {'City': 'Arraial Do Cabo',
#   'Cloudiness %': 22,
#   'Country': 'BR',
#   'Humidity %': 81,
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp F°': 68.31,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 14.5},
#  {'City': 'Roquetas De Mar',
#   'Cloudiness %': 0,
#   'Country': 'ES',
#   'Humidity %': 86,
#   'Lat': 36.7642,
#   'Lng': -2.6148,
#   'Max Temp F°': 75.2,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.74},
#  {'City': 'Butaritari',
#   'Cloudiness %': 11,
#   'Country': 'KI',
#   'Humidity %': 64,
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp F°': 83.34,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Dikson',
#   'Cloudiness %': 3,
#   'Country': 'RU',
#   'Humidity %': 89,
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp F°': 51.37,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.59},
#  {'City': 'Mar Del Plata',
#   'Cloudiness %': 90,
#   'Country': 'AR',
#   'Humidity %': 28,
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp F°': 57.09,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Mayo',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 74,
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp F°': 80.24,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.61},
#  {'City': 'Puerto Ayora',
#   'Cloudiness %': 57,
#   'Country': 'EC',
#   'Humidity %': 90,
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp F°': 70.56,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.01},
#  {'City': 'Nenjiang',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 82,
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp F°': 68.41,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.26},
#  {'City': 'Kodiak',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 88,
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp F°': 56.71,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 3.44},
#  {'City': 'Upernavik',
#   'Cloudiness %': 38,
#   'Country': 'GL',
#   'Humidity %': 70,
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp F°': 43.9,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 5.37},
#  {'City': 'Prokuplje',
#   'Cloudiness %': 99,
#   'Country': 'RS',
#   'Humidity %': 57,
#   'Lat': 43.2342,
#   'Lng': 21.5881,
#   'Max Temp F°': 69.08,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.61},
#  {'City': 'Chuy',
#   'Cloudiness %': 60,
#   'Country': 'UY',
#   'Humidity %': 94,
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp F°': 56.64,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 10.36},
#  {'City': 'Jinka',
#   'Cloudiness %': 100,
#   'Country': 'ET',
#   'Humidity %': 56,
#   'Lat': 5.65,
#   'Lng': 36.65,
#   'Max Temp F°': 67.59,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.5},
#  {'City': 'Port Alfred',
#   'Cloudiness %': 24,
#   'Country': 'ZA',
#   'Humidity %': 88,
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp F°': 61.48,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 10.11},
#  {'City': 'Hambantota',
#   'Cloudiness %': 98,
#   'Country': 'LK',
#   'Humidity %': 81,
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp F°': 79.03,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 17.27},
#  {'City': 'Abu Kamal',
#   'Cloudiness %': 47,
#   'Country': 'SY',
#   'Humidity %': 18,
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp F°': 95.38,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 14.12},
#  {'City': 'Thompson',
#   'Cloudiness %': 75,
#   'Country': 'CA',
#   'Humidity %': 48,
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp F°': 64.56,
#   'Weather Description': 'smoke',
#   'Wind Speed mph': 3.44},
#  {'City': 'Necochea',
#   'Cloudiness %': 0,
#   'Country': 'AR',
#   'Humidity %': 80,
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp F°': 53.33,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 13.73},
#  {'City': 'Saint George',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 10,
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp F°': 108.19,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.01},
#  {'City': 'Sao Filipe',
#   'Cloudiness %': 100,
#   'Country': 'CV',
#   'Humidity %': 91,
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp F°': 77.86,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.84},
#  {'City': 'Nouakchott',
#   'Cloudiness %': 9,
#   'Country': 'MR',
#   'Humidity %': 77,
#   'Lat': 18.0858,
#   'Lng': -15.9785,
#   'Max Temp F°': 78.73,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.96},
#  {'City': 'Hobyo',
#   'Cloudiness %': 96,
#   'Country': 'SO',
#   'Humidity %': 83,
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp F°': 75.72,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 25.48},
#  {'City': 'Pisco',
#   'Cloudiness %': 40,
#   'Country': 'PE',
#   'Humidity %': 88,
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp F°': 61.02,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 13.8},
#  {'City': 'Gigmoto',
#   'Cloudiness %': 52,
#   'Country': 'PH',
#   'Humidity %': 70,
#   'Lat': 13.7796,
#   'Lng': 124.39,
#   'Max Temp F°': 86.29,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 15.1},
#  {'City': 'Jamestown',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 73,
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp F°': 71.24,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.1},
#  {'City': 'Carnarvon',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 31,
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp F°': 66.27,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 18.41},
#  {'City': 'Kapaa',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 78,
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp F°': 84.18,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 4},
#  {'City': 'Sampit',
#   'Cloudiness %': 100,
#   'Country': 'ID',
#   'Humidity %': 84,
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp F°': 79.48,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.84},
#  {'City': 'Atuona',
#   'Cloudiness %': 17,
#   'Country': 'PF',
#   'Humidity %': 73,
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp F°': 77.97,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 13.38},
#  {'City': 'Berdigestyakh',
#   'Cloudiness %': 28,
#   'Country': 'RU',
#   'Humidity %': 25,
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp F°': 73.56,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 10},
#  {'City': 'Punta Arenas',
#   'Cloudiness %': 90,
#   'Country': 'CL',
#   'Humidity %': 87,
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp F°': 39.31,
#   'Weather Description': 'light intensity shower rain',
#   'Wind Speed mph': 8.05},
#  {'City': 'Airai',
#   'Cloudiness %': 62,
#   'Country': 'TL',
#   'Humidity %': 43,
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp F°': 68.36,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.68},
#  {'City': 'Savannah Bight',
#   'Cloudiness %': 6,
#   'Country': 'HN',
#   'Humidity %': 82,
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp F°': 82.99,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 21.99},
#  {'City': 'Houma',
#   'Cloudiness %': 100,
#   'Country': 'US',
#   'Humidity %': 72,
#   'Lat': 29.5958,
#   'Lng': -90.7195,
#   'Max Temp F°': 82,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.51},
#  {'City': 'Jinchang',
#   'Cloudiness %': 79,
#   'Country': 'CN',
#   'Humidity %': 35,
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp F°': 76.66,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 12.48},
#  {'City': 'Antsohihy',
#   'Cloudiness %': 0,
#   'Country': 'MG',
#   'Humidity %': 70,
#   'Lat': -14.8796,
#   'Lng': 47.9875,
#   'Max Temp F°': 66.15,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.87},
#  {'City': 'Shahrud',
#   'Cloudiness %': 0,
#   'Country': 'IR',
#   'Humidity %': 42,
#   'Lat': 36.4182,
#   'Lng': 54.9763,
#   'Max Temp F°': 69.67,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.09},
#  {'City': 'Starosubkhangulovo',
#   'Cloudiness %': 20,
#   'Country': 'RU',
#   'Humidity %': 97,
#   'Lat': 53.1031,
#   'Lng': 57.4423,
#   'Max Temp F°': 58.68,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4.03},
#  {'City': 'Yanam',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 78,
#   'Lat': 16.7333,
#   'Lng': 82.2167,
#   'Max Temp F°': 84.6,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.95},
#  {'City': 'Doume',
#   'Cloudiness %': 68,
#   'Country': 'CM',
#   'Humidity %': 99,
#   'Lat': 4.2333,
#   'Lng': 13.45,
#   'Max Temp F°': 67.17,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.74},
#  {'City': 'Harper',
#   'Cloudiness %': 76,
#   'Country': 'LR',
#   'Humidity %': 83,
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp F°': 75.42,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 10.4},
#  {'City': 'Orsha',
#   'Cloudiness %': 100,
#   'Country': 'BY',
#   'Humidity %': 93,
#   'Lat': 54.5153,
#   'Lng': 30.4053,
#   'Max Temp F°': 58.62,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.71},
#  {'City': 'Sulangan',
#   'Cloudiness %': 96,
#   'Country': 'PH',
#   'Humidity %': 71,
#   'Lat': 11.1373,
#   'Lng': 123.7228,
#   'Max Temp F°': 83.53,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.07},
#  {'City': 'Barrow',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp F°': 39.22,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 19.57},
#  {'City': 'Mumbwa',
#   'Cloudiness %': 0,
#   'Country': 'ZM',
#   'Humidity %': 43,
#   'Lat': -14.9783,
#   'Lng': 27.0619,
#   'Max Temp F°': 54.21,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.91},
#  {'City': 'Mae Hong Son',
#   'Cloudiness %': 75,
#   'Country': 'TH',
#   'Humidity %': 94,
#   'Lat': 19.3003,
#   'Lng': 97.9685,
#   'Max Temp F°': 77.14,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Batagay',
#   'Cloudiness %': 7,
#   'Country': 'RU',
#   'Humidity %': 42,
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp F°': 58.03,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.8},
#  {'City': 'San Patricio',
#   'Cloudiness %': 100,
#   'Country': 'US',
#   'Humidity %': 69,
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp F°': 83.12,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.35},
#  {'City': 'Kruisfontein',
#   'Cloudiness %': 94,
#   'Country': 'ZA',
#   'Humidity %': 94,
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp F°': 55.89,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.8},
#  {'City': 'Basoko',
#   'Cloudiness %': 92,
#   'Country': 'CD',
#   'Humidity %': 89,
#   'Lat': 1.2391,
#   'Lng': 23.616,
#   'Max Temp F°': 73.36,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.94},
#  {'City': 'Alice Springs',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 47,
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp F°': 56.75,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 16.11},
#  {'City': 'Tasiilaq',
#   'Cloudiness %': 0,
#   'Country': 'GL',
#   'Humidity %': 77,
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp F°': 37.24,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.91},
#  {'City': 'Nikolskoye',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 80,
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp F°': 58.78,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.71},
#  {'City': 'Te Anau',
#   'Cloudiness %': 57,
#   'Country': 'NZ',
#   'Humidity %': 87,
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp F°': 45.19,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.57},
#  {'City': 'Haapiti',
#   'Cloudiness %': 100,
#   'Country': 'PF',
#   'Humidity %': 73,
#   'Lat': -17.5667,
#   'Lng': -149.8667,
#   'Max Temp F°': 82.13,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.23},
#  {'City': 'Yumen',
#   'Cloudiness %': 51,
#   'Country': 'CN',
#   'Humidity %': 15,
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp F°': 77.22,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.61},
#  {'City': 'Constitucion',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 91,
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp F°': 50.49,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.13},
#  {'City': 'Baherden',
#   'Cloudiness %': 0,
#   'Country': 'TM',
#   'Humidity %': 20,
#   'Lat': 38.4362,
#   'Lng': 57.4316,
#   'Max Temp F°': 83.35,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.73},
#  {'City': 'Labrea',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 40,
#   'Lat': -7.2586,
#   'Lng': -64.7981,
#   'Max Temp F°': 78.75,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.95},
#  {'City': 'Naze',
#   'Cloudiness %': 99,
#   'Country': 'JP',
#   'Humidity %': 91,
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp F°': 85.12,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 17.47},
#  {'City': 'Yellowknife',
#   'Cloudiness %': 75,
#   'Country': 'CA',
#   'Humidity %': 55,
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp F°': 63.28,
#   'Weather Description': 'smoke',
#   'Wind Speed mph': 9.22},
#  {'City': 'Hervey Bay',
#   'Cloudiness %': 82,
#   'Country': 'AU',
#   'Humidity %': 58,
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp F°': 68.11,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.38},
#  {'City': 'Quatre Cocos',
#   'Cloudiness %': 71,
#   'Country': 'MU',
#   'Humidity %': 73,
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp F°': 68.11,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 14.05},
#  {'City': 'Port Elizabeth',
#   'Cloudiness %': 75,
#   'Country': 'ZA',
#   'Humidity %': 94,
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp F°': 61.09,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 10.36},
#  {'City': 'Ahipara',
#   'Cloudiness %': 29,
#   'Country': 'NZ',
#   'Humidity %': 83,
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp F°': 57.69,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 16.8},
#  {'City': 'Cape Town',
#   'Cloudiness %': 90,
#   'Country': 'ZA',
#   'Humidity %': 88,
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp F°': 54.12,
#   'Weather Description': 'fog',
#   'Wind Speed mph': 2.3},
#  {'City': 'Vestmannaeyjar',
#   'Cloudiness %': 27,
#   'Country': 'IS',
#   'Humidity %': 83,
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp F°': 54.79,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.07},
#  {'City': 'Healdsburg',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 47,
#   'Lat': 38.6105,
#   'Lng': -122.8692,
#   'Max Temp F°': 96.01,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 12.66},
#  {'City': 'Poitiers',
#   'Cloudiness %': 90,
#   'Country': 'FR',
#   'Humidity %': 51,
#   'Lat': 46.5833,
#   'Lng': 0.3333,
#   'Max Temp F°': 61.25,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Hilo',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 75,
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp F°': 82.13,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 12.66},
#  {'City': 'Garowe',
#   'Cloudiness %': 97,
#   'Country': 'SO',
#   'Humidity %': 66,
#   'Lat': 8.4054,
#   'Lng': 48.4845,
#   'Max Temp F°': 73.45,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 27.89},
#  {'City': 'Prince Rupert',
#   'Cloudiness %': 90,
#   'Country': 'CA',
#   'Humidity %': 94,
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp F°': 58.69,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 6.91},
#  {'City': 'Inhambane',
#   'Cloudiness %': 0,
#   'Country': 'MZ',
#   'Humidity %': 84,
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp F°': 64.78,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.04},
#  {'City': 'Nyurba',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 32,
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp F°': 69.21,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.47},
#  {'City': 'Kharan',
#   'Cloudiness %': 0,
#   'Country': 'PK',
#   'Humidity %': 16,
#   'Lat': 28.5833,
#   'Lng': 65.4167,
#   'Max Temp F°': 83.46,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.79},
#  {'City': 'Esperance',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 63,
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp F°': 55.44,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 12.64},
#  {'City': 'Pittsfield',
#   'Cloudiness %': 20,
#   'Country': 'US',
#   'Humidity %': 92,
#   'Lat': 42.4501,
#   'Lng': -73.2454,
#   'Max Temp F°': 68.76,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Arcata',
#   'Cloudiness %': 20,
#   'Country': 'US',
#   'Humidity %': 78,
#   'Lat': 40.8665,
#   'Lng': -124.0828,
#   'Max Temp F°': 68.2,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Placido De Castro',
#   'Cloudiness %': 0,
#   'Country': 'BR',
#   'Humidity %': 40,
#   'Lat': -10.3353,
#   'Lng': -67.1856,
#   'Max Temp F°': 75.76,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 1.45},
#  {'City': 'Baoding',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 73,
#   'Lat': 38.8511,
#   'Lng': 115.4903,
#   'Max Temp F°': 79.29,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 2.48},
#  {'City': 'Dauriya',
#   'Cloudiness %': 6,
#   'Country': 'RU',
#   'Humidity %': 54,
#   'Lat': 49.9333,
#   'Lng': 116.8667,
#   'Max Temp F°': 70.84,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.2},
#  {'City': 'Salalah',
#   'Cloudiness %': 90,
#   'Country': 'OM',
#   'Humidity %': 94,
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp F°': 78.89,
#   'Weather Description': 'light intensity drizzle',
#   'Wind Speed mph': 6.91},
#  {'City': 'Hirara',
#   'Cloudiness %': 75,
#   'Country': 'JP',
#   'Humidity %': 79,
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp F°': 89.87,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 13.8},
#  {'City': 'Longhua',
#   'Cloudiness %': 100,
#   'Country': 'CN',
#   'Humidity %': 93,
#   'Lat': 23.6137,
#   'Lng': 114.1919,
#   'Max Temp F°': 81.07,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 3.15},
#  {'City': 'Ribeira Grande',
#   'Cloudiness %': 17,
#   'Country': 'PT',
#   'Humidity %': 91,
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp F°': 73.49,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 13.89},
#  {'City': 'Nacala',
#   'Cloudiness %': 3,
#   'Country': 'MZ',
#   'Humidity %': 84,
#   'Lat': -14.5428,
#   'Lng': 40.6728,
#   'Max Temp F°': 68.85,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.61},
#  {'City': 'Longyearbyen',
#   'Cloudiness %': 75,
#   'Country': 'SJ',
#   'Humidity %': 87,
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp F°': 42.64,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.44},
#  {'City': 'Vostok',
#   'Cloudiness %': 94,
#   'Country': 'RU',
#   'Humidity %': 82,
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp F°': 74.84,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 4.32},
#  {'City': 'Sinegorye',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 96,
#   'Lat': 62.0788,
#   'Lng': 150.477,
#   'Max Temp F°': 39.42,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 7.23},
#  {'City': 'Chabahar',
#   'Cloudiness %': 14,
#   'Country': 'IR',
#   'Humidity %': 80,
#   'Lat': 25.2919,
#   'Lng': 60.643,
#   'Max Temp F°': 83.37,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4.27},
#  {'City': 'Padang',
#   'Cloudiness %': 100,
#   'Country': 'ID',
#   'Humidity %': 74,
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp F°': 80.65,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.33},
#  {'City': 'Lincoln',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 57,
#   'Lat': 40.8,
#   'Lng': -96.667,
#   'Max Temp F°': 86.29,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 1.01},
#  {'City': 'La Baule-Escoublac',
#   'Cloudiness %': 75,
#   'Country': 'FR',
#   'Humidity %': 86,
#   'Lat': 47.2922,
#   'Lng': -2.364,
#   'Max Temp F°': 62.26,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 16.11},
#  {'City': 'Ponta Do Sol',
#   'Cloudiness %': 47,
#   'Country': 'PT',
#   'Humidity %': 84,
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp F°': 77,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 2.21},
#  {'City': 'Pangnirtung',
#   'Cloudiness %': 100,
#   'Country': 'CA',
#   'Humidity %': 97,
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp F°': 40.91,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 8.5},
#  {'City': 'Preobrazheniye',
#   'Cloudiness %': 90,
#   'Country': 'RU',
#   'Humidity %': 76,
#   'Lat': 42.9019,
#   'Lng': 133.9064,
#   'Max Temp F°': 81.05,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.37},
#  {'City': 'Kutum',
#   'Cloudiness %': 63,
#   'Country': 'SD',
#   'Humidity %': 62,
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp F°': 75.51,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 13.27},
#  {'City': 'Luanda',
#   'Cloudiness %': 75,
#   'Country': 'AO',
#   'Humidity %': 88,
#   'Lat': -8.8368,
#   'Lng': 13.2343,
#   'Max Temp F°': 71.6,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.14},
#  {'City': 'Kapuskasing',
#   'Cloudiness %': 90,
#   'Country': 'CA',
#   'Humidity %': 88,
#   'Lat': 49.4169,
#   'Lng': -82.4331,
#   'Max Temp F°': 69.89,
#   'Weather Description': 'smoke',
#   'Wind Speed mph': 5.75},
#  {'City': 'Ostrovnoy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 81,
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp F°': 49.6,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.35},
#  {'City': 'Provideniya',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 58,
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp F°': 55.51,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 11.18},
#  {'City': 'Fare',
#   'Cloudiness %': 94,
#   'Country': 'PF',
#   'Humidity %': 70,
#   'Lat': -16.7,
#   'Lng': -151.0167,
#   'Max Temp F°': 78.89,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.28},
#  {'City': 'Port Blair',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 83,
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp F°': 82.29,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 20.27},
#  {'City': 'Hithadhoo',
#   'Cloudiness %': 86,
#   'Country': 'MV',
#   'Humidity %': 75,
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp F°': 80.24,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.03},
#  {'City': 'Alofi',
#   'Cloudiness %': 40,
#   'Country': 'NU',
#   'Humidity %': 69,
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp F°': 78.69,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 5.75},
#  {'City': 'Vila Franca Do Campo',
#   'Cloudiness %': 47,
#   'Country': 'PT',
#   'Humidity %': 91,
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp F°': 72.01,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 7.18},
#  {'City': 'Faya',
#   'Cloudiness %': 91,
#   'Country': 'SA',
#   'Humidity %': 66,
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp F°': 64.92,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.16},
#  {'City': 'Stroud',
#   'Cloudiness %': 92,
#   'Country': 'GB',
#   'Humidity %': 88,
#   'Lat': 51.75,
#   'Lng': -2.2,
#   'Max Temp F°': 60.71,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 11.1},
#  {'City': 'Saskylakh',
#   'Cloudiness %': 10,
#   'Country': 'RU',
#   'Humidity %': 43,
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp F°': 58.78,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 11.3},
#  {'City': 'Lompoc',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp F°': 77.68,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 20.71},
#  {'City': 'Coihaique',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 46,
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp F°': 49.95,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 11.5},
#  {'City': 'Atocha',
#   'Cloudiness %': 0,
#   'Country': 'BO',
#   'Humidity %': 17,
#   'Lat': -20.9333,
#   'Lng': -66.2333,
#   'Max Temp F°': 39.94,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.45},
#  {'City': 'Cidreira',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 91,
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp F°': 61.11,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 17.69},
#  {'City': 'La Cruz',
#   'Cloudiness %': 95,
#   'Country': 'MX',
#   'Humidity %': 78,
#   'Lat': 23.9167,
#   'Lng': -106.9,
#   'Max Temp F°': 86.47,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3},
#  {'City': 'Victoria',
#   'Cloudiness %': 100,
#   'Country': 'HK',
#   'Humidity %': 90,
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp F°': 84.38,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.99},
#  {'City': 'Bilibino',
#   'Cloudiness %': 9,
#   'Country': 'RU',
#   'Humidity %': 48,
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp F°': 67.24,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.37},
#  {'City': 'Santa Maria',
#   'Cloudiness %': 0,
#   'Country': 'BR',
#   'Humidity %': 100,
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp F°': 56.5,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.3},
#  {'City': 'Bima',
#   'Cloudiness %': 100,
#   'Country': 'ID',
#   'Humidity %': 62,
#   'Lat': -8.4667,
#   'Lng': 118.7167,
#   'Max Temp F°': 85.01,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.13},
#  {'City': 'Cherskiy',
#   'Cloudiness %': 38,
#   'Country': 'RU',
#   'Humidity %': 57,
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp F°': 59.56,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 3.96},
#  {'City': 'Tangshan',
#   'Cloudiness %': 4,
#   'Country': 'CN',
#   'Humidity %': 77,
#   'Lat': 39.6333,
#   'Lng': 118.1833,
#   'Max Temp F°': 76.48,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.41},
#  {'City': 'Ilo',
#   'Cloudiness %': 3,
#   'Country': 'PE',
#   'Humidity %': 83,
#   'Lat': -17.6394,
#   'Lng': -71.3375,
#   'Max Temp F°': 60.71,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.31},
#  {'City': 'Lavrentiya',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 93,
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp F°': 52.72,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.37},
#  {'City': 'Qaanaaq',
#   'Cloudiness %': 17,
#   'Country': 'GL',
#   'Humidity %': 65,
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp F°': 44.17,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.22},
#  {'City': 'Lookan',
#   'Cloudiness %': 90,
#   'Country': 'PH',
#   'Humidity %': 70,
#   'Lat': 5.037,
#   'Lng': 120.1027,
#   'Max Temp F°': 84.83,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.85},
#  {'City': 'Vila Velha',
#   'Cloudiness %': 20,
#   'Country': 'BR',
#   'Humidity %': 100,
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp F°': 62.55,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Khatanga',
#   'Cloudiness %': 11,
#   'Country': 'RU',
#   'Humidity %': 34,
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp F°': 68.49,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.55},
#  {'City': 'Fairbanks',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 46,
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp F°': 84.09,
#   'Weather Description': 'smoke',
#   'Wind Speed mph': 1.99},
#  {'City': 'Andra',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 94,
#   'Lat': 62.5147,
#   'Lng': 65.8878,
#   'Max Temp F°': 62.74,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.87},
#  {'City': 'Tiksi',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 84,
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp F°': 42.4,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 15.57},
#  {'City': 'Pevek',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 93,
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp F°': 39.4,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.08},
#  {'City': 'Bajmok',
#   'Cloudiness %': 14,
#   'Country': 'RS',
#   'Humidity %': 95,
#   'Lat': 45.9688,
#   'Lng': 19.4243,
#   'Max Temp F°': 56.32,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 8.75},
#  {'City': 'Altamira',
#   'Cloudiness %': 4,
#   'Country': 'BR',
#   'Humidity %': 60,
#   'Lat': -3.2033,
#   'Lng': -52.2064,
#   'Max Temp F°': 75.6,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.84},
#  {'City': 'Dustlik',
#   'Cloudiness %': 1,
#   'Country': 'UZ',
#   'Humidity %': 21,
#   'Lat': 40.5247,
#   'Lng': 68.0358,
#   'Max Temp F°': 74.66,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.21},
#  {'City': 'Caravelas',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 70,
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp F°': 71.02,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 10.4},
#  {'City': 'Atchison',
#   'Cloudiness %': 100,
#   'Country': 'US',
#   'Humidity %': 70,
#   'Lat': 39.563,
#   'Lng': -95.1216,
#   'Max Temp F°': 81.01,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 16.37},
#  {'City': 'Bengkulu',
#   'Cloudiness %': 22,
#   'Country': 'ID',
#   'Humidity %': 80,
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp F°': 78.3,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 2.66},
#  {'City': 'Mitsamiouli',
#   'Cloudiness %': 1,
#   'Country': 'KM',
#   'Humidity %': 69,
#   'Lat': -11.3847,
#   'Lng': 43.2844,
#   'Max Temp F°': 74.97,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.83},
#  {'City': 'Tilichiki',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 82,
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp F°': 49.96,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 26.55},
#  {'City': 'Lalganj',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 75,
#   'Lat': 25.8667,
#   'Lng': 85.1833,
#   'Max Temp F°': 80.55,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.55},
#  {'City': 'Durres',
#   'Cloudiness %': 100,
#   'Country': 'AL',
#   'Humidity %': 74,
#   'Lat': 41.3231,
#   'Lng': 19.4414,
#   'Max Temp F°': 77.18,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.73},
#  {'City': 'Zempoala',
#   'Cloudiness %': 50,
#   'Country': 'MX',
#   'Humidity %': 80,
#   'Lat': 19.45,
#   'Lng': -96.4167,
#   'Max Temp F°': 82.9,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.57},
#  {'City': 'Isaszeg',
#   'Cloudiness %': 90,
#   'Country': 'HU',
#   'Humidity %': 82,
#   'Lat': 47.5301,
#   'Lng': 19.4021,
#   'Max Temp F°': 62.11,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 16.11},
#  {'City': 'Inongo',
#   'Cloudiness %': 83,
#   'Country': 'CD',
#   'Humidity %': 48,
#   'Lat': -1.95,
#   'Lng': 18.2667,
#   'Max Temp F°': 72.84,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.63},
#  {'City': 'Lodja',
#   'Cloudiness %': 78,
#   'Country': 'CD',
#   'Humidity %': 47,
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp F°': 75.51,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 0.47},
#  {'City': 'Tutoia',
#   'Cloudiness %': 22,
#   'Country': 'BR',
#   'Humidity %': 82,
#   'Lat': -2.7619,
#   'Lng': -42.2744,
#   'Max Temp F°': 78.98,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 9.06},
#  {'City': 'Saint Anthony',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 71,
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp F°': 82.54,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3},
#  {'City': 'Bambous Virieux',
#   'Cloudiness %': 20,
#   'Country': 'MU',
#   'Humidity %': 64,
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp F°': 68.25,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 6.91},
#  {'City': 'Teya',
#   'Cloudiness %': 67,
#   'Country': 'RU',
#   'Humidity %': 53,
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp F°': 68.32,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.04},
#  {'City': 'Lhokseumawe',
#   'Cloudiness %': 99,
#   'Country': 'ID',
#   'Humidity %': 72,
#   'Lat': 5.1801,
#   'Lng': 97.1507,
#   'Max Temp F°': 79.16,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.63},
#  {'City': 'Mbandaka',
#   'Cloudiness %': 100,
#   'Country': 'CD',
#   'Humidity %': 48,
#   'Lat': 0.0487,
#   'Lng': 18.2603,
#   'Max Temp F°': 77.7,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.25},
#  {'City': 'Libreville',
#   'Cloudiness %': 20,
#   'Country': 'GA',
#   'Humidity %': 88,
#   'Lat': 0.3925,
#   'Lng': 9.4537,
#   'Max Temp F°': 77.02,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 8.05},
#  {'City': 'Bundaberg',
#   'Cloudiness %': 30,
#   'Country': 'AU',
#   'Humidity %': 40,
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp F°': 68.29,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 3.44},
#  {'City': 'Tura',
#   'Cloudiness %': 89,
#   'Country': 'IN',
#   'Humidity %': 94,
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp F°': 77.88,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.31},
#  {'City': 'Brufut',
#   'Cloudiness %': 75,
#   'Country': 'GM',
#   'Humidity %': 100,
#   'Lat': 13.3814,
#   'Lng': -16.7518,
#   'Max Temp F°': 73.49,
#   'Weather Description': 'thunderstorm',
#   'Wind Speed mph': 6.91},
#  {'City': 'Saldanha',
#   'Cloudiness %': 0,
#   'Country': 'ZA',
#   'Humidity %': 86,
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp F°': 44.65,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.8},
#  {'City': 'Narsaq',
#   'Cloudiness %': 100,
#   'Country': 'GL',
#   'Humidity %': 93,
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp F°': 48.42,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 1.07},
#  {'City': 'Palembang',
#   'Cloudiness %': 20,
#   'Country': 'ID',
#   'Humidity %': 89,
#   'Lat': -2.9167,
#   'Lng': 104.7458,
#   'Max Temp F°': 78.89,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 6.91},
#  {'City': 'Hualmay',
#   'Cloudiness %': 1,
#   'Country': 'PE',
#   'Humidity %': 82,
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp F°': 64.06,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.71},
#  {'City': 'Pennagaram',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 75,
#   'Lat': 12.1333,
#   'Lng': 77.9,
#   'Max Temp F°': 74.59,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.06},
#  {'City': 'Broome',
#   'Cloudiness %': 0,
#   'Country': 'US',
#   'Humidity %': 75,
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp F°': 68.58,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.35},
#  {'City': 'Zhigansk',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 45,
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp F°': 58.39,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.04},
#  {'City': 'Kaeo',
#   'Cloudiness %': 77,
#   'Country': 'NZ',
#   'Humidity %': 78,
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp F°': 61.32,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 13.96},
#  {'City': 'Norman Wells',
#   'Cloudiness %': 40,
#   'Country': 'CA',
#   'Humidity %': 52,
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp F°': 69.84,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 6.91},
#  {'City': 'Chardara',
#   'Cloudiness %': 19,
#   'Country': 'KZ',
#   'Humidity %': 31,
#   'Lat': 41.2547,
#   'Lng': 67.9692,
#   'Max Temp F°': 75.52,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 9.69},
#  {'City': 'Chernyshevsk',
#   'Cloudiness %': 10,
#   'Country': 'RU',
#   'Humidity %': 81,
#   'Lat': 52.5243,
#   'Lng': 117.0174,
#   'Max Temp F°': 65.19,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.68},
#  {'City': 'Severo-Kurilsk',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 64,
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp F°': 55.31,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 18.03},
#  {'City': 'Muros',
#   'Cloudiness %': 95,
#   'Country': 'ES',
#   'Humidity %': 87,
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp F°': 64.24,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.09},
#  {'City': 'Santa Rosalia',
#   'Cloudiness %': 0,
#   'Country': 'MX',
#   'Humidity %': 57,
#   'Lat': 27.3167,
#   'Lng': -112.2833,
#   'Max Temp F°': 88,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.26},
#  {'City': 'Aripuana',
#   'Cloudiness %': 34,
#   'Country': 'BR',
#   'Humidity %': 38,
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp F°': 77.05,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 2.46},
#  {'City': 'Mazatlan',
#   'Cloudiness %': 75,
#   'Country': 'MX',
#   'Humidity %': 78,
#   'Lat': 23.2167,
#   'Lng': -106.4167,
#   'Max Temp F°': 87.03,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.99},
#  {'City': 'Saint-Philippe',
#   'Cloudiness %': 49,
#   'Country': 'RE',
#   'Humidity %': 71,
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp F°': 65.75,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 9.17},
#  {'City': 'Shebalino',
#   'Cloudiness %': 98,
#   'Country': 'RU',
#   'Humidity %': 91,
#   'Lat': 51.2917,
#   'Lng': 85.6772,
#   'Max Temp F°': 54.99,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.48},
#  {'City': 'Kapiri Mposhi',
#   'Cloudiness %': 0,
#   'Country': 'ZM',
#   'Humidity %': 50,
#   'Lat': -13.9652,
#   'Lng': 28.6809,
#   'Max Temp F°': 52.83,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.43},
#  {'City': 'Gizo',
#   'Cloudiness %': 72,
#   'Country': 'SB',
#   'Humidity %': 68,
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp F°': 82.8,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 15.17},
#  {'City': 'Qunduz',
#   'Cloudiness %': 0,
#   'Country': 'AF',
#   'Humidity %': 20,
#   'Lat': 36.729,
#   'Lng': 68.857,
#   'Max Temp F°': 81.82,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.72},
#  {'City': 'Fianarantsoa',
#   'Cloudiness %': 50,
#   'Country': 'MG',
#   'Humidity %': 92,
#   'Lat': -21.4333,
#   'Lng': 47.0833,
#   'Max Temp F°': 47.26,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 2.3},
#  {'City': 'Gatehouse Of Fleet',
#   'Cloudiness %': 100,
#   'Country': 'GB',
#   'Humidity %': 94,
#   'Lat': 54.882,
#   'Lng': -4.1843,
#   'Max Temp F°': 59.81,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 9.71},
#  {'City': 'Tynda',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 97,
#   'Lat': 55.1667,
#   'Lng': 124.7167,
#   'Max Temp F°': 56.3,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.44},
#  {'City': 'Murray Bridge',
#   'Cloudiness %': 95,
#   'Country': 'AU',
#   'Humidity %': 62,
#   'Lat': -35.1167,
#   'Lng': 139.2667,
#   'Max Temp F°': 57.69,
# ...
#   'Humidity %': 83,
#   'Lat': 8.25,
#   'Lng': 34.5833,
#   'Max Temp F°': 69.51,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.38},
#  {'City': 'Mahon',
#   'Cloudiness %': 75,
#   'Country': 'ES',
#   'Humidity %': 94,
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp F°': 75.76,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.61},
#  {'City': 'Riyadh',
#   'Cloudiness %': 0,
#   'Country': 'SA',
#   'Humidity %': 13,
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp F°': 87.94,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 9.95},
#  {'City': 'Guerrero Negro',
#   'Cloudiness %': 20,
#   'Country': 'MX',
#   'Humidity %': 69,
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp F°': 75.94,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 15.08},
#  {'City': 'Santa Fe',
#   'Cloudiness %': 99,
#   'Country': 'AR',
#   'Humidity %': 77,
#   'Lat': -31.6333,
#   'Lng': -60.7,
#   'Max Temp F°': 62.01,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4},
#  {'City': 'Catuday',
#   'Cloudiness %': 100,
#   'Country': 'PH',
#   'Humidity %': 83,
#   'Lat': 16.2923,
#   'Lng': 119.8062,
#   'Max Temp F°': 81.61,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 24.7},
#  {'City': 'Magadan',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 62,
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp F°': 55.96,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.17},
#  {'City': 'Leczna',
#   'Cloudiness %': 90,
#   'Country': 'PL',
#   'Humidity %': 100,
#   'Lat': 51.3012,
#   'Lng': 22.8814,
#   'Max Temp F°': 62.91,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.22},
#  {'City': 'Itarema',
#   'Cloudiness %': 13,
#   'Country': 'BR',
#   'Humidity %': 80,
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp F°': 79.09,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 15.7},
#  {'City': 'Teguise',
#   'Cloudiness %': 90,
#   'Country': 'ES',
#   'Humidity %': 83,
#   'Lat': 29.0605,
#   'Lng': -13.564,
#   'Max Temp F°': 68.22,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Belize',
#   'Cloudiness %': 100,
#   'Country': 'BZ',
#   'Humidity %': 98,
#   'Lat': 17.25,
#   'Lng': -88.75,
#   'Max Temp F°': 83.25,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.55},
#  {'City': 'Kajaani',
#   'Cloudiness %': 0,
#   'Country': 'FI',
#   'Humidity %': 100,
#   'Lat': 64.2273,
#   'Lng': 27.7285,
#   'Max Temp F°': 41.05,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 1.14},
#  {'City': 'Mount Isa',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 26,
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp F°': 67.77,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 16.11},
#  {'City': 'Marsabit',
#   'Cloudiness %': 93,
#   'Country': 'KE',
#   'Humidity %': 71,
#   'Lat': 2.3284,
#   'Lng': 37.9899,
#   'Max Temp F°': 60.51,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 19.6},
#  {'City': 'Sevierville',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 66,
#   'Lat': 35.8681,
#   'Lng': -83.5618,
#   'Max Temp F°': 80.83,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Yabelo',
#   'Cloudiness %': 97,
#   'Country': 'ET',
#   'Humidity %': 60,
#   'Lat': 4.8833,
#   'Lng': 38.0833,
#   'Max Temp F°': 60.8,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 10.49},
#  {'City': 'Kahuta',
#   'Cloudiness %': 48,
#   'Country': 'PK',
#   'Humidity %': 78,
#   'Lat': 33.5913,
#   'Lng': 73.3868,
#   'Max Temp F°': 74.84,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 6.29},
#  {'City': 'Sovetskiy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 98,
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp F°': 61.25,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 8.48},
#  {'City': 'Bukama',
#   'Cloudiness %': 0,
#   'Country': 'CD',
#   'Humidity %': 34,
#   'Lat': -9.2,
#   'Lng': 25.85,
#   'Max Temp F°': 68.43,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.46},
#  {'City': 'Los Llanos De Aridane',
#   'Cloudiness %': 20,
#   'Country': 'ES',
#   'Humidity %': 96,
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp F°': 67.75,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 18.41},
#  {'City': 'Banda Aceh',
#   'Cloudiness %': 56,
#   'Country': 'ID',
#   'Humidity %': 70,
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp F°': 82.8,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 11.5},
#  {'City': 'Awbari',
#   'Cloudiness %': 0,
#   'Country': 'LY',
#   'Humidity %': 13,
#   'Lat': 26.5921,
#   'Lng': 12.7805,
#   'Max Temp F°': 86.79,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.2},
#  {'City': 'Olinda',
#   'Cloudiness %': 40,
#   'Country': 'BR',
#   'Humidity %': 94,
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp F°': 71.33,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 6.91},
#  {'City': 'Tecoanapa',
#   'Cloudiness %': 100,
#   'Country': 'MX',
#   'Humidity %': 86,
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp F°': 79.11,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.17},
#  {'City': 'Taltal',
#   'Cloudiness %': 0,
#   'Country': 'CL',
#   'Humidity %': 68,
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp F°': 59.13,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.87},
#  {'City': 'Adre',
#   'Cloudiness %': 100,
#   'Country': 'TD',
#   'Humidity %': 69,
#   'Lat': 13.4667,
#   'Lng': 22.2,
#   'Max Temp F°': 75.45,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.09},
#  {'City': 'Ouesso',
#   'Cloudiness %': 30,
#   'Country': 'CG',
#   'Humidity %': 81,
#   'Lat': 1.6136,
#   'Lng': 16.0517,
#   'Max Temp F°': 73.35,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 3.74},
#  {'City': 'Mpika',
#   'Cloudiness %': 0,
#   'Country': 'ZM',
#   'Humidity %': 53,
#   'Lat': -11.8343,
#   'Lng': 31.4529,
#   'Max Temp F°': 53.76,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.85},
#  {'City': 'Purpe',
#   'Cloudiness %': 64,
#   'Country': 'RU',
#   'Humidity %': 68,
#   'Lat': 64.4803,
#   'Lng': 76.6897,
#   'Max Temp F°': 67.33,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 10.56},
#  {'City': 'Portsmouth',
#   'Cloudiness %': 99,
#   'Country': 'GB',
#   'Humidity %': 88,
#   'Lat': 50.799,
#   'Lng': -1.0913,
#   'Max Temp F°': 63,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 10},
#  {'City': 'Lasa',
#   'Cloudiness %': 83,
#   'Country': 'IT',
#   'Humidity %': 85,
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp F°': 56.28,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.53},
#  {'City': 'Lebanon',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 68,
#   'Lat': 36.2081,
#   'Lng': -86.2911,
#   'Max Temp F°': 80.96,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 0},
#  {'City': 'Mount Darwin',
#   'Cloudiness %': 0,
#   'Country': 'ZW',
#   'Humidity %': 66,
#   'Lat': -16.7725,
#   'Lng': 31.5838,
#   'Max Temp F°': 51.03,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.06},
#  {'City': 'Alpena',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 73,
#   'Lat': 45.0617,
#   'Lng': -83.4327,
#   'Max Temp F°': 75.11,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.91},
#  {'City': 'Launceston',
#   'Cloudiness %': 83,
#   'Country': 'AU',
#   'Humidity %': 66,
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp F°': 58.6,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 8.01},
#  {'City': 'Ouadda',
#   'Cloudiness %': 100,
#   'Country': 'CF',
#   'Humidity %': 96,
#   'Lat': 8.0777,
#   'Lng': 22.4007,
#   'Max Temp F°': 67.98,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 2.19},
#  {'City': 'Bilgi',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 80,
#   'Lat': 16.35,
#   'Lng': 75.6167,
#   'Max Temp F°': 73.54,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 13.85},
#  {'City': 'Nioro',
#   'Cloudiness %': 93,
#   'Country': 'GM',
#   'Humidity %': 90,
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp F°': 76.69,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.63},
#  {'City': 'Montego Bay',
#   'Cloudiness %': 20,
#   'Country': 'JM',
#   'Humidity %': 74,
#   'Lat': 18.4712,
#   'Lng': -77.9188,
#   'Max Temp F°': 82.2,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.44},
#  {'City': 'Maykor',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 73,
#   'Lat': 59.0059,
#   'Lng': 55.88,
#   'Max Temp F°': 52.56,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.34},
#  {'City': 'Lewes',
#   'Cloudiness %': 98,
#   'Country': 'GB',
#   'Humidity %': 95,
#   'Lat': 50.8736,
#   'Lng': 0.0113,
#   'Max Temp F°': 62.94,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.99},
#  {'City': 'Tautira',
#   'Cloudiness %': 99,
#   'Country': 'PF',
#   'Humidity %': 75,
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp F°': 82.42,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.04},
#  {'City': 'Arkhangelsk',
#   'Cloudiness %': 90,
#   'Country': 'RU',
#   'Humidity %': 100,
#   'Lat': 64.5401,
#   'Lng': 40.5433,
#   'Max Temp F°': 35.71,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.24},
#  {'City': 'Muhlhausen',
#   'Cloudiness %': 65,
#   'Country': 'DE',
#   'Humidity %': 94,
#   'Lat': 51.2167,
#   'Lng': 10.45,
#   'Max Temp F°': 60.19,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.96},
#  {'City': 'Port Hardy',
#   'Cloudiness %': 40,
#   'Country': 'CA',
#   'Humidity %': 67,
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp F°': 62.78,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 14.97},
#  {'City': 'Wheatley',
#   'Cloudiness %': 75,
#   'Country': 'GB',
#   'Humidity %': 94,
#   'Lat': 51.7473,
#   'Lng': -1.1394,
#   'Max Temp F°': 61.07,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.61},
#  {'City': 'Kerman',
#   'Cloudiness %': 20,
#   'Country': 'IR',
#   'Humidity %': 30,
#   'Lat': 30.2832,
#   'Lng': 57.0788,
#   'Max Temp F°': 66.06,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4.61},
#  {'City': 'Buchanan',
#   'Cloudiness %': 100,
#   'Country': 'LR',
#   'Humidity %': 79,
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp F°': 76.32,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.44},
#  {'City': 'Samdrup Jongkhar',
#   'Cloudiness %': 93,
#   'Country': 'BT',
#   'Humidity %': 76,
#   'Lat': 26.9167,
#   'Lng': 91.6167,
#   'Max Temp F°': 77.4,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.77},
#  {'City': 'Ozernovskiy',
#   'Cloudiness %': 1,
#   'Country': 'RU',
#   'Humidity %': 71,
#   'Lat': 51.5,
#   'Lng': 156.5167,
#   'Max Temp F°': 52.81,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 20.07},
#  {'City': 'Labuhan',
#   'Cloudiness %': 87,
#   'Country': 'ID',
#   'Humidity %': 76,
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp F°': 80.64,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.45},
#  {'City': 'Moron',
#   'Cloudiness %': 0,
#   'Country': 'AR',
#   'Humidity %': 97,
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp F°': 55.15,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.55},
#  {'City': 'Huangmei',
#   'Cloudiness %': 16,
#   'Country': 'CN',
#   'Humidity %': 73,
#   'Lat': 30.1924,
#   'Lng': 116.025,
#   'Max Temp F°': 86.56,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4.7},
#  {'City': 'Dakar',
#   'Cloudiness %': 40,
#   'Country': 'SN',
#   'Humidity %': 86,
#   'Lat': 14.6937,
#   'Lng': -17.4441,
#   'Max Temp F°': 79.68,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 10.16},
#  {'City': 'San Cristobal',
#   'Cloudiness %': 92,
#   'Country': 'VE',
#   'Humidity %': 98,
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp F°': 75.38,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.97},
#  {'City': 'Cozumel',
#   'Cloudiness %': 75,
#   'Country': 'MX',
#   'Humidity %': 83,
#   'Lat': 20.5083,
#   'Lng': -86.9458,
#   'Max Temp F°': 86.11,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.01},
#  {'City': 'Sangar',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 29,
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp F°': 70.39,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.31},
#  {'City': 'Mlyniv',
#   'Cloudiness %': 4,
#   'Country': 'UA',
#   'Humidity %': 95,
#   'Lat': 50.509,
#   'Lng': 25.6168,
#   'Max Temp F°': 61.93,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.03},
#  {'City': 'Kilgore',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 65,
#   'Lat': 32.3863,
#   'Lng': -94.8758,
#   'Max Temp F°': 82.29,
#   'Weather Description': 'haze',
#   'Wind Speed mph': 6.91},
#  {'City': 'Rivadavia',
#   'Cloudiness %': 100,
#   'Country': 'AR',
#   'Humidity %': 34,
#   'Lat': -33.1905,
#   'Lng': -68.4608,
#   'Max Temp F°': 57.67,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.53},
#  {'City': 'Giyani',
#   'Cloudiness %': 0,
#   'Country': 'ZA',
#   'Humidity %': 47,
#   'Lat': -23.3025,
#   'Lng': 30.7187,
#   'Max Temp F°': 60.94,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.33},
#  {'City': 'Algarrobo',
#   'Cloudiness %': 37,
#   'Country': 'CO',
#   'Humidity %': 84,
#   'Lat': 10.1869,
#   'Lng': -74.5753,
#   'Max Temp F°': 80.94,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 8.79},
#  {'City': 'Mangai',
#   'Cloudiness %': 0,
#   'Country': 'CD',
#   'Humidity %': 37,
#   'Lat': -4.05,
#   'Lng': 19.5333,
#   'Max Temp F°': 72.01,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.01},
#  {'City': 'Bida',
#   'Cloudiness %': 100,
#   'Country': 'NG',
#   'Humidity %': 94,
#   'Lat': 9.0833,
#   'Lng': 6.0167,
#   'Max Temp F°': 72.57,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.26},
#  {'City': 'Koryazhma',
#   'Cloudiness %': 90,
#   'Country': 'RU',
#   'Humidity %': 80,
#   'Lat': 61.3143,
#   'Lng': 47.1691,
#   'Max Temp F°': 47.53,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 0.83},
#  {'City': 'Karratha',
#   'Cloudiness %': 46,
#   'Country': 'AU',
#   'Humidity %': 26,
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp F°': 70.54,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 26.17},
#  {'City': 'Bambanglipuro',
#   'Cloudiness %': 98,
#   'Country': 'ID',
#   'Humidity %': 78,
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp F°': 78.67,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.22},
#  {'City': 'Terrace',
#   'Cloudiness %': 75,
#   'Country': 'CA',
#   'Humidity %': 59,
#   'Lat': 54.5163,
#   'Lng': -128.6035,
#   'Max Temp F°': 66.11,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 20.71},
#  {'City': 'Santa Lucia',
#   'Cloudiness %': 40,
#   'Country': 'ES',
#   'Humidity %': 83,
#   'Lat': 27.9117,
#   'Lng': -15.5407,
#   'Max Temp F°': 63.77,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 24.16},
#  {'City': 'Karimganj',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 95,
#   'Lat': 24.8667,
#   'Lng': 92.35,
#   'Max Temp F°': 78.85,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.39},
#  {'City': 'Coolum Beach',
#   'Cloudiness %': 92,
#   'Country': 'AU',
#   'Humidity %': 57,
#   'Lat': -26.5333,
#   'Lng': 153.1,
#   'Max Temp F°': 68.34,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.33},
#  {'City': 'Winnemucca',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 4,
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp F°': 89.65,
#   'Weather Description': 'haze',
#   'Wind Speed mph': 27.63},
#  {'City': 'San Isidro',
#   'Cloudiness %': 90,
#   'Country': 'PE',
#   'Humidity %': 86,
#   'Lat': -12.1167,
#   'Lng': -77.05,
#   'Max Temp F°': 62.26,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Loandjili',
#   'Cloudiness %': 90,
#   'Country': 'CG',
#   'Humidity %': 88,
#   'Lat': -4.7561,
#   'Lng': 11.8578,
#   'Max Temp F°': 73.51,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.44},
#  {'City': 'Koslan',
#   'Cloudiness %': 90,
#   'Country': 'RU',
#   'Humidity %': 91,
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp F°': 48.92,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.06},
#  {'City': 'Boa Vista',
#   'Cloudiness %': 20,
#   'Country': 'BR',
#   'Humidity %': 74,
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp F°': 80.58,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 6.91}]

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp F°  Humidity %  \
# 0       Talnakh      RU  69.4865   88.3972        71.51          58
# 1       Manyana      BW -23.4000   21.7167        54.09          39
# 2        Bethel      US  41.3712  -73.4140        72.41          87
# 3        Albany      US  42.6001  -73.9662        72.21          81
# 4    Bredasdorp      ZA -34.5322   20.0403        54.28          94
# ..          ...     ...      ...       ...          ...         ...
# 715  Winnemucca      US  40.9730 -117.7357        89.65           4
# 716  San Isidro      PE -12.1167  -77.0500        62.26          86
# 717   Loandjili      CG  -4.7561   11.8578        73.51          88
# 718      Koslan      RU  63.4564   48.8989        48.92          91
# 719   Boa Vista      BR   2.8197  -60.6733        80.58          74
#
#      Cloudiness %  Wind Speed mph Weather Description
# 0             100            2.01     overcast clouds
# 1              20            6.96          few clouds
# 2               1            3.44           clear sky
# 3               0            2.80           clear sky
# 4              96            3.44     overcast clouds
# ..            ...             ...                 ...
# 715            75           27.63                haze
# 716            90            1.01     overcast clouds
# 717            90            3.44     overcast clouds
# 718            90            5.06     overcast clouds
# 719            20            6.91          few clouds
#
# [720 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
