# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json as json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
import requests
from datetime import datetime

import os
import sys

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"] 
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp F°": city_max_temp,
                          "Humidity %": city_humidity,
                          "Cloudiness %": city_clouds,
                          "Wind Speed mph": city_wind,
                          "Weather Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | blonduos
# City not found. Skipping...
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | satipo
# Processing Record 4 of Set 1 | juneau
# Processing Record 5 of Set 1 | adrar
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | lorengau
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | ust-maya
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | sinnamary
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | shakawe
# Processing Record 18 of Set 1 | the valley
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | nalut
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 1 | taybad
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | changping
# Processing Record 34 of Set 1 | oranjemund
# Processing Record 35 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 1 | zlatoustovsk
# City not found. Skipping...
# Processing Record 37 of Set 1 | sorland
# Processing Record 38 of Set 1 | chapais
# Processing Record 39 of Set 1 | smoky lake
# Processing Record 40 of Set 1 | pangnirtung
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | iwaki
# Processing Record 44 of Set 1 | omboue
# Processing Record 45 of Set 1 | ames
# Processing Record 46 of Set 1 | baoqing
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | aripuana
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | katsuura
# Processing Record 3 of Set 2 | cangzhou
# Processing Record 4 of Set 2 | grindavik
# Processing Record 5 of Set 2 | amga
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | dalian
# Processing Record 9 of Set 2 | takoradi
# Processing Record 10 of Set 2 | inuvik
# Processing Record 11 of Set 2 | luderitz
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | esperance
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | pokaran
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | jijiga
# Processing Record 18 of Set 2 | cabo san lucas
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | bawal
# Processing Record 21 of Set 2 | necochea
# Processing Record 22 of Set 2 | berlevag
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | rawson
# Processing Record 25 of Set 2 | beringovskiy
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | cazaje
# City not found. Skipping...
# Processing Record 31 of Set 2 | havre-saint-pierre
# Processing Record 32 of Set 2 | gawler
# Processing Record 33 of Set 2 | taltal
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | salmon arm
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | beloha
# Processing Record 39 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | san policarpo
# Processing Record 42 of Set 2 | pudozh
# Processing Record 43 of Set 2 | husavik
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | mitu
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | sal rei
# Processing Record 48 of Set 2 | perth
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | portel
# Processing Record 1 of Set 3 | maneadero
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | teya
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | eston
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | merauke
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 3 | miajadas
# Processing Record 12 of Set 3 | skelleftea
# Processing Record 13 of Set 3 | kulhudhuffushi
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 3 | asau
# Processing Record 17 of Set 3 | corn island
# Processing Record 18 of Set 3 | trapani
# Processing Record 19 of Set 3 | puertollano
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | jiaojiang
# Processing Record 23 of Set 3 | limoux
# Processing Record 24 of Set 3 | bandarbeyla
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 27 of Set 3 | faanui
# Processing Record 28 of Set 3 | gambo
# Processing Record 29 of Set 3 | yellowknife
# Processing Record 30 of Set 3 | mackay
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | porosozero
# Processing Record 35 of Set 3 | santiago del estero
# Processing Record 36 of Set 3 | bantou
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | constitucion
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | goderich
# Processing Record 41 of Set 3 | bathsheba
# Processing Record 42 of Set 3 | malmesbury
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | mufumbwe
# Processing Record 45 of Set 3 | cabedelo
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | san vicente
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | chara
# Processing Record 50 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 1 of Set 4 | koplik
# Processing Record 2 of Set 4 | san vicente de canete
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | north bend
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | jasper
# Processing Record 7 of Set 4 | sovetskiy
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | cap malheureux
# Processing Record 10 of Set 4 | wabash
# Processing Record 11 of Set 4 | jiazi
# Processing Record 12 of Set 4 | takaka
# Processing Record 13 of Set 4 | kuminskiy
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | crib point
# Processing Record 16 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 4 | cartaya
# Processing Record 19 of Set 4 | hermanus
# Processing Record 20 of Set 4 | praia
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | flamanzi
# Processing Record 24 of Set 4 | half moon bay
# Processing Record 25 of Set 4 | carbondale
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | saint-georges
# Processing Record 29 of Set 4 | coihaique
# Processing Record 30 of Set 4 | ngunguru
# Processing Record 31 of Set 4 | yarim
# Processing Record 32 of Set 4 | clyde river
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | nakasongola
# Processing Record 35 of Set 4 | ballina
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | mahroni
# Processing Record 39 of Set 4 | dalbandin
# Processing Record 40 of Set 4 | tigil
# Processing Record 41 of Set 4 | wewak
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | helong
# Processing Record 45 of Set 4 | sisimiut
# Processing Record 46 of Set 4 | sembakung
# Processing Record 47 of Set 4 | iberia
# Processing Record 48 of Set 4 | ripky
# Processing Record 49 of Set 4 | nishihara
# Processing Record 50 of Set 4 | prince albert
# Processing Record 1 of Set 5 | jingdezhen
# Processing Record 2 of Set 5 | atlantic beach
# Processing Record 3 of Set 5 | honiara
# Processing Record 4 of Set 5 | anchorage
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | watertown
# Processing Record 7 of Set 5 | ampanihy
# Processing Record 8 of Set 5 | bozdar
# Processing Record 9 of Set 5 | turbat
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | carbonia
# Processing Record 13 of Set 5 | teodoro sampaio
# Processing Record 14 of Set 5 | nome
# Processing Record 15 of Set 5 | esso
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 19 of Set 5 | san lorenzo
# Processing Record 20 of Set 5 | hirara
# Processing Record 21 of Set 5 | derzhavinsk
# Processing Record 22 of Set 5 | khash
# Processing Record 23 of Set 5 | angoram
# Processing Record 24 of Set 5 | kununurra
# Processing Record 25 of Set 5 | katobu
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | daru
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | banjar
# Processing Record 30 of Set 5 | america dourada
# Processing Record 31 of Set 5 | arica
# Processing Record 32 of Set 5 | nhulunbuy
# Processing Record 33 of Set 5 | nizhniy kuranakh
# Processing Record 34 of Set 5 | labuhan
# Processing Record 35 of Set 5 | asyut
# Processing Record 36 of Set 5 | liwale
# Processing Record 37 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 38 of Set 5 | saint-philippe
# Processing Record 39 of Set 5 | salalah
# Processing Record 40 of Set 5 | indramayu
# Processing Record 41 of Set 5 | abu samrah
# Processing Record 42 of Set 5 | northam
# Processing Record 43 of Set 5 | formosa
# Processing Record 44 of Set 5 | ambilobe
# Processing Record 45 of Set 5 | ambulu
# Processing Record 46 of Set 5 | shenjiamen
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 5 | vanavara
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | riachao das neves
# Processing Record 3 of Set 6 | saint-joseph
# Processing Record 4 of Set 6 | hauterive
# Processing Record 5 of Set 6 | leshukonskoye
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | bintulu
# Processing Record 8 of Set 6 | kamaishi
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | puerto leguizamo
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | sao joao da barra
# Processing Record 13 of Set 6 | samarai
# Processing Record 14 of Set 6 | gorontalo
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | hay river
# Processing Record 17 of Set 6 | kingman
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | kodiak
# Processing Record 20 of Set 6 | sola
# Processing Record 21 of Set 6 | ansbach
# Processing Record 22 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | road town
# Processing Record 25 of Set 6 | ayagoz
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | kahului
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | tiznit
# Processing Record 30 of Set 6 | marshall
# Processing Record 31 of Set 6 | mbandaka
# Processing Record 32 of Set 6 | roma
# Processing Record 33 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 6 | rio grande
# Processing Record 35 of Set 6 | egvekinot
# Processing Record 36 of Set 6 | serenje
# Processing Record 37 of Set 6 | havelock
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | watsa
# Processing Record 40 of Set 6 | kuusankoski
# Processing Record 41 of Set 6 | la paz
# Processing Record 42 of Set 6 | port blair
# Processing Record 43 of Set 6 | alpena
# Processing Record 44 of Set 6 | kailua
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | inverell
# Processing Record 47 of Set 6 | jacmel
# Processing Record 48 of Set 6 | tambura
# Processing Record 49 of Set 6 | nilanga
# Processing Record 50 of Set 6 | tuatapere
# Processing Record 1 of Set 7 | lata
# Processing Record 2 of Set 7 | yar-sale
# Processing Record 3 of Set 7 | gizo
# Processing Record 4 of Set 7 | mahon
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 7 | yagoua
# Processing Record 8 of Set 7 | zhoucheng
# Processing Record 9 of Set 7 | thunder bay
# Processing Record 10 of Set 7 | margate
# Processing Record 11 of Set 7 | mattru
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | saurimo
# Processing Record 14 of Set 7 | parrita
# Processing Record 15 of Set 7 | malanje
# Processing Record 16 of Set 7 | dunmore town
# Processing Record 17 of Set 7 | palana
# Processing Record 18 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 19 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 20 of Set 7 | vostok
# Processing Record 21 of Set 7 | paamiut
# Processing Record 22 of Set 7 | wanxian
# Processing Record 23 of Set 7 | nola
# Processing Record 24 of Set 7 | aklavik
# Processing Record 25 of Set 7 | alice springs
# Processing Record 26 of Set 7 | conakry
# Processing Record 27 of Set 7 | verkhnevilyuysk
# Processing Record 28 of Set 7 | hargeysa
# Processing Record 29 of Set 7 | yei
# Processing Record 30 of Set 7 | hakui
# Processing Record 31 of Set 7 | korla
# Processing Record 32 of Set 7 | tiksi
# Processing Record 33 of Set 7 | baculin
# Processing Record 34 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 7 | cedar city
# Processing Record 36 of Set 7 | namatanai
# Processing Record 37 of Set 7 | nabire
# Processing Record 38 of Set 7 | springbok
# Processing Record 39 of Set 7 | paragominas
# Processing Record 40 of Set 7 | qeshm
# Processing Record 41 of Set 7 | sakakah
# Processing Record 42 of Set 7 | tuktoyaktuk
# Processing Record 43 of Set 7 | nieuw amsterdam
# Processing Record 44 of Set 7 | aksarka
# Processing Record 45 of Set 7 | zabol
# Processing Record 46 of Set 7 | marsh harbour
# Processing Record 47 of Set 7 | kavaratti
# Processing Record 48 of Set 7 | san jose
# Processing Record 49 of Set 7 | torbay
# Processing Record 50 of Set 7 | bambous virieux
# Processing Record 1 of Set 8 | nanae
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | dawei
# Processing Record 4 of Set 8 | puerto ayacucho
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | oparino
# Processing Record 7 of Set 8 | vydrino
# Processing Record 8 of Set 8 | peniche
# Processing Record 9 of Set 8 | dezhou
# Processing Record 10 of Set 8 | yenagoa
# Processing Record 11 of Set 8 | xining
# Processing Record 12 of Set 8 | morada nova
# Processing Record 13 of Set 8 | kyabram
# Processing Record 14 of Set 8 | manali
# Processing Record 15 of Set 8 | chikwawa
# Processing Record 16 of Set 8 | rio branco
# Processing Record 17 of Set 8 | khor
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | ransang
# Processing Record 22 of Set 8 | swan hill
# Processing Record 23 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 8 | olafsvik
# Processing Record 25 of Set 8 | saint anthony
# Processing Record 26 of Set 8 | santiago
# Processing Record 27 of Set 8 | meulaboh
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | damietta
# Processing Record 30 of Set 8 | sao gabriel da cachoeira
# Processing Record 31 of Set 8 | sangar
# Processing Record 32 of Set 8 | apricena
# Processing Record 33 of Set 8 | gisborne
# Processing Record 34 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 8 | tual
# Processing Record 36 of Set 8 | sept-iles
# Processing Record 37 of Set 8 | uk
# City not found. Skipping...
# Processing Record 38 of Set 8 | alofi
# Processing Record 39 of Set 8 | nepomuceno
# Processing Record 40 of Set 8 | kirakira
# Processing Record 41 of Set 8 | saint george
# Processing Record 42 of Set 8 | salihorsk
# Processing Record 43 of Set 8 | bekwai
# Processing Record 44 of Set 8 | port lincoln
# Processing Record 45 of Set 8 | pangody
# Processing Record 46 of Set 8 | lavrentiya
# Processing Record 47 of Set 8 | la asuncion
# Processing Record 48 of Set 8 | dalvik
# Processing Record 49 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 8 | colac
# Processing Record 1 of Set 9 | pafos
# Processing Record 2 of Set 9 | nelson bay
# Processing Record 3 of Set 9 | mehran
# Processing Record 4 of Set 9 | rio gallegos
# Processing Record 5 of Set 9 | longonjo
# Processing Record 6 of Set 9 | sirjan
# Processing Record 7 of Set 9 | santa isabel do rio negro
# Processing Record 8 of Set 9 | villarrica
# Processing Record 9 of Set 9 | danville
# Processing Record 10 of Set 9 | gushikawa
# Processing Record 11 of Set 9 | abeokuta
# Processing Record 12 of Set 9 | acarau
# Processing Record 13 of Set 9 | souillac
# Processing Record 14 of Set 9 | marienburg
# Processing Record 15 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 9 | tiarei
# Processing Record 17 of Set 9 | kloulklubed
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | chicama
# Processing Record 20 of Set 9 | yeniseysk
# Processing Record 21 of Set 9 | avera
# Processing Record 22 of Set 9 | veraval
# Processing Record 23 of Set 9 | cockburn town
# Processing Record 24 of Set 9 | the pas
# Processing Record 25 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 9 | khani
# Processing Record 27 of Set 9 | dargaville
# Processing Record 28 of Set 9 | manado
# Processing Record 29 of Set 9 | maumere
# Processing Record 30 of Set 9 | bima
# Processing Record 31 of Set 9 | salinopolis
# Processing Record 32 of Set 9 | kamwenge
# Processing Record 33 of Set 9 | almaznyy
# Processing Record 34 of Set 9 | ilam
# Processing Record 35 of Set 9 | itarema
# Processing Record 36 of Set 9 | huarmey
# Processing Record 37 of Set 9 | verkhoyansk
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | beboto
# Processing Record 40 of Set 9 | sitka
# Processing Record 41 of Set 9 | shimoda
# Processing Record 42 of Set 9 | khuzhir
# Processing Record 43 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 9 | ust-nera
# Processing Record 45 of Set 9 | oistins
# Processing Record 46 of Set 9 | mehamn
# Processing Record 47 of Set 9 | matara
# Processing Record 48 of Set 9 | ketchikan
# Processing Record 49 of Set 9 | carson city
# Processing Record 50 of Set 9 | antalaha
# Processing Record 1 of Set 10 | aleksandrovka
# Processing Record 2 of Set 10 | kizilskoye
# Processing Record 3 of Set 10 | qasigiannguit
# Processing Record 4 of Set 10 | ancud
# Processing Record 5 of Set 10 | altay
# Processing Record 6 of Set 10 | lloro
# Processing Record 7 of Set 10 | puerto narino
# Processing Record 8 of Set 10 | saint-augustin
# Processing Record 9 of Set 10 | masaka
# Processing Record 10 of Set 10 | kiruna
# Processing Record 11 of Set 10 | baykit
# Processing Record 12 of Set 10 | leh
# Processing Record 13 of Set 10 | dzaoudzi
# Processing Record 14 of Set 10 | carauari
# Processing Record 15 of Set 10 | kalabo
# Processing Record 16 of Set 10 | mareeba
# Processing Record 17 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 10 | alamosa
# Processing Record 19 of Set 10 | peruibe
# Processing Record 20 of Set 10 | vrangel
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | westerland
# Processing Record 23 of Set 10 | dongkan
# Processing Record 24 of Set 10 | tynda
# Processing Record 25 of Set 10 | dalhousie
# Processing Record 26 of Set 10 | mongoumba
# Processing Record 27 of Set 10 | wenling
# Processing Record 28 of Set 10 | oktyabrskoye
# Processing Record 29 of Set 10 | pisco
# Processing Record 30 of Set 10 | aswan
# Processing Record 31 of Set 10 | gat
# Processing Record 32 of Set 10 | roblin
# Processing Record 33 of Set 10 | kalmunai
# Processing Record 34 of Set 10 | kollam
# Processing Record 35 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | jodiya
# Processing Record 38 of Set 10 | maragogi
# Processing Record 39 of Set 10 | kajaani
# Processing Record 40 of Set 10 | codrington
# Processing Record 41 of Set 10 | gorom-gorom
# Processing Record 42 of Set 10 | toumodi
# Processing Record 43 of Set 10 | guiratinga
# Processing Record 44 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 10 | liusha
# Processing Record 46 of Set 10 | rodniki
# Processing Record 47 of Set 10 | cururupu
# Processing Record 48 of Set 10 | chase
# Processing Record 49 of Set 10 | filadelfia
# Processing Record 50 of Set 10 | ahipara
# Processing Record 1 of Set 11 | barcelos
# Processing Record 2 of Set 11 | porto velho
# Processing Record 3 of Set 11 | nador
# Processing Record 4 of Set 11 | knokke-heist
# Processing Record 5 of Set 11 | hinton
# Processing Record 6 of Set 11 | yamethin
# Processing Record 7 of Set 11 | wallaceburg
# Processing Record 8 of Set 11 | komsomolskiy
# Processing Record 9 of Set 11 | yen bai
# Processing Record 10 of Set 11 | nesbyen
# Processing Record 11 of Set 11 | poso
# Processing Record 12 of Set 11 | bafoulabe
# Processing Record 13 of Set 11 | mountain home
# Processing Record 14 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 11 | blagodatnoye
# Processing Record 16 of Set 11 | kelvington
# Processing Record 17 of Set 11 | longyearbyen
# Processing Record 18 of Set 11 | porto nacional
# Processing Record 19 of Set 11 | atasu
# Processing Record 20 of Set 11 | choma
# Processing Record 21 of Set 11 | krasnokholm
# Processing Record 22 of Set 11 | vagur
# Processing Record 23 of Set 11 | alghero
# Processing Record 24 of Set 11 | oskarshamn
# Processing Record 25 of Set 11 | shu
# Processing Record 26 of Set 11 | iralaya
# Processing Record 27 of Set 11 | pindobacu
# Processing Record 28 of Set 11 | waipawa
# Processing Record 29 of Set 11 | belmonte
# Processing Record 30 of Set 11 | bardiyah
# Processing Record 31 of Set 11 | noumea
# Processing Record 32 of Set 11 | poum
# Processing Record 33 of Set 11 | ostrovnoy
# Processing Record 34 of Set 11 | zambezi
# Processing Record 35 of Set 11 | tabou
# Processing Record 36 of Set 11 | udachnyy
# Processing Record 37 of Set 11 | basco
# Processing Record 38 of Set 11 | san cristobal
# Processing Record 39 of Set 11 | raton
# Processing Record 40 of Set 11 | nanchang
# Processing Record 41 of Set 11 | askiz
# Processing Record 42 of Set 11 | bagdarin
# Processing Record 43 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 11 | dauphin
# Processing Record 45 of Set 11 | provideniya
# Processing Record 46 of Set 11 | flinders
# Processing Record 47 of Set 11 | aberdeen
# Processing Record 48 of Set 11 | peace river
# Processing Record 49 of Set 11 | meadow lake
# Processing Record 50 of Set 11 | tokur
# Processing Record 1 of Set 12 | san juan del sur
# Processing Record 2 of Set 12 | charters towers
# Processing Record 3 of Set 12 | quimperle
# Processing Record 4 of Set 12 | nanortalik
# Processing Record 5 of Set 12 | jalingo
# Processing Record 6 of Set 12 | baglung
# Processing Record 7 of Set 12 | solnechnyy
# Processing Record 8 of Set 12 | luena
# Processing Record 9 of Set 12 | berdigestyakh
# Processing Record 10 of Set 12 | magistralnyy
# Processing Record 11 of Set 12 | dobryatino
# Processing Record 12 of Set 12 | fare
# Processing Record 13 of Set 12 | macamic
# Processing Record 14 of Set 12 | surt
# Processing Record 15 of Set 12 | qaqortoq
# Processing Record 16 of Set 12 | ust-omchug
# Processing Record 17 of Set 12 | maceio
# Processing Record 18 of Set 12 | banapur
# Processing Record 19 of Set 12 | almonte
# Processing Record 20 of Set 12 | san ignacio
# Processing Record 21 of Set 12 | black diamond
# Processing Record 22 of Set 12 | wyszkow
# Processing Record 23 of Set 12 | magadan
# Processing Record 24 of Set 12 | mardin
# Processing Record 25 of Set 12 | pleasanton
# Processing Record 26 of Set 12 | concepcion
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | vredendal
# Processing Record 29 of Set 12 | pacific grove
# Processing Record 30 of Set 12 | kurilsk
# Processing Record 31 of Set 12 | wajima
# Processing Record 32 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 12 | zhenhai
# Processing Record 34 of Set 12 | bestobe
# Processing Record 35 of Set 12 | morgantown
# Processing Record 36 of Set 12 | mayumba
# Processing Record 37 of Set 12 | hambantota
# Processing Record 38 of Set 12 | tecoanapa
# Processing Record 39 of Set 12 | copiapo
# Processing Record 40 of Set 12 | ilo
# Processing Record 41 of Set 12 | aksha
# Processing Record 42 of Set 12 | hami
# Processing Record 43 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 44 of Set 12 | sawtell
# Processing Record 45 of Set 12 | aneho
# Processing Record 46 of Set 12 | itaituba
# Processing Record 47 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 12 | adre
# Processing Record 49 of Set 12 | sambava
# Processing Record 50 of Set 12 | kasongo-lunda
# Processing Record 1 of Set 13 | buala
# Processing Record 2 of Set 13 | sechura
# Processing Record 3 of Set 13 | agadir
# Processing Record 4 of Set 13 | marzuq
# Processing Record 5 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 6 of Set 13 | banamba
# Processing Record 7 of Set 13 | brewster
# Processing Record 8 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 13 | jumla
# Processing Record 10 of Set 13 | wawa
# Processing Record 11 of Set 13 | lasa
# Processing Record 12 of Set 13 | xuddur
# Processing Record 13 of Set 13 | hoa binh
# Processing Record 14 of Set 13 | orangeburg
# Processing Record 15 of Set 13 | gambela
# Processing Record 16 of Set 13 | independence
# Processing Record 17 of Set 13 | baisha
# Processing Record 18 of Set 13 | palasbari
# Processing Record 19 of Set 13 | rundu
# Processing Record 20 of Set 13 | general roca
# Processing Record 21 of Set 13 | debno
# Processing Record 22 of Set 13 | tilichiki
# Processing Record 23 of Set 13 | leninskoye
# Processing Record 24 of Set 13 | lebanon
# Processing Record 25 of Set 13 | gold coast
# Processing Record 26 of Set 13 | gunjur
# Processing Record 27 of Set 13 | wloszczowa
# Processing Record 28 of Set 13 | roald
# Processing Record 29 of Set 13 | cedral
# Processing Record 30 of Set 13 | back mountain
# Processing Record 31 of Set 13 | zhanaozen
# Processing Record 32 of Set 13 | barcelona
# Processing Record 33 of Set 13 | namie
# Processing Record 34 of Set 13 | shieli
# Processing Record 35 of Set 13 | menongue
# Processing Record 36 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 13 | tlapacoyan
# Processing Record 38 of Set 13 | ilulissat
# Processing Record 39 of Set 13 | muli
# Processing Record 40 of Set 13 | belyy yar
# Processing Record 41 of Set 13 | ukiah
# Processing Record 42 of Set 13 | kieta
# Processing Record 43 of Set 13 | vaitape
# Processing Record 44 of Set 13 | sharjah
# Processing Record 45 of Set 13 | abu dhabi
# Processing Record 46 of Set 13 | kysyl-syr
# Processing Record 47 of Set 13 | padilla
# Processing Record 48 of Set 13 | erdemli
# Processing Record 49 of Set 13 | saquarema
# Processing Record 50 of Set 13 | monrovia
# Processing Record 1 of Set 14 | yoichi
# Processing Record 2 of Set 14 | fairbanks
# Processing Record 3 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 14 | moussoro
# Processing Record 5 of Set 14 | smithers
# Processing Record 6 of Set 14 | evensk
# Processing Record 7 of Set 14 | panaba
# Processing Record 8 of Set 14 | puerto del rosario
# Processing Record 9 of Set 14 | uvira
# Processing Record 10 of Set 14 | washington
# Processing Record 11 of Set 14 | antofagasta
# Processing Record 12 of Set 14 | vicuna
# Processing Record 13 of Set 14 | mocuba
# Processing Record 14 of Set 14 | humberto de campos
# Processing Record 15 of Set 14 | berkak
# Processing Record 16 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 14 | ullapool
# Processing Record 18 of Set 14 | santa maria
# Processing Record 19 of Set 14 | tamiahua
# Processing Record 20 of Set 14 | taoudenni
# Processing Record 21 of Set 14 | dunedin
# Processing Record 22 of Set 14 | prince rupert
# Processing Record 23 of Set 14 | dwarka
# Processing Record 24 of Set 14 | aksu
# Processing Record 25 of Set 14 | harlingen
# Processing Record 26 of Set 14 | baruun-urt
# Processing Record 27 of Set 14 | zhangye
# Processing Record 28 of Set 14 | tlaltizapan
# Processing Record 29 of Set 14 | mae sai
# Processing Record 30 of Set 14 | sur
# Processing Record 31 of Set 14 | brae
# Processing Record 32 of Set 14 | ganzhou
# Processing Record 33 of Set 14 | koygorodok
# Processing Record 34 of Set 14 | isangel
# Processing Record 35 of Set 14 | muisne
# Processing Record 36 of Set 14 | voyvozh
# Processing Record 37 of Set 14 | dergachi
# Processing Record 38 of Set 14 | sosua
# Processing Record 39 of Set 14 | bedesa
# Processing Record 40 of Set 14 | yaan
# Processing Record 41 of Set 14 | lakes entrance
# Processing Record 42 of Set 14 | sorong
# Processing Record 43 of Set 14 | shirokiy
# Processing Record 44 of Set 14 | clarksburg
# Processing Record 45 of Set 14 | charleston
# Processing Record 46 of Set 14 | deputatskiy
# Processing Record 47 of Set 14 | santa rita
# Processing Record 48 of Set 14 | wilmington
# Processing Record 49 of Set 14 | monywa
# Processing Record 50 of Set 14 | moerai
# Processing Record 1 of Set 15 | san luis
# Processing Record 2 of Set 15 | effium
# Processing Record 3 of Set 15 | clifton
# Processing Record 4 of Set 15 | manavalakurichi
# Processing Record 5 of Set 15 | vadodara
# Processing Record 6 of Set 15 | stornoway
# Processing Record 7 of Set 15 | bairiki
# Processing Record 8 of Set 15 | tlahualilo
# City not found. Skipping...
# Processing Record 9 of Set 15 | quatre cocos
# Processing Record 10 of Set 15 | vila franca do campo
# Processing Record 11 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 15 | mahibadhoo
# Processing Record 14 of Set 15 | bengkalis
# City not found. Skipping...
# Processing Record 15 of Set 15 | biloela
# Processing Record 16 of Set 15 | novobirilyussy
# Processing Record 17 of Set 15 | san zenon
# Processing Record 18 of Set 15 | newport
# Processing Record 19 of Set 15 | yanam
# Processing Record 20 of Set 15 | port hedland
# Processing Record 21 of Set 15 | mount isa
# Processing Record 22 of Set 15 | aktau
# Processing Record 23 of Set 15 | santa rosa
# Processing Record 24 of Set 15 | little rock
# Processing Record 25 of Set 15 | skjervoy
# Processing Record 26 of Set 15 | arlit
# Processing Record 27 of Set 15 | klaksvik
# Processing Record 28 of Set 15 | kota belud
# Processing Record 29 of Set 15 | najran
# Processing Record 30 of Set 15 | scalea
# Processing Record 31 of Set 15 | halifax
# Processing Record 32 of Set 15 | balaguer
# Processing Record 33 of Set 15 | chegutu
# Processing Record 34 of Set 15 | harnosand
# Processing Record 35 of Set 15 | slave lake
# Processing Record 36 of Set 15 | vardo
# Processing Record 37 of Set 15 | belaya gora
# Processing Record 38 of Set 15 | inhambane
# Processing Record 39 of Set 15 | corralillo
# Processing Record 40 of Set 15 | flin flon
# Processing Record 41 of Set 15 | dauriya
# Processing Record 42 of Set 15 | weihai
# Processing Record 43 of Set 15 | kiunga
# Processing Record 44 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 15 | vila
# Processing Record 47 of Set 15 | lixourion
# Processing Record 48 of Set 15 | onega
# Processing Record 49 of Set 15 | igarka
# Processing Record 50 of Set 15 | vangaindrano
# Processing Record 1 of Set 16 | praya
# Processing Record 2 of Set 16 | sibolga
# Processing Record 3 of Set 16 | strezhevoy
# Processing Record 4 of Set 16 | port-gentil
# Processing Record 5 of Set 16 | milledgeville
# Processing Record 6 of Set 16 | gongzhuling
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#json.dumps(thing_to_be_printed, indent=4, sort_keys=True) iport p print
import pprint
pprint.pprint(city_data)
# Out:
# [{'City': 'Mar Del Plata',
#   'Cloudiness %': 90,
#   'Country': 'AR',
#   'Humidity %': 28,
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp F°': 57.09,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.99},
#  {'City': 'Satipo',
#   'Cloudiness %': 22,
#   'Country': 'PE',
#   'Humidity %': 62,
#   'Lat': -11.2522,
#   'Lng': -74.6386,
#   'Max Temp F°': 70.03,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 2.51},
#  {'City': 'Juneau',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 72,
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp F°': 67.84,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 6.91},
#  {'City': 'Adrar',
#   'Cloudiness %': 90,
#   'Country': 'MR',
#   'Humidity %': 16,
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp F°': 91.17,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.7},
#  {'City': 'Butaritari',
#   'Cloudiness %': 11,
#   'Country': 'KI',
#   'Humidity %': 64,
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp F°': 83.34,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Lorengau',
#   'Cloudiness %': 28,
#   'Country': 'PG',
#   'Humidity %': 68,
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp F°': 85.78,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 9.17},
#  {'City': 'Rikitea',
#   'Cloudiness %': 66,
#   'Country': 'PF',
#   'Humidity %': 74,
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp F°': 74.3,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 15.23},
#  {'City': 'Avarua',
#   'Cloudiness %': 72,
#   'Country': 'CK',
#   'Humidity %': 65,
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp F°': 77.05,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.75},
#  {'City': 'Ust-Maya',
#   'Cloudiness %': 99,
#   'Country': 'RU',
#   'Humidity %': 39,
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp F°': 69.03,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.73},
#  {'City': 'East London',
#   'Cloudiness %': 3,
#   'Country': 'ZA',
#   'Humidity %': 89,
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp F°': 63.03,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.63},
#  {'City': 'Sinnamary',
#   'Cloudiness %': 39,
#   'Country': 'GF',
#   'Humidity %': 86,
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp F°': 77.2,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.88},
#  {'City': 'Iqaluit',
#   'Cloudiness %': 100,
#   'Country': 'CA',
#   'Humidity %': 96,
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp F°': 37.53,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 15.59},
#  {'City': 'Albany',
#   'Cloudiness %': 0,
#   'Country': 'US',
#   'Humidity %': 81,
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp F°': 72.21,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.8},
#  {'City': 'Qaanaaq',
#   'Cloudiness %': 17,
#   'Country': 'GL',
#   'Humidity %': 65,
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp F°': 44.17,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.22},
#  {'City': 'Barrow',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp F°': 39.22,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 19.57},
#  {'City': 'Shakawe',
#   'Cloudiness %': 0,
#   'Country': 'BW',
#   'Humidity %': 33,
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp F°': 54.68,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.56},
#  {'City': 'The Valley',
#   'Cloudiness %': 2,
#   'Country': 'AI',
#   'Humidity %': 75,
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp F°': 82.81,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 17.52},
#  {'City': 'Nikolskoye',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 80,
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp F°': 58.78,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.71},
#  {'City': 'Lebu',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 85,
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp F°': 51.31,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 10.31},
#  {'City': 'Jamestown',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 73,
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp F°': 72.72,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.1},
#  {'City': 'Nalut',
#   'Cloudiness %': 0,
#   'Country': 'LY',
#   'Humidity %': 13,
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp F°': 88.14,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.7},
#  {'City': 'Hithadhoo',
#   'Cloudiness %': 86,
#   'Country': 'MV',
#   'Humidity %': 75,
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp F°': 80.24,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.03},
#  {'City': 'Kapaa',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp F°': 84.18,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 5.01},
#  {'City': 'Taybad',
#   'Cloudiness %': 0,
#   'Country': 'IR',
#   'Humidity %': 20,
#   'Lat': 34.74,
#   'Lng': 60.7756,
#   'Max Temp F°': 78.24,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 14.81},
#  {'City': 'Bluff',
#   'Cloudiness %': 43,
#   'Country': 'NZ',
#   'Humidity %': 70,
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp F°': 50.81,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 13.58},
#  {'City': 'Georgetown',
#   'Cloudiness %': 20,
#   'Country': 'MY',
#   'Humidity %': 75,
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp F°': 82.89,
#   'Weather Description': 'thunderstorm',
#   'Wind Speed mph': 1.99},
#  {'City': 'Tasiilaq',
#   'Cloudiness %': 0,
#   'Country': 'GL',
#   'Humidity %': 77,
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp F°': 37.24,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.91},
#  {'City': 'Cape Town',
#   'Cloudiness %': 0,
#   'Country': 'ZA',
#   'Humidity %': 85,
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp F°': 54.12,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.62},
#  {'City': 'Changping',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 51,
#   'Lat': 40.2186,
#   'Lng': 116.2197,
#   'Max Temp F°': 76.64,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.84},
#  {'City': 'Oranjemund',
#   'Cloudiness %': 0,
#   'Country': 'NA',
#   'Humidity %': 78,
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp F°': 53.6,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 1.05},
#  {'City': 'Sorland',
#   'Cloudiness %': 100,
#   'Country': 'NO',
#   'Humidity %': 86,
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp F°': 54.46,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.72},
#  {'City': 'Chapais',
#   'Cloudiness %': 73,
#   'Country': 'CA',
#   'Humidity %': 95,
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp F°': 62.74,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 8.32},
#  {'City': 'Smoky Lake',
#   'Cloudiness %': 70,
#   'Country': 'CA',
#   'Humidity %': 25,
#   'Lat': 54.1169,
#   'Lng': -112.4686,
#   'Max Temp F°': 86.49,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 7.02},
#  {'City': 'Pangnirtung',
#   'Cloudiness %': 100,
#   'Country': 'CA',
#   'Humidity %': 97,
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp F°': 40.91,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 8.5},
#  {'City': 'Ushuaia',
#   'Cloudiness %': 40,
#   'Country': 'AR',
#   'Humidity %': 65,
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp F°': 38.86,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 5.75},
#  {'City': 'Vaini',
#   'Cloudiness %': 20,
#   'Country': 'TO',
#   'Humidity %': 78,
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp F°': 77.16,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Iwaki',
#   'Cloudiness %': 15,
#   'Country': 'JP',
#   'Humidity %': 65,
#   'Lat': 37.05,
#   'Lng': 140.8833,
#   'Max Temp F°': 91.76,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Omboue',
#   'Cloudiness %': 4,
#   'Country': 'GA',
#   'Humidity %': 84,
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp F°': 74.28,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.35},
#  {'City': 'Ames',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 80,
#   'Lat': 42.0347,
#   'Lng': -93.6199,
#   'Max Temp F°': 79.11,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.75},
#  {'City': 'Baoqing',
#   'Cloudiness %': 100,
#   'Country': 'CN',
#   'Humidity %': 46,
#   'Lat': 46.3317,
#   'Lng': 132.2111,
#   'Max Temp F°': 84.72,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 8.88},
#  {'City': 'Punta Arenas',
#   'Cloudiness %': 90,
#   'Country': 'CL',
#   'Humidity %': 87,
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp F°': 39.31,
#   'Weather Description': 'light intensity shower rain',
#   'Wind Speed mph': 8.05},
#  {'City': 'Castro',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 90,
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp F°': 50.31,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.62},
#  {'City': 'Aripuana',
#   'Cloudiness %': 34,
#   'Country': 'BR',
#   'Humidity %': 38,
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp F°': 77.05,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 2.46},
#  {'City': 'Dikson',
#   'Cloudiness %': 3,
#   'Country': 'RU',
#   'Humidity %': 89,
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp F°': 51.37,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.59},
#  {'City': 'Port Alfred',
#   'Cloudiness %': 24,
#   'Country': 'ZA',
#   'Humidity %': 88,
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp F°': 61.48,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 10.11},
#  {'City': 'Katsuura',
#   'Cloudiness %': 73,
#   'Country': 'JP',
#   'Humidity %': 74,
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp F°': 87.91,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 9.75},
#  {'City': 'Cangzhou',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 71,
#   'Lat': 38.3167,
#   'Lng': 116.8667,
#   'Max Temp F°': 81.19,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 0.83},
#  {'City': 'Grindavik',
#   'Cloudiness %': 51,
#   'Country': 'IS',
#   'Humidity %': 100,
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp F°': 53.91,
#   'Weather Description': 'fog',
#   'Wind Speed mph': 6.91},
#  {'City': 'Amga',
#   'Cloudiness %': 93,
#   'Country': 'RU',
#   'Humidity %': 45,
#   'Lat': 60.8953,
#   'Lng': 131.9608,
#   'Max Temp F°': 72.99,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.8},
#  {'City': 'Lagoa',
#   'Cloudiness %': 8,
#   'Country': 'PT',
#   'Humidity %': 93,
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp F°': 72.7,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 20.04},
#  {'City': 'Mataura',
#   'Cloudiness %': 77,
#   'Country': 'NZ',
#   'Humidity %': 71,
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp F°': 50.49,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 2.53},
#  {'City': 'Dalian',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 69,
#   'Lat': 38.9122,
#   'Lng': 121.6022,
#   'Max Temp F°': 80.53,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.47},
#  {'City': 'Takoradi',
#   'Cloudiness %': 25,
#   'Country': 'GH',
#   'Humidity %': 87,
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp F°': 75,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 6.96},
#  {'City': 'Inuvik',
#   'Cloudiness %': 49,
#   'Country': 'CA',
#   'Humidity %': 44,
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp F°': 62.01,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 18.84},
#  {'City': 'Luderitz',
#   'Cloudiness %': 37,
#   'Country': 'NA',
#   'Humidity %': 69,
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp F°': 55.81,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.97},
#  {'City': 'Ribeira Grande',
#   'Cloudiness %': 17,
#   'Country': 'PT',
#   'Humidity %': 91,
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp F°': 73.49,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 13.89},
#  {'City': 'Esperance',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 63,
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp F°': 55.44,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 12.64},
#  {'City': 'Airai',
#   'Cloudiness %': 62,
#   'Country': 'TL',
#   'Humidity %': 43,
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp F°': 68.36,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.68},
#  {'City': 'Pokaran',
#   'Cloudiness %': 6,
#   'Country': 'IN',
#   'Humidity %': 62,
#   'Lat': 26.9167,
#   'Lng': 71.9167,
#   'Max Temp F°': 84.58,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 12.28},
#  {'City': 'Jijiga',
#   'Cloudiness %': 100,
#   'Country': 'ET',
#   'Humidity %': 64,
#   'Lat': 9.35,
#   'Lng': 42.8,
#   'Max Temp F°': 63.81,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 19.06},
#  {'City': 'Cabo San Lucas',
#   'Cloudiness %': 75,
#   'Country': 'MX',
#   'Humidity %': 75,
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp F°': 86.5,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Kaitangata',
#   'Cloudiness %': 2,
#   'Country': 'NZ',
#   'Humidity %': 68,
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp F°': 52.93,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.31},
#  {'City': 'Bawal',
#   'Cloudiness %': 14,
#   'Country': 'IN',
#   'Humidity %': 74,
#   'Lat': 28.0833,
#   'Lng': 76.5833,
#   'Max Temp F°': 88.83,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 1.83},
#  {'City': 'Necochea',
#   'Cloudiness %': 0,
#   'Country': 'AR',
#   'Humidity %': 80,
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp F°': 53.33,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 13.73},
#  {'City': 'Berlevag',
#   'Cloudiness %': 100,
#   'Country': 'NO',
#   'Humidity %': 85,
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp F°': 50.81,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.34},
#  {'City': 'Port Elizabeth',
#   'Cloudiness %': 7,
#   'Country': 'ZA',
#   'Humidity %': 90,
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp F°': 58.1,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.86},
#  {'City': 'Rawson',
#   'Cloudiness %': 99,
#   'Country': 'AR',
#   'Humidity %': 38,
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp F°': 60.67,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.86},
#  {'City': 'Beringovskiy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 84,
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp F°': 49.59,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.81},
#  {'City': 'Carnarvon',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 31,
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp F°': 66.27,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 18.41},
#  {'City': 'Bredasdorp',
#   'Cloudiness %': 96,
#   'Country': 'ZA',
#   'Humidity %': 96,
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp F°': 54.28,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.54},
#  {'City': 'Guerrero Negro',
#   'Cloudiness %': 20,
#   'Country': 'MX',
#   'Humidity %': 69,
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp F°': 75.94,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 15.08},
#  {'City': 'Mahebourg',
#   'Cloudiness %': 84,
#   'Country': 'MU',
#   'Humidity %': 72,
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp F°': 65.25,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 13.33},
#  {'City': 'Havre-Saint-Pierre',
#   'Cloudiness %': 100,
#   'Country': 'CA',
#   'Humidity %': 87,
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp F°': 61.25,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.64},
#  {'City': 'Gawler',
#   'Cloudiness %': 96,
#   'Country': 'AU',
#   'Humidity %': 94,
#   'Lat': -34.6,
#   'Lng': 138.7333,
#   'Max Temp F°': 56.46,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.4},
#  {'City': 'Taltal',
#   'Cloudiness %': 0,
#   'Country': 'CL',
#   'Humidity %': 68,
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp F°': 59.13,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.87},
#  {'City': 'Hobart',
#   'Cloudiness %': 75,
#   'Country': 'AU',
#   'Humidity %': 51,
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp F°': 60.06,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.99},
#  {'City': 'Salmon Arm',
#   'Cloudiness %': 93,
#   'Country': 'CA',
#   'Humidity %': 12,
#   'Lat': 50.6998,
#   'Lng': -119.3024,
#   'Max Temp F°': 97.23,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.71},
#  {'City': 'Caravelas',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 70,
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp F°': 71.02,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 10.4},
#  {'City': 'Beloha',
#   'Cloudiness %': 0,
#   'Country': 'MG',
#   'Humidity %': 63,
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp F°': 62.65,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.55},
#  {'City': 'San Policarpo',
#   'Cloudiness %': 100,
#   'Country': 'PH',
#   'Humidity %': 61,
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp F°': 86.94,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.17},
#  {'City': 'Pudozh',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 72,
#   'Lat': 61.8099,
#   'Lng': 36.5345,
#   'Max Temp F°': 53.51,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.12},
#  {'City': 'Husavik',
#   'Cloudiness %': 61,
#   'Country': 'IS',
#   'Humidity %': 90,
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp F°': 50.05,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 2.98},
#  {'City': 'Busselton',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 76,
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp F°': 49.05,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.89},
#  {'City': 'Mitu',
#   'Cloudiness %': 96,
#   'Country': 'CO',
#   'Humidity %': 99,
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp F°': 68.86,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.52},
#  {'City': 'Puerto Ayora',
#   'Cloudiness %': 57,
#   'Country': 'EC',
#   'Humidity %': 89,
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp F°': 70.56,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3},
#  {'City': 'Sal Rei',
#   'Cloudiness %': 100,
#   'Country': 'CV',
#   'Humidity %': 86,
#   'Lat': 16.1833,
#   'Lng': -22.9167,
#   'Max Temp F°': 75.76,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 13.2},
#  {'City': 'Perth',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 64,
#   'Lat': -31.9333,
#   'Lng': 115.8333,
#   'Max Temp F°': 58.08,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.05},
#  {'City': 'Cidreira',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 91,
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp F°': 61.11,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 17.69},
#  {'City': 'Portel',
#   'Cloudiness %': 99,
#   'Country': 'BR',
#   'Humidity %': 66,
#   'Lat': -1.9356,
#   'Lng': -50.8211,
#   'Max Temp F°': 78.87,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.22},
#  {'City': 'Maneadero',
#   'Cloudiness %': 22,
#   'Country': 'MX',
#   'Humidity %': 78,
#   'Lat': 31.7167,
#   'Lng': -116.5667,
#   'Max Temp F°': 75.18,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3},
#  {'City': 'Teya',
#   'Cloudiness %': 67,
#   'Country': 'RU',
#   'Humidity %': 53,
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp F°': 68.32,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.04},
#  {'City': 'Saskylakh',
#   'Cloudiness %': 10,
#   'Country': 'RU',
#   'Humidity %': 43,
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp F°': 58.78,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 11.3},
#  {'City': 'Eston',
#   'Cloudiness %': 0,
#   'Country': 'CA',
#   'Humidity %': 25,
#   'Lat': 51.1501,
#   'Lng': -108.7514,
#   'Max Temp F°': 85.93,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.03},
#  {'City': 'Cherskiy',
#   'Cloudiness %': 38,
#   'Country': 'RU',
#   'Humidity %': 57,
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp F°': 59.56,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 3.96},
#  {'City': 'Upernavik',
#   'Cloudiness %': 38,
#   'Country': 'GL',
#   'Humidity %': 70,
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp F°': 43.9,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 5.37},
#  {'City': 'Merauke',
#   'Cloudiness %': 97,
#   'Country': 'ID',
#   'Humidity %': 68,
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp F°': 80.1,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 10.58},
#  {'City': 'Norman Wells',
#   'Cloudiness %': 16,
#   'Country': 'CA',
#   'Humidity %': 44,
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp F°': 75.47,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 1.95},
#  {'City': 'Miajadas',
#   'Cloudiness %': 0,
#   'Country': 'ES',
#   'Humidity %': 63,
#   'Lat': 39.1513,
#   'Lng': -5.9084,
#   'Max Temp F°': 73.78,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.7},
#  {'City': 'Skelleftea',
#   'Cloudiness %': 100,
#   'Country': 'SE',
#   'Humidity %': 81,
#   'Lat': 64.7507,
#   'Lng': 20.9528,
#   'Max Temp F°': 50.36,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.3},
#  {'City': 'Kulhudhuffushi',
#   'Cloudiness %': 100,
#   'Country': 'MV',
#   'Humidity %': 79,
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp F°': 81.37,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 13.8},
#  {'City': 'Cayenne',
#   'Cloudiness %': 75,
#   'Country': 'GF',
#   'Humidity %': 81,
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp F°': 81.09,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Asau',
#   'Cloudiness %': 100,
#   'Country': 'RO',
#   'Humidity %': 97,
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp F°': 64.4,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.59},
#  {'City': 'Corn Island',
#   'Cloudiness %': 16,
#   'Country': 'NI',
#   'Humidity %': 81,
#   'Lat': 12.1694,
#   'Lng': -83.0418,
#   'Max Temp F°': 82.08,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.5},
#  {'City': 'Trapani',
#   'Cloudiness %': 12,
#   'Country': 'IT',
#   'Humidity %': 48,
#   'Lat': 37.8333,
#   'Lng': 12.6667,
#   'Max Temp F°': 76.93,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4.74},
#  {'City': 'Puertollano',
#   'Cloudiness %': 0,
#   'Country': 'ES',
#   'Humidity %': 25,
#   'Lat': 38.6871,
#   'Lng': -4.1073,
#   'Max Temp F°': 77.16,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.07},
#  {'City': 'Thompson',
#   'Cloudiness %': 45,
#   'Country': 'CA',
#   'Humidity %': 34,
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp F°': 68.72,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 3.6},
#  {'City': 'New Norfolk',
#   'Cloudiness %': 86,
#   'Country': 'AU',
#   'Humidity %': 58,
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp F°': 59.72,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.01},
#  {'City': 'Jiaojiang',
#   'Cloudiness %': 56,
#   'Country': 'CN',
#   'Humidity %': 85,
#   'Lat': 28.6803,
#   'Lng': 121.4428,
#   'Max Temp F°': 84.99,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 3.87},
#  {'City': 'Limoux',
#   'Cloudiness %': 75,
#   'Country': 'FR',
#   'Humidity %': 52,
#   'Lat': 42.9167,
#   'Lng': 2.1667,
#   'Max Temp F°': 66.54,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.7},
#  {'City': 'Bandarbeyla',
#   'Cloudiness %': 100,
#   'Country': 'SO',
#   'Humidity %': 72,
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp F°': 77.31,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 27.07},
#  {'City': 'Chuy',
#   'Cloudiness %': 60,
#   'Country': 'UY',
#   'Humidity %': 94,
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp F°': 56.64,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 10.36},
#  {'City': 'Faanui',
#   'Cloudiness %': 99,
#   'Country': 'PF',
#   'Humidity %': 71,
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp F°': 79.16,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.41},
#  {'City': 'Gambo',
#   'Cloudiness %': 100,
#   'Country': 'CF',
#   'Humidity %': 98,
#   'Lat': 4.6482,
#   'Lng': 22.2633,
#   'Max Temp F°': 70.39,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.12},
#  {'City': 'Yellowknife',
#   'Cloudiness %': 100,
#   'Country': 'CA',
#   'Humidity %': 50,
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp F°': 63.28,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3},
#  {'City': 'Mackay',
#   'Cloudiness %': 100,
#   'Country': 'AU',
#   'Humidity %': 54,
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp F°': 71.69,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 15.1},
#  {'City': 'Bethel',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 86,
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp F°': 72.99,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.44},
#  {'City': 'Pevek',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 93,
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp F°': 39.4,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.08},
#  {'City': 'Touros',
#   'Cloudiness %': 53,
#   'Country': 'BR',
#   'Humidity %': 83,
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp F°': 76.1,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 15.59},
#  {'City': 'Porosozero',
#   'Cloudiness %': 68,
#   'Country': 'RU',
#   'Humidity %': 71,
#   'Lat': 62.7191,
#   'Lng': 32.727,
#   'Max Temp F°': 51.76,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.06},
#  {'City': 'Santiago Del Estero',
#   'Cloudiness %': 0,
#   'Country': 'AR',
#   'Humidity %': 26,
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp F°': 53.8,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.78},
#  {'City': 'Bantou',
#   'Cloudiness %': 100,
#   'Country': 'CN',
#   'Humidity %': 98,
#   'Lat': 26.2151,
#   'Lng': 117.4893,
#   'Max Temp F°': 76.66,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.97},
#  {'City': 'Constitucion',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 91,
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp F°': 50.49,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.13},
#  {'City': 'Atuona',
#   'Cloudiness %': 17,
#   'Country': 'PF',
#   'Humidity %': 73,
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp F°': 77.97,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 13.38},
#  {'City': 'Goderich',
#   'Cloudiness %': 6,
#   'Country': 'CA',
#   'Humidity %': 69,
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp F°': 73.9,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 9.44},
#  {'City': 'Bathsheba',
#   'Cloudiness %': 75,
#   'Country': 'BB',
#   'Humidity %': 83,
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp F°': 81.21,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 11.5},
#  {'City': 'Malmesbury',
#   'Cloudiness %': 0,
#   'Country': 'ZA',
#   'Humidity %': 89,
#   'Lat': -33.4608,
#   'Lng': 18.7271,
#   'Max Temp F°': 52.79,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.06},
#  {'City': 'Mufumbwe',
#   'Cloudiness %': 0,
#   'Country': 'ZM',
#   'Humidity %': 32,
#   'Lat': -13.6833,
#   'Lng': 24.8,
#   'Max Temp F°': 49.15,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.89},
#  {'City': 'Cabedelo',
#   'Cloudiness %': 11,
#   'Country': 'BR',
#   'Humidity %': 85,
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp F°': 72.27,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 14.99},
#  {'City': 'Saldanha',
#   'Cloudiness %': 0,
#   'Country': 'ZA',
#   'Humidity %': 86,
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp F°': 54,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.8},
#  {'City': 'San Vicente',
#   'Cloudiness %': 100,
#   'Country': 'AR',
#   'Humidity %': 60,
#   'Lat': -26.6167,
#   'Lng': -54.1333,
#   'Max Temp F°': 58.82,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 2.8},
#  {'City': 'Chara',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 94,
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp F°': 57.09,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 1.74},
#  {'City': 'Koplik',
#   'Cloudiness %': 35,
#   'Country': 'AL',
#   'Humidity %': 60,
#   'Lat': 42.2136,
#   'Lng': 19.4364,
#   'Max Temp F°': 76.6,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 3.33},
#  {'City': 'San Vicente De Canete',
#   'Cloudiness %': 28,
#   'Country': 'PE',
#   'Humidity %': 83,
#   'Lat': -13.0751,
#   'Lng': -76.3835,
#   'Max Temp F°': 63.68,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 5.26},
#  {'City': 'Geraldton',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 71,
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp F°': 54.12,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 17.27},
#  {'City': 'North Bend',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 94,
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp F°': 74.25,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.05},
#  {'City': 'Victoria',
#   'Cloudiness %': 100,
#   'Country': 'HK',
#   'Humidity %': 93,
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp F°': 84.38,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.99},
#  {'City': 'Jasper',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 78,
#   'Lat': 37.2001,
#   'Lng': -94.3502,
#   'Max Temp F°': 78.85,
#   'Weather Description': 'haze',
#   'Wind Speed mph': 6.91},
#  {'City': 'Sovetskiy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 98,
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp F°': 61.25,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 8.48},
#  {'City': 'Fortuna',
#   'Cloudiness %': 20,
#   'Country': 'US',
#   'Humidity %': 69,
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp F°': 76.19,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3},
#  {'City': 'Cap Malheureux',
#   'Cloudiness %': 13,
#   'Country': 'MU',
#   'Humidity %': 69,
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp F°': 65.46,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4},
#  {'City': 'Wabash',
#   'Cloudiness %': 21,
#   'Country': 'US',
#   'Humidity %': 76,
#   'Lat': 40.7978,
#   'Lng': -85.8205,
#   'Max Temp F°': 75.7,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 5.03},
#  {'City': 'Jiazi',
#   'Cloudiness %': 100,
#   'Country': 'CN',
#   'Humidity %': 92,
#   'Lat': 22.8779,
#   'Lng': 116.067,
#   'Max Temp F°': 80.4,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 19.1},
#  {'City': 'Takaka',
#   'Cloudiness %': 75,
#   'Country': 'NZ',
#   'Humidity %': 71,
#   'Lat': -40.85,
#   'Lng': 172.8,
#   'Max Temp F°': 57.97,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 5.59},
#  {'City': 'Kuminskiy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 99,
#   'Lat': 58.6667,
#   'Lng': 66.5667,
#   'Max Temp F°': 62.15,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.15},
#  {'City': 'Hilo',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 76,
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp F°': 82.13,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 12.66},
#  {'City': 'Crib Point',
#   'Cloudiness %': 100,
#   'Country': 'AU',
#   'Humidity %': 85,
#   'Lat': -38.35,
#   'Lng': 145.2,
#   'Max Temp F°': 57.85,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 15.57},
#  {'City': 'Cartaya',
#   'Cloudiness %': 3,
#   'Country': 'ES',
#   'Humidity %': 49,
#   'Lat': 37.2811,
#   'Lng': -7.1507,
#   'Max Temp F°': 79.18,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 19.44},
#  {'City': 'Hermanus',
#   'Cloudiness %': 68,
#   'Country': 'ZA',
#   'Humidity %': 85,
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp F°': 54.81,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 8.61},
#  {'City': 'Praia',
#   'Cloudiness %': 75,
#   'Country': 'CV',
#   'Humidity %': 94,
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp F°': 77.54,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 16.11},
#  {'City': 'Hasaki',
#   'Cloudiness %': 9,
#   'Country': 'JP',
#   'Humidity %': 73,
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp F°': 91.29,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.16},
#  {'City': 'Leningradskiy',
#   'Cloudiness %': 82,
#   'Country': 'RU',
#   'Humidity %': 90,
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp F°': 40.68,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 7},
#  {'City': 'Flamanzi',
#   'Cloudiness %': 100,
#   'Country': 'RO',
#   'Humidity %': 97,
#   'Lat': 47.559,
#   'Lng': 26.8946,
#   'Max Temp F°': 69.71,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 3.29},
#  {'City': 'Half Moon Bay',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp F°': 82.15,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 12.66},
#  {'City': 'Carbondale',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 72,
#   'Lat': 37.7273,
#   'Lng': -89.2168,
#   'Max Temp F°': 75.09,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.44},
#  {'City': 'San Patricio',
#   'Cloudiness %': 100,
#   'Country': 'US',
#   'Humidity %': 69,
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp F°': 84.29,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.35},
#  {'City': 'Saint-Georges',
#   'Cloudiness %': 20,
#   'Country': 'GD',
#   'Humidity %': 89,
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp F°': 80.28,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Coihaique',
#   'Cloudiness %': 100,
#   'Country': 'CL',
#   'Humidity %': 46,
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp F°': 49.95,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 11.5},
#  {'City': 'Ngunguru',
#   'Cloudiness %': 100,
#   'Country': 'NZ',
#   'Humidity %': 81,
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp F°': 61.16,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 14.27},
#  {'City': 'Yarim',
#   'Cloudiness %': 94,
#   'Country': 'YE',
#   'Humidity %': 64,
#   'Lat': 14.298,
#   'Lng': 44.3779,
#   'Max Temp F°': 60.15,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.17},
#  {'City': 'Clyde River',
#   'Cloudiness %': 90,
#   'Country': 'CA',
#   'Humidity %': 100,
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp F°': 39.43,
#   'Weather Description': 'mist',
#   'Wind Speed mph': 11.5},
#  {'City': 'Severo-Kurilsk',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 64,
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp F°': 55.31,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 18.03},
#  {'City': 'Nakasongola',
#   'Cloudiness %': 100,
#   'Country': 'UG',
#   'Humidity %': 78,
#   'Lat': 1.3089,
#   'Lng': 32.4564,
#   'Max Temp F°': 65.35,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.91},
#  {'City': 'Ballina',
#   'Cloudiness %': 67,
#   'Country': 'AU',
#   'Humidity %': 47,
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp F°': 64.78,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.47},
#  {'City': 'Arraial Do Cabo',
#   'Cloudiness %': 22,
#   'Country': 'BR',
#   'Humidity %': 81,
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp F°': 68.31,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 14.5},
#  {'City': 'Khatanga',
#   'Cloudiness %': 11,
#   'Country': 'RU',
#   'Humidity %': 34,
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp F°': 68.49,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 12.55},
#  {'City': 'Mahroni',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 95,
#   'Lat': 24.5862,
#   'Lng': 78.7288,
#   'Max Temp F°': 75.36,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.33},
#  {'City': 'Dalbandin',
#   'Cloudiness %': 0,
#   'Country': 'PK',
#   'Humidity %': 17,
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp F°': 82.78,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 9.6},
#  {'City': 'Tigil',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 97,
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp F°': 46.06,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 5.79},
#  {'City': 'Wewak',
#   'Cloudiness %': 13,
#   'Country': 'PG',
#   'Humidity %': 73,
#   'Lat': -3.5534,
#   'Lng': 143.6268,
#   'Max Temp F°': 83.5,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.67},
#  {'City': 'Ponta Do Sol',
#   'Cloudiness %': 47,
#   'Country': 'PT',
#   'Humidity %': 84,
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp F°': 77,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 2.21},
#  {'City': 'Hamilton',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 67,
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp F°': 78.89,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 0},
#  {'City': 'Helong',
#   'Cloudiness %': 100,
#   'Country': 'CN',
#   'Humidity %': 65,
#   'Lat': 42.5397,
#   'Lng': 128.9972,
#   'Max Temp F°': 75.97,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 2.71},
#  {'City': 'Sisimiut',
#   'Cloudiness %': 99,
#   'Country': 'GL',
#   'Humidity %': 94,
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp F°': 44.15,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.82},
#  {'City': 'Sembakung',
#   'Cloudiness %': 39,
#   'Country': 'ID',
#   'Humidity %': 78,
#   'Lat': 3.8167,
#   'Lng': 117.25,
#   'Max Temp F°': 80.53,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 2.71},
#  {'City': 'Iberia',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 69,
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp F°': 80.67,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.61},
#  {'City': 'Ripky',
#   'Cloudiness %': 88,
#   'Country': 'UA',
#   'Humidity %': 93,
#   'Lat': 51.801,
#   'Lng': 31.0838,
#   'Max Temp F°': 63.52,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.82},
#  {'City': 'Nishihara',
#   'Cloudiness %': 75,
#   'Country': 'JP',
#   'Humidity %': 86,
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp F°': 85.68,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4.61},
#  {'City': 'Prince Albert',
#   'Cloudiness %': 5,
#   'Country': 'CA',
#   'Humidity %': 51,
#   'Lat': 53.2001,
#   'Lng': -105.7677,
#   'Max Temp F°': 77.72,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.31},
#  {'City': 'Jingdezhen',
#   'Cloudiness %': 14,
#   'Country': 'CN',
#   'Humidity %': 66,
#   'Lat': 29.2947,
#   'Lng': 117.2079,
#   'Max Temp F°': 87.1,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 5.68},
#  {'City': 'Atlantic Beach',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 94,
#   'Lat': 30.3344,
#   'Lng': -81.3987,
#   'Max Temp F°': 79.23,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.75},
#  {'City': 'Honiara',
#   'Cloudiness %': 15,
#   'Country': 'SB',
#   'Humidity %': 58,
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp F°': 85.03,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.89},
#  {'City': 'Anchorage',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 74,
#   'Lat': 61.2181,
#   'Lng': -149.9003,
#   'Max Temp F°': 75.2,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 8.99},
#  {'City': 'Palmer',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp F°': 68.76,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Watertown',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 94,
#   'Lat': 42.3709,
#   'Lng': -71.1828,
#   'Max Temp F°': 68.5,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.01},
#  {'City': 'Ampanihy',
#   'Cloudiness %': 0,
#   'Country': 'MG',
#   'Humidity %': 55,
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp F°': 63.84,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.91},
#  {'City': 'Bozdar',
#   'Cloudiness %': 1,
#   'Country': 'PK',
#   'Humidity %': 69,
#   'Lat': 27.1828,
#   'Lng': 68.636,
#   'Max Temp F°': 82.47,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 16.24},
#  {'City': 'Turbat',
#   'Cloudiness %': 4,
#   'Country': 'PK',
#   'Humidity %': 55,
#   'Lat': 26.0023,
#   'Lng': 63.044,
#   'Max Temp F°': 87.91,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.66},
#  {'City': 'Nouadhibou',
#   'Cloudiness %': 0,
#   'Country': 'MR',
#   'Humidity %': 87,
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp F°': 69.85,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 24.58},
#  {'City': 'Carbonia',
#   'Cloudiness %': 24,
#   'Country': 'IT',
#   'Humidity %': 62,
#   'Lat': 39.1672,
#   'Lng': 8.5222,
#   'Max Temp F°': 74.98,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 3.24},
#  {'City': 'Teodoro Sampaio',
#   'Cloudiness %': 89,
#   'Country': 'BR',
#   'Humidity %': 55,
#   'Lat': -22.5325,
#   'Lng': -52.1675,
#   'Max Temp F°': 65.98,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.63},
#  {'City': 'Nome',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 82,
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp F°': 65.16,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 21.85},
#  {'City': 'Esso',
#   'Cloudiness %': 99,
#   'Country': 'RU',
#   'Humidity %': 75,
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp F°': 47.34,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.65},
#  {'City': 'Kavieng',
#   'Cloudiness %': 85,
#   'Country': 'PG',
#   'Humidity %': 75,
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp F°': 82.83,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 10.38},
#  {'City': 'La Ronge',
#   'Cloudiness %': 74,
#   'Country': 'CA',
#   'Humidity %': 72,
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp F°': 65.12,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.95},
#  {'City': 'San Lorenzo',
#   'Cloudiness %': 9,
#   'Country': 'PY',
#   'Humidity %': 61,
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp F°': 61.83,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.38},
#  {'City': 'Hirara',
#   'Cloudiness %': 100,
#   'Country': 'JP',
#   'Humidity %': 87,
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp F°': 81.93,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 13.69},
#  {'City': 'Derzhavinsk',
#   'Cloudiness %': 100,
#   'Country': 'KZ',
#   'Humidity %': 47,
#   'Lat': 51.1,
#   'Lng': 66.3167,
#   'Max Temp F°': 72.19,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.15},
#  {'City': 'Khash',
#   'Cloudiness %': 2,
#   'Country': 'IR',
#   'Humidity %': 18,
#   'Lat': 28.2211,
#   'Lng': 61.2158,
#   'Max Temp F°': 75.04,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.08},
#  {'City': 'Angoram',
#   'Cloudiness %': 2,
#   'Country': 'PG',
#   'Humidity %': 57,
#   'Lat': -4.0625,
#   'Lng': 144.0661,
#   'Max Temp F°': 89.38,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 1.63},
#  {'City': 'Kununurra',
#   'Cloudiness %': 2,
#   'Country': 'AU',
#   'Humidity %': 16,
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp F°': 73.38,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 20.71},
#  {'City': 'Katobu',
#   'Cloudiness %': 94,
#   'Country': 'ID',
#   'Humidity %': 69,
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Max Temp F°': 81.66,
#   'Weather Description': 'moderate rain',
#   'Wind Speed mph': 8.23},
#  {'City': 'Namibe',
#   'Cloudiness %': 0,
#   'Country': 'AO',
#   'Humidity %': 81,
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp F°': 66.31,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 2.48},
#  {'City': 'Daru',
#   'Cloudiness %': 95,
#   'Country': 'PG',
#   'Humidity %': 68,
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp F°': 80.04,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 14.05},
#  {'City': 'San Quintin',
#   'Cloudiness %': 1,
#   'Country': 'MX',
#   'Humidity %': 76,
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp F°': 71.13,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 12.19},
#  {'City': 'Banjar',
#   'Cloudiness %': 38,
#   'Country': 'ID',
#   'Humidity %': 77,
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp F°': 80.46,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 0.85},
#  {'City': 'America Dourada',
#   'Cloudiness %': 81,
#   'Country': 'BR',
#   'Humidity %': 78,
#   'Lat': -11.4553,
#   'Lng': -41.4361,
#   'Max Temp F°': 65.23,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 9.75},
#  {'City': 'Arica',
#   'Cloudiness %': 90,
#   'Country': 'CL',
#   'Humidity %': 82,
#   'Lat': -18.475,
#   'Lng': -70.3042,
#   'Max Temp F°': 59.23,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.61},
#  {'City': 'Nhulunbuy',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 53,
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp F°': 77.61,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 16.11},
#  {'City': 'Nizhniy Kuranakh',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 67,
#   'Lat': 58.8353,
#   'Lng': 125.4869,
#   'Max Temp F°': 68.2,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.77},
#  {'City': 'Labuhan',
#   'Cloudiness %': 87,
#   'Country': 'ID',
#   'Humidity %': 76,
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp F°': 80.64,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.45},
#  {'City': 'Asyut',
#   'Cloudiness %': 0,
#   'Country': 'EG',
#   'Humidity %': 16,
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp F°': 87.96,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.3},
#  {'City': 'Liwale',
#   'Cloudiness %': 53,
#   'Country': 'TZ',
#   'Humidity %': 91,
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp F°': 63.5,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 1.48},
#  {'City': 'Saint-Philippe',
#   'Cloudiness %': 49,
#   'Country': 'RE',
#   'Humidity %': 71,
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp F°': 65.75,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 9.17},
#  {'City': 'Salalah',
#   'Cloudiness %': 90,
#   'Country': 'OM',
#   'Humidity %': 94,
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp F°': 78.89,
#   'Weather Description': 'light intensity drizzle',
#   'Wind Speed mph': 6.91},
#  {'City': 'Indramayu',
#   'Cloudiness %': 82,
#   'Country': 'ID',
#   'Humidity %': 72,
#   'Lat': -6.3264,
#   'Lng': 108.32,
#   'Max Temp F°': 82.81,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 14.29},
#  {'City': 'Abu Samrah',
#   'Cloudiness %': 84,
#   'Country': 'SY',
#   'Humidity %': 48,
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp F°': 79.93,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 6.35},
#  {'City': 'Northam',
#   'Cloudiness %': 98,
#   'Country': 'GB',
#   'Humidity %': 97,
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp F°': 61.66,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 21.36},
#  {'City': 'Formosa',
#   'Cloudiness %': 0,
#   'Country': 'AR',
#   'Humidity %': 72,
#   'Lat': -26.1775,
#   'Lng': -58.1781,
#   'Max Temp F°': 64.38,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 6.91},
#  {'City': 'Ambilobe',
#   'Cloudiness %': 85,
#   'Country': 'MG',
#   'Humidity %': 68,
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp F°': 70.2,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.17},
#  {'City': 'Ambulu',
#   'Cloudiness %': 100,
#   'Country': 'ID',
#   'Humidity %': 80,
#   'Lat': -8.345,
#   'Lng': 113.6058,
#   'Max Temp F°': 78.24,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.44},
#  {'City': 'Shenjiamen',
#   'Cloudiness %': 0,
#   'Country': 'CN',
#   'Humidity %': 81,
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp F°': 82.02,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.09},
#  {'City': 'Makakilo City',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 56,
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp F°': 86.32,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 10.36},
#  {'City': 'Vanavara',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 60,
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp F°': 66.31,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.08},
#  {'City': 'Chokurdakh',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 72,
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp F°': 43.88,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.13},
#  {'City': 'Riachao Das Neves',
#   'Cloudiness %': 100,
#   'Country': 'BR',
#   'Humidity %': 41,
#   'Lat': -11.7461,
#   'Lng': -44.91,
#   'Max Temp F°': 70.07,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.77},
#  {'City': 'Saint-Joseph',
#   'Cloudiness %': 48,
#   'Country': 'RE',
#   'Humidity %': 72,
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp F°': 64.76,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 9.69},
#  {'City': 'Hauterive',
#   'Cloudiness %': 97,
#   'Country': 'FR',
#   'Humidity %': 82,
#   'Lat': 46.0901,
#   'Lng': 3.4459,
#   'Max Temp F°': 68.76,
# ...
#   'Lng': -97.6961,
#   'Max Temp F°': 88.18,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.36},
#  {'City': 'Baruun-Urt',
#   'Cloudiness %': 6,
#   'Country': 'MN',
#   'Humidity %': 47,
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp F°': 69.57,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.33},
#  {'City': 'Zhangye',
#   'Cloudiness %': 83,
#   'Country': 'CN',
#   'Humidity %': 31,
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp F°': 79.93,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 6.93},
#  {'City': 'Tlaltizapan',
#   'Cloudiness %': 99,
#   'Country': 'MX',
#   'Humidity %': 81,
#   'Lat': 18.6833,
#   'Lng': -99.1167,
#   'Max Temp F°': 74.16,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.95},
#  {'City': 'Mae Sai',
#   'Cloudiness %': 100,
#   'Country': 'TH',
#   'Humidity %': 97,
#   'Lat': 20.4335,
#   'Lng': 99.8762,
#   'Max Temp F°': 79.45,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.1},
#  {'City': 'Sur',
#   'Cloudiness %': 0,
#   'Country': 'OM',
#   'Humidity %': 45,
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp F°': 92.21,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.71},
#  {'City': 'Brae',
#   'Cloudiness %': 53,
#   'Country': 'GB',
#   'Humidity %': 94,
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp F°': 57.11,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 15.14},
#  {'City': 'Ganzhou',
#   'Cloudiness %': 5,
#   'Country': 'CN',
#   'Humidity %': 73,
#   'Lat': 28.8184,
#   'Lng': 115.4327,
#   'Max Temp F°': 87.17,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.23},
#  {'City': 'Koygorodok',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 86,
#   'Lat': 60.445,
#   'Lng': 50.9968,
#   'Max Temp F°': 46.51,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.58},
#  {'City': 'Isangel',
#   'Cloudiness %': 90,
#   'Country': 'VU',
#   'Humidity %': 100,
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp F°': 69.91,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.91},
#  {'City': 'Muisne',
#   'Cloudiness %': 100,
#   'Country': 'EC',
#   'Humidity %': 85,
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp F°': 75.45,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 9.28},
#  {'City': 'Voyvozh',
#   'Cloudiness %': 0,
#   'Country': 'RU',
#   'Humidity %': 90,
#   'Lat': 62.892,
#   'Lng': 54.9635,
#   'Max Temp F°': 45.63,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 4.94},
#  {'City': 'Dergachi',
#   'Cloudiness %': 78,
#   'Country': 'RU',
#   'Humidity %': 51,
#   'Lat': 51.2328,
#   'Lng': 48.7659,
#   'Max Temp F°': 64.31,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 7.58},
#  {'City': 'Sosua',
#   'Cloudiness %': 75,
#   'Country': 'DO',
#   'Humidity %': 94,
#   'Lat': 19.7667,
#   'Lng': -70.5167,
#   'Max Temp F°': 82.53,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 9.22},
#  {'City': 'Bedesa',
#   'Cloudiness %': 100,
#   'Country': 'ET',
#   'Humidity %': 74,
#   'Lat': 8.9,
#   'Lng': 40.7833,
#   'Max Temp F°': 62.19,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 6.85},
#  {'City': 'Yaan',
#   'Cloudiness %': 93,
#   'Country': 'NG',
#   'Humidity %': 97,
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp F°': 70.45,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 4.05},
#  {'City': 'Lakes Entrance',
#   'Cloudiness %': 48,
#   'Country': 'AU',
#   'Humidity %': 57,
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp F°': 60.19,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 14.74},
#  {'City': 'Sorong',
#   'Cloudiness %': 100,
#   'Country': 'ID',
#   'Humidity %': 73,
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp F°': 82.47,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 11.1},
#  {'City': 'Shirokiy',
#   'Cloudiness %': 98,
#   'Country': 'RU',
#   'Humidity %': 87,
#   'Lat': 49.758,
#   'Lng': 129.523,
#   'Max Temp F°': 69.33,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 11.3},
#  {'City': 'Clarksburg',
#   'Cloudiness %': 1,
#   'Country': 'US',
#   'Humidity %': 80,
#   'Lat': 39.2807,
#   'Lng': -80.3445,
#   'Max Temp F°': 73.85,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 0},
#  {'City': 'Charleston',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 94,
#   'Lat': 32.7766,
#   'Lng': -79.9309,
#   'Max Temp F°': 75.36,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 4},
#  {'City': 'Deputatskiy',
#   'Cloudiness %': 100,
#   'Country': 'RU',
#   'Humidity %': 92,
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp F°': 37.15,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.28},
#  {'City': 'Santa Rita',
#   'Cloudiness %': 75,
#   'Country': 'BR',
#   'Humidity %': 100,
#   'Lat': -7.1139,
#   'Lng': -34.9781,
#   'Max Temp F°': 72.27,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 10.36},
#  {'City': 'Wilmington',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 85,
#   'Lat': 34.2257,
#   'Lng': -77.9447,
#   'Max Temp F°': 78.71,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 0},
#  {'City': 'Monywa',
#   'Cloudiness %': 100,
#   'Country': 'MM',
#   'Humidity %': 90,
#   'Lat': 22.1167,
#   'Lng': 95.1333,
#   'Max Temp F°': 77.22,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.68},
#  {'City': 'Moerai',
#   'Cloudiness %': 6,
#   'Country': 'PF',
#   'Humidity %': 71,
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp F°': 73.69,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.78},
#  {'City': 'San Luis',
#   'Cloudiness %': 1,
#   'Country': 'AR',
#   'Humidity %': 35,
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp F°': 60.03,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 7.47},
#  {'City': 'Effium',
#   'Cloudiness %': 89,
#   'Country': 'NG',
#   'Humidity %': 96,
#   'Lat': 6.6292,
#   'Lng': 8.0593,
#   'Max Temp F°': 72.01,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.25},
#  {'City': 'Clifton',
#   'Cloudiness %': 40,
#   'Country': 'US',
#   'Humidity %': 77,
#   'Lat': 40.8584,
#   'Lng': -74.1638,
#   'Max Temp F°': 75.81,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.99},
#  {'City': 'Manavalakurichi',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 80,
#   'Lat': 8.1333,
#   'Lng': 77.3,
#   'Max Temp F°': 77.09,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 15.84},
#  {'City': 'Vadodara',
#   'Cloudiness %': 75,
#   'Country': 'IN',
#   'Humidity %': 89,
#   'Lat': 22.3,
#   'Lng': 73.2,
#   'Max Temp F°': 80.56,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 9.22},
#  {'City': 'Stornoway',
#   'Cloudiness %': 100,
#   'Country': 'GB',
#   'Humidity %': 82,
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp F°': 60.93,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.66},
#  {'City': 'Bairiki',
#   'Cloudiness %': 20,
#   'Country': 'KI',
#   'Humidity %': 62,
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp F°': 86,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 13.8},
#  {'City': 'Quatre Cocos',
#   'Cloudiness %': 71,
#   'Country': 'MU',
#   'Humidity %': 73,
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp F°': 68.11,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 14.05},
#  {'City': 'Vila Franca Do Campo',
#   'Cloudiness %': 47,
#   'Country': 'PT',
#   'Humidity %': 91,
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp F°': 72.01,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 7.18},
#  {'City': 'Mahibadhoo',
#   'Cloudiness %': 100,
#   'Country': 'MV',
#   'Humidity %': 78,
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp F°': 81.18,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.66},
#  {'City': 'Biloela',
#   'Cloudiness %': 43,
#   'Country': 'AU',
#   'Humidity %': 36,
#   'Lat': -24.4167,
#   'Lng': 150.5,
#   'Max Temp F°': 65.86,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 13.29},
#  {'City': 'Novobirilyussy',
#   'Cloudiness %': 42,
#   'Country': 'RU',
#   'Humidity %': 84,
#   'Lat': 56.9514,
#   'Lng': 90.6661,
#   'Max Temp F°': 62.31,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.16},
#  {'City': 'San Zenon',
#   'Cloudiness %': 11,
#   'Country': 'CO',
#   'Humidity %': 77,
#   'Lat': 9.2422,
#   'Lng': -74.5004,
#   'Max Temp F°': 80.73,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 7.29},
#  {'City': 'Newport',
#   'Cloudiness %': 100,
#   'Country': 'GB',
#   'Humidity %': 92,
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp F°': 61.86,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 13.98},
#  {'City': 'Yanam',
#   'Cloudiness %': 100,
#   'Country': 'IN',
#   'Humidity %': 78,
#   'Lat': 16.7333,
#   'Lng': 82.2167,
#   'Max Temp F°': 84.6,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.95},
#  {'City': 'Port Hedland',
#   'Cloudiness %': 75,
#   'Country': 'AU',
#   'Humidity %': 21,
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp F°': 71.65,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 25.32},
#  {'City': 'Mount Isa',
#   'Cloudiness %': 0,
#   'Country': 'AU',
#   'Humidity %': 26,
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp F°': 67.77,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 16.11},
#  {'City': 'Aktau',
#   'Cloudiness %': 11,
#   'Country': 'KZ',
#   'Humidity %': 46,
#   'Lat': 43.65,
#   'Lng': 51.2,
#   'Max Temp F°': 73.98,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 5.95},
#  {'City': 'Santa Rosa',
#   'Cloudiness %': 100,
#   'Country': 'PH',
#   'Humidity %': 71,
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp F°': 90.09,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 12.57},
#  {'City': 'Little Rock',
#   'Cloudiness %': 75,
#   'Country': 'US',
#   'Humidity %': 57,
#   'Lat': 34.7465,
#   'Lng': -92.2896,
#   'Max Temp F°': 82.22,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.75},
#  {'City': 'Skjervoy',
#   'Cloudiness %': 100,
#   'Country': 'NO',
#   'Humidity %': 81,
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp F°': 52.56,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 6.78},
#  {'City': 'Arlit',
#   'Cloudiness %': 10,
#   'Country': 'NE',
#   'Humidity %': 39,
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp F°': 90.16,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 8.34},
#  {'City': 'Klaksvik',
#   'Cloudiness %': 100,
#   'Country': 'FO',
#   'Humidity %': 95,
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp F°': 54.52,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.02},
#  {'City': 'Kota Belud',
#   'Cloudiness %': 74,
#   'Country': 'MY',
#   'Humidity %': 58,
#   'Lat': 6.351,
#   'Lng': 116.4305,
#   'Max Temp F°': 87.66,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 3.22},
#  {'City': 'Najran',
#   'Cloudiness %': 100,
#   'Country': 'SA',
#   'Humidity %': 44,
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp F°': 84.85,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.5},
#  {'City': 'Scalea',
#   'Cloudiness %': 34,
#   'Country': 'IT',
#   'Humidity %': 69,
#   'Lat': 39.813,
#   'Lng': 15.7956,
#   'Max Temp F°': 75.34,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 9.01},
#  {'City': 'Halifax',
#   'Cloudiness %': 92,
#   'Country': 'CA',
#   'Humidity %': 95,
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp F°': 73.42,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 5.01},
#  {'City': 'Balaguer',
#   'Cloudiness %': 1,
#   'Country': 'ES',
#   'Humidity %': 63,
#   'Lat': 41.7912,
#   'Lng': 0.8109,
#   'Max Temp F°': 74.88,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 9.89},
#  {'City': 'Chegutu',
#   'Cloudiness %': 0,
#   'Country': 'ZW',
#   'Humidity %': 43,
#   'Lat': -18.1302,
#   'Lng': 30.1407,
#   'Max Temp F°': 52.7,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 3.85},
#  {'City': 'Harnosand',
#   'Cloudiness %': 48,
#   'Country': 'SE',
#   'Humidity %': 86,
#   'Lat': 62.6323,
#   'Lng': 17.9379,
#   'Max Temp F°': 59,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 5.64},
#  {'City': 'Slave Lake',
#   'Cloudiness %': 1,
#   'Country': 'CA',
#   'Humidity %': 50,
#   'Lat': 55.2834,
#   'Lng': -114.769,
#   'Max Temp F°': 80.58,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.91},
#  {'City': 'Vardo',
#   'Cloudiness %': 52,
#   'Country': 'NO',
#   'Humidity %': 82,
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp F°': 50.2,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 2.57},
#  {'City': 'Belaya Gora',
#   'Cloudiness %': 90,
#   'Country': 'RU',
#   'Humidity %': 68,
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp F°': 48.45,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 3.69},
#  {'City': 'Inhambane',
#   'Cloudiness %': 0,
#   'Country': 'MZ',
#   'Humidity %': 84,
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp F°': 64.78,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 6.04},
#  {'City': 'Corralillo',
#   'Cloudiness %': 99,
#   'Country': 'CU',
#   'Humidity %': 81,
#   'Lat': 22.9819,
#   'Lng': -80.5856,
#   'Max Temp F°': 80.19,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 7.29},
#  {'City': 'Flin Flon',
#   'Cloudiness %': 93,
#   'Country': 'CA',
#   'Humidity %': 39,
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp F°': 73.53,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 2.44},
#  {'City': 'Dauriya',
#   'Cloudiness %': 6,
#   'Country': 'RU',
#   'Humidity %': 54,
#   'Lat': 49.9333,
#   'Lng': 116.8667,
#   'Max Temp F°': 70.84,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.2},
#  {'City': 'Weihai',
#   'Cloudiness %': 75,
#   'Country': 'CN',
#   'Humidity %': 81,
#   'Lat': 37.5017,
#   'Lng': 122.1136,
#   'Max Temp F°': 76.08,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 5.79},
#  {'City': 'Kiunga',
#   'Cloudiness %': 100,
#   'Country': 'PG',
#   'Humidity %': 96,
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp F°': 73.42,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 2.57},
#  {'City': 'Vila',
#   'Cloudiness %': 39,
#   'Country': 'PT',
#   'Humidity %': 85,
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp F°': 53.33,
#   'Weather Description': 'scattered clouds',
#   'Wind Speed mph': 1.9},
#  {'City': 'Lixourion',
#   'Cloudiness %': 0,
#   'Country': 'GR',
#   'Humidity %': 87,
#   'Lat': 38.2019,
#   'Lng': 20.4314,
#   'Max Temp F°': 79.41,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 5.35},
#  {'City': 'Onega',
#   'Cloudiness %': 13,
#   'Country': 'RU',
#   'Humidity %': 85,
#   'Lat': 63.9061,
#   'Lng': 38.1404,
#   'Max Temp F°': 46.08,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 4.38},
#  {'City': 'Igarka',
#   'Cloudiness %': 76,
#   'Country': 'RU',
#   'Humidity %': 51,
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp F°': 68.23,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 7.45},
#  {'City': 'Vangaindrano',
#   'Cloudiness %': 93,
#   'Country': 'MG',
#   'Humidity %': 87,
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp F°': 63.91,
#   'Weather Description': 'light rain',
#   'Wind Speed mph': 3.13},
#  {'City': 'Praya',
#   'Cloudiness %': 75,
#   'Country': 'CV',
#   'Humidity %': 94,
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp F°': 77.54,
#   'Weather Description': 'broken clouds',
#   'Wind Speed mph': 16.11},
#  {'City': 'Sibolga',
#   'Cloudiness %': 99,
#   'Country': 'ID',
#   'Humidity %': 73,
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp F°': 79.57,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 1.81},
#  {'City': 'Strezhevoy',
#   'Cloudiness %': 19,
#   'Country': 'RU',
#   'Humidity %': 76,
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp F°': 60.78,
#   'Weather Description': 'few clouds',
#   'Wind Speed mph': 6.11},
#  {'City': 'Port-Gentil',
#   'Cloudiness %': 6,
#   'Country': 'GA',
#   'Humidity %': 81,
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp F°': 77.16,
#   'Weather Description': 'clear sky',
#   'Wind Speed mph': 10.67},
#  {'City': 'Milledgeville',
#   'Cloudiness %': 90,
#   'Country': 'US',
#   'Humidity %': 79,
#   'Lat': 33.0801,
#   'Lng': -83.2321,
#   'Max Temp F°': 78.49,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 4.54},
#  {'City': 'Gongzhuling',
#   'Cloudiness %': 100,
#   'Country': 'CN',
#   'Humidity %': 79,
#   'Lat': 43.5008,
#   'Lng': 124.8198,
#   'Max Temp F°': 75.11,
#   'Weather Description': 'overcast clouds',
#   'Wind Speed mph': 8.55}]

# %%
city_data
# Out:
# [{'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp F°': 57.09,
#   'Humidity %': 28,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Satipo',
#   'Country': 'PE',
#   'Lat': -11.2522,
#   'Lng': -74.6386,
#   'Max Temp F°': 70.03,
#   'Humidity %': 62,
#   'Cloudiness %': 22,
#   'Wind Speed mph': 2.51,
#   'Weather Description': 'few clouds'},
#  {'City': 'Juneau',
#   'Country': 'US',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp F°': 67.84,
#   'Humidity %': 72,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp F°': 91.17,
#   'Humidity %': 16,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 7.7,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp F°': 83.34,
#   'Humidity %': 64,
#   'Cloudiness %': 11,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'few clouds'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp F°': 85.78,
#   'Humidity %': 68,
#   'Cloudiness %': 28,
#   'Wind Speed mph': 9.17,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp F°': 74.3,
#   'Humidity %': 74,
#   'Cloudiness %': 66,
#   'Wind Speed mph': 15.23,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp F°': 77.05,
#   'Humidity %': 65,
#   'Cloudiness %': 72,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ust-Maya',
#   'Country': 'RU',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp F°': 69.03,
#   'Humidity %': 39,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 12.73,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp F°': 63.03,
#   'Humidity %': 89,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 8.63,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp F°': 77.2,
#   'Humidity %': 86,
#   'Cloudiness %': 39,
#   'Wind Speed mph': 1.88,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp F°': 37.53,
#   'Humidity %': 96,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 15.59,
#   'Weather Description': 'light rain'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp F°': 72.21,
#   'Humidity %': 81,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp F°': 44.17,
#   'Humidity %': 65,
#   'Cloudiness %': 17,
#   'Wind Speed mph': 3.22,
#   'Weather Description': 'few clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp F°': 39.22,
#   'Humidity %': 77,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 19.57,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shakawe',
#   'Country': 'BW',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp F°': 54.68,
#   'Humidity %': 33,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.56,
#   'Weather Description': 'clear sky'},
#  {'City': 'The Valley',
#   'Country': 'AI',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp F°': 82.81,
#   'Humidity %': 75,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 17.52,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp F°': 58.78,
#   'Humidity %': 80,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.71,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp F°': 51.31,
#   'Humidity %': 85,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 10.31,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp F°': 72.72,
#   'Humidity %': 73,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 1.1,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Nalut',
#   'Country': 'LY',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp F°': 88.14,
#   'Humidity %': 13,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 8.7,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp F°': 80.24,
#   'Humidity %': 75,
#   'Cloudiness %': 86,
#   'Wind Speed mph': 4.03,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp F°': 84.18,
#   'Humidity %': 77,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 5.01,
#   'Weather Description': 'light rain'},
#  {'City': 'Taybad',
#   'Country': 'IR',
#   'Lat': 34.74,
#   'Lng': 60.7756,
#   'Max Temp F°': 78.24,
#   'Humidity %': 20,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 14.81,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp F°': 50.81,
#   'Humidity %': 70,
#   'Cloudiness %': 43,
#   'Wind Speed mph': 13.58,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp F°': 82.89,
#   'Humidity %': 75,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'thunderstorm'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp F°': 37.24,
#   'Humidity %': 77,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp F°': 54.12,
#   'Humidity %': 85,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.62,
#   'Weather Description': 'clear sky'},
#  {'City': 'Changping',
#   'Country': 'CN',
#   'Lat': 40.2186,
#   'Lng': 116.2197,
#   'Max Temp F°': 76.64,
#   'Humidity %': 51,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.84,
#   'Weather Description': 'clear sky'},
#  {'City': 'Oranjemund',
#   'Country': 'NA',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp F°': 53.6,
#   'Humidity %': 78,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 1.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp F°': 54.46,
#   'Humidity %': 86,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 7.72,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp F°': 62.74,
#   'Humidity %': 95,
#   'Cloudiness %': 73,
#   'Wind Speed mph': 8.32,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Smoky Lake',
#   'Country': 'CA',
#   'Lat': 54.1169,
#   'Lng': -112.4686,
#   'Max Temp F°': 86.49,
#   'Humidity %': 25,
#   'Cloudiness %': 70,
#   'Wind Speed mph': 7.02,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp F°': 40.91,
#   'Humidity %': 97,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.5,
#   'Weather Description': 'light rain'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp F°': 38.86,
#   'Humidity %': 65,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'light rain'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp F°': 77.16,
#   'Humidity %': 78,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'few clouds'},
#  {'City': 'Iwaki',
#   'Country': 'JP',
#   'Lat': 37.05,
#   'Lng': 140.8833,
#   'Max Temp F°': 91.76,
#   'Humidity %': 65,
#   'Cloudiness %': 15,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'few clouds'},
#  {'City': 'Omboue',
#   'Country': 'GA',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp F°': 74.28,
#   'Humidity %': 84,
#   'Cloudiness %': 4,
#   'Wind Speed mph': 5.35,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ames',
#   'Country': 'US',
#   'Lat': 42.0347,
#   'Lng': -93.6199,
#   'Max Temp F°': 79.11,
#   'Humidity %': 80,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'clear sky'},
#  {'City': 'Baoqing',
#   'Country': 'CN',
#   'Lat': 46.3317,
#   'Lng': 132.2111,
#   'Max Temp F°': 84.72,
#   'Humidity %': 46,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.88,
#   'Weather Description': 'light rain'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp F°': 39.31,
#   'Humidity %': 87,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'light intensity shower rain'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp F°': 50.31,
#   'Humidity %': 90,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.62,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Aripuana',
#   'Country': 'BR',
#   'Lat': -9.1667,
#   'Lng': -60.6333,
#   'Max Temp F°': 77.05,
#   'Humidity %': 38,
#   'Cloudiness %': 34,
#   'Wind Speed mph': 2.46,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp F°': 51.37,
#   'Humidity %': 89,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 5.59,
#   'Weather Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp F°': 61.48,
#   'Humidity %': 88,
#   'Cloudiness %': 24,
#   'Wind Speed mph': 10.11,
#   'Weather Description': 'few clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp F°': 87.91,
#   'Humidity %': 74,
#   'Cloudiness %': 73,
#   'Wind Speed mph': 9.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Cangzhou',
#   'Country': 'CN',
#   'Lat': 38.3167,
#   'Lng': 116.8667,
#   'Max Temp F°': 81.19,
#   'Humidity %': 71,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 0.83,
#   'Weather Description': 'light rain'},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp F°': 53.91,
#   'Humidity %': 100,
#   'Cloudiness %': 51,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'fog'},
#  {'City': 'Amga',
#   'Country': 'RU',
#   'Lat': 60.8953,
#   'Lng': 131.9608,
#   'Max Temp F°': 72.99,
#   'Humidity %': 45,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 9.8,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp F°': 72.7,
#   'Humidity %': 93,
#   'Cloudiness %': 8,
#   'Wind Speed mph': 20.04,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp F°': 50.49,
#   'Humidity %': 71,
#   'Cloudiness %': 77,
#   'Wind Speed mph': 2.53,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Dalian',
#   'Country': 'CN',
#   'Lat': 38.9122,
#   'Lng': 121.6022,
#   'Max Temp F°': 80.53,
#   'Humidity %': 69,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 4.47,
#   'Weather Description': 'clear sky'},
#  {'City': 'Takoradi',
#   'Country': 'GH',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp F°': 75,
#   'Humidity %': 87,
#   'Cloudiness %': 25,
#   'Wind Speed mph': 6.96,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Inuvik',
#   'Country': 'CA',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp F°': 62.01,
#   'Humidity %': 44,
#   'Cloudiness %': 49,
#   'Wind Speed mph': 18.84,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp F°': 55.81,
#   'Humidity %': 69,
#   'Cloudiness %': 37,
#   'Wind Speed mph': 1.97,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp F°': 73.49,
#   'Humidity %': 91,
#   'Cloudiness %': 17,
#   'Wind Speed mph': 13.89,
#   'Weather Description': 'few clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp F°': 55.44,
#   'Humidity %': 63,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 12.64,
#   'Weather Description': 'clear sky'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp F°': 68.36,
#   'Humidity %': 43,
#   'Cloudiness %': 62,
#   'Wind Speed mph': 5.68,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Pokaran',
#   'Country': 'IN',
#   'Lat': 26.9167,
#   'Lng': 71.9167,
#   'Max Temp F°': 84.58,
#   'Humidity %': 62,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 12.28,
#   'Weather Description': 'clear sky'},
#  {'City': 'Jijiga',
#   'Country': 'ET',
#   'Lat': 9.35,
#   'Lng': 42.8,
#   'Max Temp F°': 63.81,
#   'Humidity %': 64,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 19.06,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp F°': 86.5,
#   'Humidity %': 75,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp F°': 52.93,
#   'Humidity %': 68,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 3.31,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bawal',
#   'Country': 'IN',
#   'Lat': 28.0833,
#   'Lng': 76.5833,
#   'Max Temp F°': 88.83,
#   'Humidity %': 74,
#   'Cloudiness %': 14,
#   'Wind Speed mph': 1.83,
#   'Weather Description': 'few clouds'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp F°': 53.33,
#   'Humidity %': 80,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 13.73,
#   'Weather Description': 'clear sky'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp F°': 50.81,
#   'Humidity %': 85,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.34,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp F°': 58.1,
#   'Humidity %': 90,
#   'Cloudiness %': 7,
#   'Wind Speed mph': 5.86,
#   'Weather Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp F°': 60.67,
#   'Humidity %': 38,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 8.86,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp F°': 49.59,
#   'Humidity %': 84,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 7.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp F°': 66.27,
#   'Humidity %': 31,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 18.41,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp F°': 54.28,
#   'Humidity %': 96,
#   'Cloudiness %': 96,
#   'Wind Speed mph': 4.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp F°': 75.94,
#   'Humidity %': 69,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 15.08,
#   'Weather Description': 'few clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp F°': 65.25,
#   'Humidity %': 72,
#   'Cloudiness %': 84,
#   'Wind Speed mph': 13.33,
#   'Weather Description': 'light rain'},
#  {'City': 'Havre-Saint-Pierre',
#   'Country': 'CA',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp F°': 61.25,
#   'Humidity %': 87,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 12.64,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gawler',
#   'Country': 'AU',
#   'Lat': -34.6,
#   'Lng': 138.7333,
#   'Max Temp F°': 56.46,
#   'Humidity %': 94,
#   'Cloudiness %': 96,
#   'Wind Speed mph': 7.4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp F°': 59.13,
#   'Humidity %': 68,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.87,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp F°': 60.06,
#   'Humidity %': 51,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 5.99,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Salmon Arm',
#   'Country': 'CA',
#   'Lat': 50.6998,
#   'Lng': -119.3024,
#   'Max Temp F°': 97.23,
#   'Humidity %': 12,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 9.71,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp F°': 71.02,
#   'Humidity %': 70,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 10.4,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp F°': 62.65,
#   'Humidity %': 63,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 5.55,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Policarpo',
#   'Country': 'PH',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp F°': 86.94,
#   'Humidity %': 61,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Pudozh',
#   'Country': 'RU',
#   'Lat': 61.8099,
#   'Lng': 36.5345,
#   'Max Temp F°': 53.51,
#   'Humidity %': 72,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.12,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp F°': 50.05,
#   'Humidity %': 90,
#   'Cloudiness %': 61,
#   'Wind Speed mph': 2.98,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp F°': 49.05,
#   'Humidity %': 76,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 10.89,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mitu',
#   'Country': 'CO',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp F°': 68.86,
#   'Humidity %': 99,
#   'Cloudiness %': 96,
#   'Wind Speed mph': 1.52,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp F°': 70.56,
#   'Humidity %': 89,
#   'Cloudiness %': 57,
#   'Wind Speed mph': 3,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sal Rei',
#   'Country': 'CV',
#   'Lat': 16.1833,
#   'Lng': -22.9167,
#   'Max Temp F°': 75.76,
#   'Humidity %': 86,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 13.2,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Perth',
#   'Country': 'AU',
#   'Lat': -31.9333,
#   'Lng': 115.8333,
#   'Max Temp F°': 58.08,
#   'Humidity %': 64,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp F°': 61.11,
#   'Humidity %': 91,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 17.69,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Portel',
#   'Country': 'BR',
#   'Lat': -1.9356,
#   'Lng': -50.8211,
#   'Max Temp F°': 78.87,
#   'Humidity %': 66,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 3.22,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Maneadero',
#   'Country': 'MX',
#   'Lat': 31.7167,
#   'Lng': -116.5667,
#   'Max Temp F°': 75.18,
#   'Humidity %': 78,
#   'Cloudiness %': 22,
#   'Wind Speed mph': 3,
#   'Weather Description': 'few clouds'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp F°': 68.32,
#   'Humidity %': 53,
#   'Cloudiness %': 67,
#   'Wind Speed mph': 3.04,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp F°': 58.78,
#   'Humidity %': 43,
#   'Cloudiness %': 10,
#   'Wind Speed mph': 11.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Eston',
#   'Country': 'CA',
#   'Lat': 51.1501,
#   'Lng': -108.7514,
#   'Max Temp F°': 85.93,
#   'Humidity %': 25,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 8.03,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp F°': 59.56,
#   'Humidity %': 57,
#   'Cloudiness %': 38,
#   'Wind Speed mph': 3.96,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp F°': 43.9,
#   'Humidity %': 70,
#   'Cloudiness %': 38,
#   'Wind Speed mph': 5.37,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Merauke',
#   'Country': 'ID',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp F°': 80.1,
#   'Humidity %': 68,
#   'Cloudiness %': 97,
#   'Wind Speed mph': 10.58,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp F°': 75.47,
#   'Humidity %': 44,
#   'Cloudiness %': 16,
#   'Wind Speed mph': 1.95,
#   'Weather Description': 'few clouds'},
#  {'City': 'Miajadas',
#   'Country': 'ES',
#   'Lat': 39.1513,
#   'Lng': -5.9084,
#   'Max Temp F°': 73.78,
#   'Humidity %': 63,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 4.7,
#   'Weather Description': 'clear sky'},
#  {'City': 'Skelleftea',
#   'Country': 'SE',
#   'Lat': 64.7507,
#   'Lng': 20.9528,
#   'Max Temp F°': 50.36,
#   'Humidity %': 81,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kulhudhuffushi',
#   'Country': 'MV',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp F°': 81.37,
#   'Humidity %': 79,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 13.8,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp F°': 81.09,
#   'Humidity %': 81,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp F°': 64.4,
#   'Humidity %': 97,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.59,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Corn Island',
#   'Country': 'NI',
#   'Lat': 12.1694,
#   'Lng': -83.0418,
#   'Max Temp F°': 82.08,
#   'Humidity %': 81,
#   'Cloudiness %': 16,
#   'Wind Speed mph': 12.5,
#   'Weather Description': 'few clouds'},
#  {'City': 'Trapani',
#   'Country': 'IT',
#   'Lat': 37.8333,
#   'Lng': 12.6667,
#   'Max Temp F°': 76.93,
#   'Humidity %': 48,
#   'Cloudiness %': 12,
#   'Wind Speed mph': 4.74,
#   'Weather Description': 'few clouds'},
#  {'City': 'Puertollano',
#   'Country': 'ES',
#   'Lat': 38.6871,
#   'Lng': -4.1073,
#   'Max Temp F°': 77.16,
#   'Humidity %': 25,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 4.07,
#   'Weather Description': 'clear sky'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp F°': 68.72,
#   'Humidity %': 34,
#   'Cloudiness %': 45,
#   'Wind Speed mph': 3.6,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp F°': 59.72,
#   'Humidity %': 58,
#   'Cloudiness %': 86,
#   'Wind Speed mph': 8.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jiaojiang',
#   'Country': 'CN',
#   'Lat': 28.6803,
#   'Lng': 121.4428,
#   'Max Temp F°': 84.99,
#   'Humidity %': 85,
#   'Cloudiness %': 56,
#   'Wind Speed mph': 3.87,
#   'Weather Description': 'light rain'},
#  {'City': 'Limoux',
#   'Country': 'FR',
#   'Lat': 42.9167,
#   'Lng': 2.1667,
#   'Max Temp F°': 66.54,
#   'Humidity %': 52,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 5.7,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp F°': 77.31,
#   'Humidity %': 72,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 27.07,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp F°': 56.64,
#   'Humidity %': 94,
#   'Cloudiness %': 60,
#   'Wind Speed mph': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp F°': 79.16,
#   'Humidity %': 71,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 8.41,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gambo',
#   'Country': 'CF',
#   'Lat': 4.6482,
#   'Lng': 22.2633,
#   'Max Temp F°': 70.39,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 1.12,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp F°': 63.28,
#   'Humidity %': 50,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mackay',
#   'Country': 'AU',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp F°': 71.69,
#   'Humidity %': 54,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 15.1,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp F°': 72.99,
#   'Humidity %': 86,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp F°': 39.4,
#   'Humidity %': 93,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.08,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp F°': 76.1,
#   'Humidity %': 83,
#   'Cloudiness %': 53,
#   'Wind Speed mph': 15.59,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Porosozero',
#   'Country': 'RU',
#   'Lat': 62.7191,
#   'Lng': 32.727,
#   'Max Temp F°': 51.76,
#   'Humidity %': 71,
#   'Cloudiness %': 68,
#   'Wind Speed mph': 3.06,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Santiago Del Estero',
#   'Country': 'AR',
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp F°': 53.8,
#   'Humidity %': 26,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 7.78,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bantou',
#   'Country': 'CN',
#   'Lat': 26.2151,
#   'Lng': 117.4893,
#   'Max Temp F°': 76.66,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 4.97,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp F°': 50.49,
#   'Humidity %': 91,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 3.13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp F°': 77.97,
#   'Humidity %': 73,
#   'Cloudiness %': 17,
#   'Wind Speed mph': 13.38,
#   'Weather Description': 'few clouds'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp F°': 73.9,
#   'Humidity %': 69,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 9.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bathsheba',
#   'Country': 'BB',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp F°': 81.21,
#   'Humidity %': 83,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 11.5,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Malmesbury',
#   'Country': 'ZA',
#   'Lat': -33.4608,
#   'Lng': 18.7271,
#   'Max Temp F°': 52.79,
#   'Humidity %': 89,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.06,
#   'Weather Description': 'clear sky'},
#  {'City': 'Mufumbwe',
#   'Country': 'ZM',
#   'Lat': -13.6833,
#   'Lng': 24.8,
#   'Max Temp F°': 49.15,
#   'Humidity %': 32,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.89,
#   'Weather Description': 'clear sky'},
#  {'City': 'Cabedelo',
#   'Country': 'BR',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp F°': 72.27,
#   'Humidity %': 85,
#   'Cloudiness %': 11,
#   'Wind Speed mph': 14.99,
#   'Weather Description': 'few clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp F°': 54,
#   'Humidity %': 86,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.8,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Vicente',
#   'Country': 'AR',
#   'Lat': -26.6167,
#   'Lng': -54.1333,
#   'Max Temp F°': 58.82,
#   'Humidity %': 60,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.8,
#   'Weather Description': 'light rain'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp F°': 57.09,
#   'Humidity %': 94,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 1.74,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Koplik',
#   'Country': 'AL',
#   'Lat': 42.2136,
#   'Lng': 19.4364,
#   'Max Temp F°': 76.6,
#   'Humidity %': 60,
#   'Cloudiness %': 35,
#   'Wind Speed mph': 3.33,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'San Vicente De Canete',
#   'Country': 'PE',
#   'Lat': -13.0751,
#   'Lng': -76.3835,
#   'Max Temp F°': 63.68,
#   'Humidity %': 83,
#   'Cloudiness %': 28,
#   'Wind Speed mph': 5.26,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp F°': 54.12,
#   'Humidity %': 71,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 17.27,
#   'Weather Description': 'clear sky'},
#  {'City': 'North Bend',
#   'Country': 'US',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp F°': 74.25,
#   'Humidity %': 94,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 8.05,
#   'Weather Description': 'clear sky'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp F°': 84.38,
#   'Humidity %': 93,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.99,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Jasper',
#   'Country': 'US',
#   'Lat': 37.2001,
#   'Lng': -94.3502,
#   'Max Temp F°': 78.85,
#   'Humidity %': 78,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'haze'},
#  {'City': 'Sovetskiy',
#   'Country': 'RU',
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp F°': 61.25,
#   'Humidity %': 98,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.48,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp F°': 76.19,
#   'Humidity %': 69,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 3,
#   'Weather Description': 'few clouds'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp F°': 65.46,
#   'Humidity %': 69,
#   'Cloudiness %': 13,
#   'Wind Speed mph': 4,
#   'Weather Description': 'few clouds'},
#  {'City': 'Wabash',
#   'Country': 'US',
#   'Lat': 40.7978,
#   'Lng': -85.8205,
#   'Max Temp F°': 75.7,
#   'Humidity %': 76,
#   'Cloudiness %': 21,
#   'Wind Speed mph': 5.03,
#   'Weather Description': 'few clouds'},
#  {'City': 'Jiazi',
#   'Country': 'CN',
#   'Lat': 22.8779,
#   'Lng': 116.067,
#   'Max Temp F°': 80.4,
#   'Humidity %': 92,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 19.1,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Takaka',
#   'Country': 'NZ',
#   'Lat': -40.85,
#   'Lng': 172.8,
#   'Max Temp F°': 57.97,
#   'Humidity %': 71,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 5.59,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Kuminskiy',
#   'Country': 'RU',
#   'Lat': 58.6667,
#   'Lng': 66.5667,
#   'Max Temp F°': 62.15,
#   'Humidity %': 99,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.15,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp F°': 82.13,
#   'Humidity %': 76,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'light rain'},
#  {'City': 'Crib Point',
#   'Country': 'AU',
#   'Lat': -38.35,
#   'Lng': 145.2,
#   'Max Temp F°': 57.85,
#   'Humidity %': 85,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 15.57,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Cartaya',
#   'Country': 'ES',
#   'Lat': 37.2811,
#   'Lng': -7.1507,
#   'Max Temp F°': 79.18,
#   'Humidity %': 49,
#   'Cloudiness %': 3,
#   'Wind Speed mph': 19.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp F°': 54.81,
#   'Humidity %': 85,
#   'Cloudiness %': 68,
#   'Wind Speed mph': 8.61,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Praia',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp F°': 77.54,
#   'Humidity %': 94,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 16.11,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp F°': 91.29,
#   'Humidity %': 73,
#   'Cloudiness %': 9,
#   'Wind Speed mph': 7.16,
#   'Weather Description': 'clear sky'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp F°': 40.68,
#   'Humidity %': 90,
#   'Cloudiness %': 82,
#   'Wind Speed mph': 7,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Flamanzi',
#   'Country': 'RO',
#   'Lat': 47.559,
#   'Lng': 26.8946,
#   'Max Temp F°': 69.71,
#   'Humidity %': 97,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 3.29,
#   'Weather Description': 'light rain'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp F°': 82.15,
#   'Humidity %': 77,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Carbondale',
#   'Country': 'US',
#   'Lat': 37.7273,
#   'Lng': -89.2168,
#   'Max Temp F°': 75.09,
#   'Humidity %': 72,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 3.44,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp F°': 84.29,
#   'Humidity %': 69,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 9.35,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Georges',
#   'Country': 'GD',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp F°': 80.28,
#   'Humidity %': 89,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 0,
#   'Weather Description': 'few clouds'},
#  {'City': 'Coihaique',
#   'Country': 'CL',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp F°': 49.95,
#   'Humidity %': 46,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 11.5,
#   'Weather Description': 'light rain'},
#  {'City': 'Ngunguru',
#   'Country': 'NZ',
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp F°': 61.16,
#   'Humidity %': 81,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 14.27,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yarim',
#   'Country': 'YE',
#   'Lat': 14.298,
#   'Lng': 44.3779,
#   'Max Temp F°': 60.15,
#   'Humidity %': 64,
#   'Cloudiness %': 94,
#   'Wind Speed mph': 2.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp F°': 39.43,
#   'Humidity %': 100,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 11.5,
#   'Weather Description': 'mist'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp F°': 55.31,
#   'Humidity %': 64,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 18.03,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nakasongola',
#   'Country': 'UG',
#   'Lat': 1.3089,
#   'Lng': 32.4564,
#   'Max Temp F°': 65.35,
#   'Humidity %': 78,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp F°': 64.78,
#   'Humidity %': 47,
#   'Cloudiness %': 67,
#   'Wind Speed mph': 4.47,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp F°': 68.31,
#   'Humidity %': 81,
#   'Cloudiness %': 22,
#   'Wind Speed mph': 14.5,
#   'Weather Description': 'few clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp F°': 68.49,
#   'Humidity %': 34,
#   'Cloudiness %': 11,
#   'Wind Speed mph': 12.55,
#   'Weather Description': 'few clouds'},
#  {'City': 'Mahroni',
#   'Country': 'IN',
#   'Lat': 24.5862,
#   'Lng': 78.7288,
#   'Max Temp F°': 75.36,
#   'Humidity %': 95,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 9.33,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dalbandin',
#   'Country': 'PK',
#   'Lat': 28.8947,
#   'Lng': 64.4101,
#   'Max Temp F°': 82.78,
#   'Humidity %': 17,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 9.6,
#   'Weather Description': 'clear sky'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp F°': 46.06,
#   'Humidity %': 97,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.79,
#   'Weather Description': 'light rain'},
#  {'City': 'Wewak',
#   'Country': 'PG',
#   'Lat': -3.5534,
#   'Lng': 143.6268,
#   'Max Temp F°': 83.5,
#   'Humidity %': 73,
#   'Cloudiness %': 13,
#   'Wind Speed mph': 3.67,
#   'Weather Description': 'few clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp F°': 77,
#   'Humidity %': 84,
#   'Cloudiness %': 47,
#   'Wind Speed mph': 2.21,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp F°': 78.89,
#   'Humidity %': 67,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Helong',
#   'Country': 'CN',
#   'Lat': 42.5397,
#   'Lng': 128.9972,
#   'Max Temp F°': 75.97,
#   'Humidity %': 65,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.71,
#   'Weather Description': 'light rain'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp F°': 44.15,
#   'Humidity %': 94,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 12.82,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sembakung',
#   'Country': 'ID',
#   'Lat': 3.8167,
#   'Lng': 117.25,
#   'Max Temp F°': 80.53,
#   'Humidity %': 78,
#   'Cloudiness %': 39,
#   'Wind Speed mph': 2.71,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Iberia',
#   'Country': 'US',
#   'Lat': 29.9502,
#   'Lng': -91.7507,
#   'Max Temp F°': 80.67,
#   'Humidity %': 69,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'clear sky'},
#  {'City': 'Ripky',
#   'Country': 'UA',
#   'Lat': 51.801,
#   'Lng': 31.0838,
#   'Max Temp F°': 63.52,
#   'Humidity %': 93,
#   'Cloudiness %': 88,
#   'Wind Speed mph': 6.82,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nishihara',
#   'Country': 'JP',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp F°': 85.68,
#   'Humidity %': 86,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Prince Albert',
#   'Country': 'CA',
#   'Lat': 53.2001,
#   'Lng': -105.7677,
#   'Max Temp F°': 77.72,
#   'Humidity %': 51,
#   'Cloudiness %': 5,
#   'Wind Speed mph': 7.31,
#   'Weather Description': 'clear sky'},
#  {'City': 'Jingdezhen',
#   'Country': 'CN',
#   'Lat': 29.2947,
#   'Lng': 117.2079,
#   'Max Temp F°': 87.1,
#   'Humidity %': 66,
#   'Cloudiness %': 14,
#   'Wind Speed mph': 5.68,
#   'Weather Description': 'light rain'},
#  {'City': 'Atlantic Beach',
#   'Country': 'US',
#   'Lat': 30.3344,
#   'Lng': -81.3987,
#   'Max Temp F°': 79.23,
#   'Humidity %': 94,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Honiara',
#   'Country': 'SB',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp F°': 85.03,
#   'Humidity %': 58,
#   'Cloudiness %': 15,
#   'Wind Speed mph': 3.89,
#   'Weather Description': 'few clouds'},
#  {'City': 'Anchorage',
#   'Country': 'US',
#   'Lat': 61.2181,
#   'Lng': -149.9003,
#   'Max Temp F°': 75.2,
#   'Humidity %': 74,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 8.99,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp F°': 68.76,
#   'Humidity %': 77,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 0,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Watertown',
#   'Country': 'US',
#   'Lat': 42.3709,
#   'Lng': -71.1828,
#   'Max Temp F°': 68.5,
#   'Humidity %': 94,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 1.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ampanihy',
#   'Country': 'MG',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp F°': 63.84,
#   'Humidity %': 55,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 5.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Bozdar',
#   'Country': 'PK',
#   'Lat': 27.1828,
#   'Lng': 68.636,
#   'Max Temp F°': 82.47,
#   'Humidity %': 69,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 16.24,
#   'Weather Description': 'clear sky'},
#  {'City': 'Turbat',
#   'Country': 'PK',
#   'Lat': 26.0023,
#   'Lng': 63.044,
#   'Max Temp F°': 87.91,
#   'Humidity %': 55,
#   'Cloudiness %': 4,
#   'Wind Speed mph': 2.66,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp F°': 69.85,
#   'Humidity %': 87,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 24.58,
#   'Weather Description': 'clear sky'},
#  {'City': 'Carbonia',
#   'Country': 'IT',
#   'Lat': 39.1672,
#   'Lng': 8.5222,
#   'Max Temp F°': 74.98,
#   'Humidity %': 62,
#   'Cloudiness %': 24,
#   'Wind Speed mph': 3.24,
#   'Weather Description': 'few clouds'},
#  {'City': 'Teodoro Sampaio',
#   'Country': 'BR',
#   'Lat': -22.5325,
#   'Lng': -52.1675,
#   'Max Temp F°': 65.98,
#   'Humidity %': 55,
#   'Cloudiness %': 89,
#   'Wind Speed mph': 8.63,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp F°': 65.16,
#   'Humidity %': 82,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 21.85,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Esso',
#   'Country': 'RU',
#   'Lat': 55.9333,
#   'Lng': 158.7,
#   'Max Temp F°': 47.34,
#   'Humidity %': 75,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 7.65,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp F°': 82.83,
#   'Humidity %': 75,
#   'Cloudiness %': 85,
#   'Wind Speed mph': 10.38,
#   'Weather Description': 'light rain'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp F°': 65.12,
#   'Humidity %': 72,
#   'Cloudiness %': 74,
#   'Wind Speed mph': 5.95,
#   'Weather Description': 'broken clouds'},
#  {'City': 'San Lorenzo',
#   'Country': 'PY',
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp F°': 61.83,
#   'Humidity %': 61,
#   'Cloudiness %': 9,
#   'Wind Speed mph': 6.38,
#   'Weather Description': 'clear sky'},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp F°': 81.93,
#   'Humidity %': 87,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 13.69,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Derzhavinsk',
#   'Country': 'KZ',
#   'Lat': 51.1,
#   'Lng': 66.3167,
#   'Max Temp F°': 72.19,
#   'Humidity %': 47,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.15,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Khash',
#   'Country': 'IR',
#   'Lat': 28.2211,
#   'Lng': 61.2158,
#   'Max Temp F°': 75.04,
#   'Humidity %': 18,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 2.08,
#   'Weather Description': 'clear sky'},
#  {'City': 'Angoram',
#   'Country': 'PG',
#   'Lat': -4.0625,
#   'Lng': 144.0661,
#   'Max Temp F°': 89.38,
#   'Humidity %': 57,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 1.63,
#   'Weather Description': 'clear sky'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp F°': 73.38,
#   'Humidity %': 16,
#   'Cloudiness %': 2,
#   'Wind Speed mph': 20.71,
#   'Weather Description': 'clear sky'},
#  {'City': 'Katobu',
#   'Country': 'ID',
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Max Temp F°': 81.66,
#   'Humidity %': 69,
#   'Cloudiness %': 94,
#   'Wind Speed mph': 8.23,
#   'Weather Description': 'moderate rain'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp F°': 66.31,
#   'Humidity %': 81,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 2.48,
#   'Weather Description': 'clear sky'},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp F°': 80.04,
#   'Humidity %': 68,
#   'Cloudiness %': 95,
#   'Wind Speed mph': 14.05,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp F°': 71.13,
#   'Humidity %': 76,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 12.19,
#   'Weather Description': 'clear sky'},
#  {'City': 'Banjar',
#   'Country': 'ID',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp F°': 80.46,
#   'Humidity %': 77,
#   'Cloudiness %': 38,
#   'Wind Speed mph': 0.85,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'America Dourada',
#   'Country': 'BR',
#   'Lat': -11.4553,
#   'Lng': -41.4361,
#   'Max Temp F°': 65.23,
#   'Humidity %': 78,
#   'Cloudiness %': 81,
#   'Wind Speed mph': 9.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Arica',
#   'Country': 'CL',
#   'Lat': -18.475,
#   'Lng': -70.3042,
#   'Max Temp F°': 59.23,
#   'Humidity %': 82,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 4.61,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Nhulunbuy',
#   'Country': 'AU',
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp F°': 77.61,
#   'Humidity %': 53,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 16.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Nizhniy Kuranakh',
#   'Country': 'RU',
#   'Lat': 58.8353,
#   'Lng': 125.4869,
#   'Max Temp F°': 68.2,
#   'Humidity %': 67,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.77,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp F°': 80.64,
#   'Humidity %': 76,
#   'Cloudiness %': 87,
#   'Wind Speed mph': 7.45,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Asyut',
#   'Country': 'EG',
#   'Lat': 27.181,
#   'Lng': 31.1837,
#   'Max Temp F°': 87.96,
#   'Humidity %': 16,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 5.3,
#   'Weather Description': 'clear sky'},
#  {'City': 'Liwale',
#   'Country': 'TZ',
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp F°': 63.5,
#   'Humidity %': 91,
#   'Cloudiness %': 53,
#   'Wind Speed mph': 1.48,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp F°': 65.75,
#   'Humidity %': 71,
#   'Cloudiness %': 49,
#   'Wind Speed mph': 9.17,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp F°': 78.89,
#   'Humidity %': 94,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'light intensity drizzle'},
#  {'City': 'Indramayu',
#   'Country': 'ID',
#   'Lat': -6.3264,
#   'Lng': 108.32,
#   'Max Temp F°': 82.81,
#   'Humidity %': 72,
#   'Cloudiness %': 82,
#   'Wind Speed mph': 14.29,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp F°': 79.93,
#   'Humidity %': 48,
#   'Cloudiness %': 84,
#   'Wind Speed mph': 6.35,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Northam',
#   'Country': 'GB',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp F°': 61.66,
#   'Humidity %': 97,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 21.36,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Formosa',
#   'Country': 'AR',
#   'Lat': -26.1775,
#   'Lng': -58.1781,
#   'Max Temp F°': 64.38,
#   'Humidity %': 72,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'light rain'},
#  {'City': 'Ambilobe',
#   'Country': 'MG',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp F°': 70.2,
#   'Humidity %': 68,
#   'Cloudiness %': 85,
#   'Wind Speed mph': 2.17,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Ambulu',
#   'Country': 'ID',
#   'Lat': -8.345,
#   'Lng': 113.6058,
#   'Max Temp F°': 78.24,
#   'Humidity %': 80,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shenjiamen',
#   'Country': 'CN',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp F°': 82.02,
#   'Humidity %': 81,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 7.09,
#   'Weather Description': 'clear sky'},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp F°': 86.32,
#   'Humidity %': 56,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vanavara',
#   'Country': 'RU',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp F°': 66.31,
#   'Humidity %': 60,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.08,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp F°': 43.88,
#   'Humidity %': 72,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 9.13,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Riachao Das Neves',
#   'Country': 'BR',
#   'Lat': -11.7461,
#   'Lng': -44.91,
#   'Max Temp F°': 70.07,
#   'Humidity %': 41,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.77,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp F°': 64.76,
#   'Humidity %': 72,
#   'Cloudiness %': 48,
#   'Wind Speed mph': 9.69,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Hauterive',
#   'Country': 'FR',
#   'Lat': 46.0901,
#   'Lng': 3.4459,
#   'Max Temp F°': 68.76,
#   'Humidity %': 82,
#   'Cloudiness %': 97,
# ...
#   'Humidity %': 86,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 10.36,
#   'Weather Description': 'clear sky'},
#  {'City': 'Baruun-Urt',
#   'Country': 'MN',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp F°': 69.57,
#   'Humidity %': 47,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 10.33,
#   'Weather Description': 'clear sky'},
#  {'City': 'Zhangye',
#   'Country': 'CN',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp F°': 79.93,
#   'Humidity %': 31,
#   'Cloudiness %': 83,
#   'Wind Speed mph': 6.93,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Tlaltizapan',
#   'Country': 'MX',
#   'Lat': 18.6833,
#   'Lng': -99.1167,
#   'Max Temp F°': 74.16,
#   'Humidity %': 81,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 1.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Mae Sai',
#   'Country': 'TH',
#   'Lat': 20.4335,
#   'Lng': 99.8762,
#   'Max Temp F°': 79.45,
#   'Humidity %': 97,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 1.1,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp F°': 92.21,
#   'Humidity %': 45,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 10.71,
#   'Weather Description': 'clear sky'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp F°': 57.11,
#   'Humidity %': 94,
#   'Cloudiness %': 53,
#   'Wind Speed mph': 15.14,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Ganzhou',
#   'Country': 'CN',
#   'Lat': 28.8184,
#   'Lng': 115.4327,
#   'Max Temp F°': 87.17,
#   'Humidity %': 73,
#   'Cloudiness %': 5,
#   'Wind Speed mph': 7.23,
#   'Weather Description': 'clear sky'},
#  {'City': 'Koygorodok',
#   'Country': 'RU',
#   'Lat': 60.445,
#   'Lng': 50.9968,
#   'Max Temp F°': 46.51,
#   'Humidity %': 86,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.58,
#   'Weather Description': 'clear sky'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp F°': 69.91,
#   'Humidity %': 100,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Muisne',
#   'Country': 'EC',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp F°': 75.45,
#   'Humidity %': 85,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 9.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Voyvozh',
#   'Country': 'RU',
#   'Lat': 62.892,
#   'Lng': 54.9635,
#   'Max Temp F°': 45.63,
#   'Humidity %': 90,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 4.94,
#   'Weather Description': 'clear sky'},
#  {'City': 'Dergachi',
#   'Country': 'RU',
#   'Lat': 51.2328,
#   'Lng': 48.7659,
#   'Max Temp F°': 64.31,
#   'Humidity %': 51,
#   'Cloudiness %': 78,
#   'Wind Speed mph': 7.58,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sosua',
#   'Country': 'DO',
#   'Lat': 19.7667,
#   'Lng': -70.5167,
#   'Max Temp F°': 82.53,
#   'Humidity %': 94,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Bedesa',
#   'Country': 'ET',
#   'Lat': 8.9,
#   'Lng': 40.7833,
#   'Max Temp F°': 62.19,
#   'Humidity %': 74,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.85,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yaan',
#   'Country': 'NG',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp F°': 70.45,
#   'Humidity %': 97,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 4.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Lakes Entrance',
#   'Country': 'AU',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp F°': 60.19,
#   'Humidity %': 57,
#   'Cloudiness %': 48,
#   'Wind Speed mph': 14.74,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp F°': 82.47,
#   'Humidity %': 73,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 11.1,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Shirokiy',
#   'Country': 'RU',
#   'Lat': 49.758,
#   'Lng': 129.523,
#   'Max Temp F°': 69.33,
#   'Humidity %': 87,
#   'Cloudiness %': 98,
#   'Wind Speed mph': 11.3,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Clarksburg',
#   'Country': 'US',
#   'Lat': 39.2807,
#   'Lng': -80.3445,
#   'Max Temp F°': 73.85,
#   'Humidity %': 80,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 0,
#   'Weather Description': 'clear sky'},
#  {'City': 'Charleston',
#   'Country': 'US',
#   'Lat': 32.7766,
#   'Lng': -79.9309,
#   'Max Temp F°': 75.36,
#   'Humidity %': 94,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 4,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp F°': 37.15,
#   'Humidity %': 92,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.28,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Santa Rita',
#   'Country': 'BR',
#   'Lat': -7.1139,
#   'Lng': -34.9781,
#   'Max Temp F°': 72.27,
#   'Humidity %': 100,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 10.36,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Wilmington',
#   'Country': 'US',
#   'Lat': 34.2257,
#   'Lng': -77.9447,
#   'Max Temp F°': 78.71,
#   'Humidity %': 85,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 0,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Monywa',
#   'Country': 'MM',
#   'Lat': 22.1167,
#   'Lng': 95.1333,
#   'Max Temp F°': 77.22,
#   'Humidity %': 90,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.68,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Moerai',
#   'Country': 'PF',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp F°': 73.69,
#   'Humidity %': 71,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 7.78,
#   'Weather Description': 'clear sky'},
#  {'City': 'San Luis',
#   'Country': 'AR',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp F°': 60.03,
#   'Humidity %': 35,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 7.47,
#   'Weather Description': 'clear sky'},
#  {'City': 'Effium',
#   'Country': 'NG',
#   'Lat': 6.6292,
#   'Lng': 8.0593,
#   'Max Temp F°': 72.01,
#   'Humidity %': 96,
#   'Cloudiness %': 89,
#   'Wind Speed mph': 4.25,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Clifton',
#   'Country': 'US',
#   'Lat': 40.8584,
#   'Lng': -74.1638,
#   'Max Temp F°': 75.81,
#   'Humidity %': 77,
#   'Cloudiness %': 40,
#   'Wind Speed mph': 1.99,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Manavalakurichi',
#   'Country': 'IN',
#   'Lat': 8.1333,
#   'Lng': 77.3,
#   'Max Temp F°': 77.09,
#   'Humidity %': 80,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 15.84,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Vadodara',
#   'Country': 'IN',
#   'Lat': 22.3,
#   'Lng': 73.2,
#   'Max Temp F°': 80.56,
#   'Humidity %': 89,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 9.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Stornoway',
#   'Country': 'GB',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp F°': 60.93,
#   'Humidity %': 82,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 12.66,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Bairiki',
#   'Country': 'KI',
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp F°': 86,
#   'Humidity %': 62,
#   'Cloudiness %': 20,
#   'Wind Speed mph': 13.8,
#   'Weather Description': 'few clouds'},
#  {'City': 'Quatre Cocos',
#   'Country': 'MU',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp F°': 68.11,
#   'Humidity %': 73,
#   'Cloudiness %': 71,
#   'Wind Speed mph': 14.05,
#   'Weather Description': 'light rain'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp F°': 72.01,
#   'Humidity %': 91,
#   'Cloudiness %': 47,
#   'Wind Speed mph': 7.18,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Mahibadhoo',
#   'Country': 'MV',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp F°': 81.18,
#   'Humidity %': 78,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.66,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Biloela',
#   'Country': 'AU',
#   'Lat': -24.4167,
#   'Lng': 150.5,
#   'Max Temp F°': 65.86,
#   'Humidity %': 36,
#   'Cloudiness %': 43,
#   'Wind Speed mph': 13.29,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Novobirilyussy',
#   'Country': 'RU',
#   'Lat': 56.9514,
#   'Lng': 90.6661,
#   'Max Temp F°': 62.31,
#   'Humidity %': 84,
#   'Cloudiness %': 42,
#   'Wind Speed mph': 1.16,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'San Zenon',
#   'Country': 'CO',
#   'Lat': 9.2422,
#   'Lng': -74.5004,
#   'Max Temp F°': 80.73,
#   'Humidity %': 77,
#   'Cloudiness %': 11,
#   'Wind Speed mph': 7.29,
#   'Weather Description': 'few clouds'},
#  {'City': 'Newport',
#   'Country': 'GB',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp F°': 61.86,
#   'Humidity %': 92,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 13.98,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Yanam',
#   'Country': 'IN',
#   'Lat': 16.7333,
#   'Lng': 82.2167,
#   'Max Temp F°': 84.6,
#   'Humidity %': 78,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 5.95,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp F°': 71.65,
#   'Humidity %': 21,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 25.32,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp F°': 67.77,
#   'Humidity %': 26,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 16.11,
#   'Weather Description': 'clear sky'},
#  {'City': 'Aktau',
#   'Country': 'KZ',
#   'Lat': 43.65,
#   'Lng': 51.2,
#   'Max Temp F°': 73.98,
#   'Humidity %': 46,
#   'Cloudiness %': 11,
#   'Wind Speed mph': 5.95,
#   'Weather Description': 'few clouds'},
#  {'City': 'Santa Rosa',
#   'Country': 'PH',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp F°': 90.09,
#   'Humidity %': 71,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 12.57,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Little Rock',
#   'Country': 'US',
#   'Lat': 34.7465,
#   'Lng': -92.2896,
#   'Max Temp F°': 82.22,
#   'Humidity %': 57,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 5.75,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Skjervoy',
#   'Country': 'NO',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp F°': 52.56,
#   'Humidity %': 81,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 6.78,
#   'Weather Description': 'light rain'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp F°': 90.16,
#   'Humidity %': 39,
#   'Cloudiness %': 10,
#   'Wind Speed mph': 8.34,
#   'Weather Description': 'clear sky'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp F°': 54.52,
#   'Humidity %': 95,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 7.02,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Kota Belud',
#   'Country': 'MY',
#   'Lat': 6.351,
#   'Lng': 116.4305,
#   'Max Temp F°': 87.66,
#   'Humidity %': 58,
#   'Cloudiness %': 74,
#   'Wind Speed mph': 3.22,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Najran',
#   'Country': 'SA',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp F°': 84.85,
#   'Humidity %': 44,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.5,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Scalea',
#   'Country': 'IT',
#   'Lat': 39.813,
#   'Lng': 15.7956,
#   'Max Temp F°': 75.34,
#   'Humidity %': 69,
#   'Cloudiness %': 34,
#   'Wind Speed mph': 9.01,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Halifax',
#   'Country': 'CA',
#   'Lat': 44.6453,
#   'Lng': -63.5724,
#   'Max Temp F°': 73.42,
#   'Humidity %': 95,
#   'Cloudiness %': 92,
#   'Wind Speed mph': 5.01,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Balaguer',
#   'Country': 'ES',
#   'Lat': 41.7912,
#   'Lng': 0.8109,
#   'Max Temp F°': 74.88,
#   'Humidity %': 63,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 9.89,
#   'Weather Description': 'clear sky'},
#  {'City': 'Chegutu',
#   'Country': 'ZW',
#   'Lat': -18.1302,
#   'Lng': 30.1407,
#   'Max Temp F°': 52.7,
#   'Humidity %': 43,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 3.85,
#   'Weather Description': 'clear sky'},
#  {'City': 'Harnosand',
#   'Country': 'SE',
#   'Lat': 62.6323,
#   'Lng': 17.9379,
#   'Max Temp F°': 59,
#   'Humidity %': 86,
#   'Cloudiness %': 48,
#   'Wind Speed mph': 5.64,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Slave Lake',
#   'Country': 'CA',
#   'Lat': 55.2834,
#   'Lng': -114.769,
#   'Max Temp F°': 80.58,
#   'Humidity %': 50,
#   'Cloudiness %': 1,
#   'Wind Speed mph': 6.91,
#   'Weather Description': 'clear sky'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp F°': 50.2,
#   'Humidity %': 82,
#   'Cloudiness %': 52,
#   'Wind Speed mph': 2.57,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Belaya Gora',
#   'Country': 'RU',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp F°': 48.45,
#   'Humidity %': 68,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 3.69,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp F°': 64.78,
#   'Humidity %': 84,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 6.04,
#   'Weather Description': 'clear sky'},
#  {'City': 'Corralillo',
#   'Country': 'CU',
#   'Lat': 22.9819,
#   'Lng': -80.5856,
#   'Max Temp F°': 80.19,
#   'Humidity %': 81,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 7.29,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Flin Flon',
#   'Country': 'CA',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp F°': 73.53,
#   'Humidity %': 39,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 2.44,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Dauriya',
#   'Country': 'RU',
#   'Lat': 49.9333,
#   'Lng': 116.8667,
#   'Max Temp F°': 70.84,
#   'Humidity %': 54,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 10.2,
#   'Weather Description': 'clear sky'},
#  {'City': 'Weihai',
#   'Country': 'CN',
#   'Lat': 37.5017,
#   'Lng': 122.1136,
#   'Max Temp F°': 76.08,
#   'Humidity %': 81,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 5.79,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Kiunga',
#   'Country': 'PG',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp F°': 73.42,
#   'Humidity %': 96,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 2.57,
#   'Weather Description': 'light rain'},
#  {'City': 'Vila',
#   'Country': 'PT',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp F°': 53.33,
#   'Humidity %': 85,
#   'Cloudiness %': 39,
#   'Wind Speed mph': 1.9,
#   'Weather Description': 'scattered clouds'},
#  {'City': 'Lixourion',
#   'Country': 'GR',
#   'Lat': 38.2019,
#   'Lng': 20.4314,
#   'Max Temp F°': 79.41,
#   'Humidity %': 87,
#   'Cloudiness %': 0,
#   'Wind Speed mph': 5.35,
#   'Weather Description': 'clear sky'},
#  {'City': 'Onega',
#   'Country': 'RU',
#   'Lat': 63.9061,
#   'Lng': 38.1404,
#   'Max Temp F°': 46.08,
#   'Humidity %': 85,
#   'Cloudiness %': 13,
#   'Wind Speed mph': 4.38,
#   'Weather Description': 'few clouds'},
#  {'City': 'Igarka',
#   'Country': 'RU',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp F°': 68.23,
#   'Humidity %': 51,
#   'Cloudiness %': 76,
#   'Wind Speed mph': 7.45,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Vangaindrano',
#   'Country': 'MG',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp F°': 63.91,
#   'Humidity %': 87,
#   'Cloudiness %': 93,
#   'Wind Speed mph': 3.13,
#   'Weather Description': 'light rain'},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp F°': 77.54,
#   'Humidity %': 94,
#   'Cloudiness %': 75,
#   'Wind Speed mph': 16.11,
#   'Weather Description': 'broken clouds'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp F°': 79.57,
#   'Humidity %': 73,
#   'Cloudiness %': 99,
#   'Wind Speed mph': 1.81,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Strezhevoy',
#   'Country': 'RU',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp F°': 60.78,
#   'Humidity %': 76,
#   'Cloudiness %': 19,
#   'Wind Speed mph': 6.11,
#   'Weather Description': 'few clouds'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp F°': 77.16,
#   'Humidity %': 81,
#   'Cloudiness %': 6,
#   'Wind Speed mph': 10.67,
#   'Weather Description': 'clear sky'},
#  {'City': 'Milledgeville',
#   'Country': 'US',
#   'Lat': 33.0801,
#   'Lng': -83.2321,
#   'Max Temp F°': 78.49,
#   'Humidity %': 79,
#   'Cloudiness %': 90,
#   'Wind Speed mph': 4.54,
#   'Weather Description': 'overcast clouds'},
#  {'City': 'Gongzhuling',
#   'Country': 'CN',
#   'Lat': 43.5008,
#   'Lng': 124.8198,
#   'Max Temp F°': 75.11,
#   'Humidity %': 79,
#   'Cloudiness %': 100,
#   'Wind Speed mph': 8.55,
#   'Weather Description': 'overcast clouds'}]

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp F°  Humidity %  \
# 0    Mar Del Plata      AR -38.0023  -57.5575        57.09          28
# 1           Satipo      PE -11.2522  -74.6386        70.03          62
# 2           Juneau      US  58.3019 -134.4197        67.84          72
# 3            Adrar      MR  20.5022  -10.0711        91.17          16
# 4       Butaritari      KI   3.0707  172.7902        83.34          64
# ..             ...     ...      ...       ...          ...         ...
# 690        Sibolga      ID   1.7427   98.7792        79.57          73
# 691     Strezhevoy      RU  60.7333   77.5889        60.78          76
# 692    Port-Gentil      GA  -0.7193    8.7815        77.16          81
# 693  Milledgeville      US  33.0801  -83.2321        78.49          79
# 694    Gongzhuling      CN  43.5008  124.8198        75.11          79
#
#      Cloudiness %  Wind Speed mph Weather Description
# 0              90            1.99     overcast clouds
# 1              22            2.51          few clouds
# 2              75            6.91       broken clouds
# 3              90            7.70     overcast clouds
# 4              11           12.66          few clouds
# ..            ...             ...                 ...
# 690            99            1.81     overcast clouds
# 691            19            6.11          few clouds
# 692             6           10.67           clear sky
# 693            90            4.54     overcast clouds
# 694           100            8.55     overcast clouds
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
